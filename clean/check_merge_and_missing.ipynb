# %%
import csv
import pandas as pd
import clean
import os
import numpy as np
# %matplotlib inline
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from start import data_path

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
year = 'yr1718'

# %% [markdown]
# # Basic Descriptives - DREF
# data from: https://tea.texas.gov/perfreport/tapr/index.html
# reference of labels: https://rptsvr1.tea.texas.gov/perfreport/tapr/2016/download/dstaff.html
# steps to cleaning dref can be found in cleaning.py

# %%
dref = clean.clean_dref(year = year)
dref.head()
# Out:
# There are  1203 districts in dref
#    district       distname distischarter rating  cntyname
# 0      1902     CAYUGA ISD             N      M  ANDERSON
# 1      1903    ELKHART ISD             N      M  ANDERSON
# 2      1904  FRANKSTON ISD             N      M  ANDERSON
# 3      1906     NECHES ISD             N      M  ANDERSON
# 4      1907  PALESTINE ISD             N      M  ANDERSON

# %% [markdown]
# # Demographic data - DDEM
# data from: https://tea.texas.gov/perfreport/tapr/index.html
# reference of labels: https://rptsvr1.tea.texas.gov/perfreport/tapr/2016/download/dstaff.html

# %%
ddem = clean.clean_ddem(year = year)
ddem.head()
# Out:
# There are  1203 districts in ddem
#    district teachers_num teachers_new_num teachers_exp_ave  \
# 0      1902        105.5                1             15.4
# 1      1903        179.6                2             14.9
# 2      1904          121                2             13.7
# 3      1906         64.2              0.3             11.9
# 4      1907          481             23.1             11.2
#
#   teachers_tenure_ave teachers_turnover_denom teacher_turnover_num  \
# 0                 7.8                    54.4                    4
# 1                 9.4                   100.3                   11
# 2                 6.4                    58.1                 15.1
# 3                 6.6                    34.5                  2.5
# 4                 6.3                   270.3                 58.9
#
#   teachers_turnover_ratio teachers_nodegree_num teachers_badegree_num  \
# 0                     7.3                     0                  48.4
# 1                      11                     0                    84
# 2                      26                     0                    42
# 3                     7.2                     0                  35.3
# 4                    21.8                   5.3                 225.8
#
#   teachers_msdegree_num teachers_phddegree_num  students_num  \
# 0                     4                      0           576
# 1                    19                      0          1267
# 2                    17                      0           846
# 3                     0                      0           377
# 4                  32.4                      0          3453
#
#    students_frpl_num  students_hisp_num  students_white_num  \
# 0                192                 42                 479
# 1                673                137                1011
# 2                446                 82                 648
# 3                172                 51                 286
# 4               2587               1382                 974
#
#    students_black_num
# 0                  27
# 1                  67
# 2                  76
# 3                  28
# 4                 949

# %% [markdown]
# # Scores - dscores
# data from: https://tea.texas.gov/student.assessment/staar/aggregate/
# labels from: https://tea.texas.gov/student.assessment/staar/variables/

# %%
subject_list = ['3rd', '4th', '5th', '6th', '7th', '8th',
                'Algebra', 'Biology', 'EnglishI', 'EnglishII', 'USHistory']

# %%
dscores = pd.DataFrame(columns = ['district'])
for subject in subject_list:
    dscores_subject = clean.clean_scores(year, subject)
    dscores = dscores.merge(dscores_subject, how='outer', 
                            on = 'district')
dscores.head()
# Out:
# There are  1164 districts in  dataset.
# There are  1161 districts in  dataset.
# There are  1159 districts in  dataset.
# There are  1164 districts in  dataset.
# There are  1148 districts in  dataset.
# There are  1147 districts in  dataset.
# There are  1122 districts in  dataset.
# There are  1087 districts in  dataset.
# There are  1097 districts in  dataset.
# There are  1088 districts in  dataset.
# There are  1083 districts in  dataset.
#    district  r_3rd_avescore  r_3rd_numtakers  m_3rd_avescore  m_3rd_numtakers  \
# 0      1902          1466.0             51.0            51.0           1530.0
# 1      1903          1473.0             93.0            93.0           1516.0
# 2      1904          1463.0             76.0            76.0           1492.0
# 3      1906          1502.0             30.0            30.0           1460.0
# 4      1907          1395.0            231.0           255.0           1412.0
#
#    r_4th_avescore  r_4th_numtakers  m_4th_avescore  m_4th_numtakers  \
# 0          1554.0             51.0            50.0           1555.0
# 1          1554.0             73.0            73.0           1613.0
# 2          1516.0             67.0            67.0           1553.0
# 3          1528.0             20.0            20.0           1576.0
# 4          1493.0            243.0           243.0           1555.0
#
#    r_5th_avescore  r_5th_numtakers  m_5th_avescore  m_5th_numtakers  \
# 0          1607.0             36.0            36.0           1685.0
# 1          1585.0             81.0            81.0           1651.0
# 2          1634.0             58.0            58.0           1678.0
# 3          1619.0             24.0            24.0           1668.0
# 4          1539.0            254.0           254.0           1591.0
#
#    r_6th_avescore  r_6th_numtakers  m_6th_avescore  m_6th_numtakers  \
# 0          1576.0             40.0            40.0           1657.0
# 1          1616.0             85.0            85.0           1653.0
# 2          1587.0             63.0            63.0           1675.0
# 3          1577.0             25.0            25.0           1644.0
# 4          1554.0            234.0           235.0           1653.0
#
#    r_7th_avescore  r_7th_numtakers  m_7th_avescore  m_7th_numtakers  \
# 0          1698.0             44.0            44.0           1696.0
# 1          1656.0             87.0            87.0           1647.0
# 2          1667.0             71.0            71.0           1684.0
# 3          1690.0             29.0            29.0           1741.0
# 4          1610.0            248.0           248.0           1637.0
#
#    r_8th_avescore  r_8th_numtakers  m_8th_avescore  m_8th_numtakers  \
# 0          1677.0             52.0            52.0           1655.0
# 1          1698.0             94.0            76.0           1673.0
# 2          1680.0             74.0            43.0           1659.0
# 3          1702.0             27.0            27.0           1697.0
# 4          1654.0            246.0           245.0           1711.0
#
#    alg_avescore  alg_numtakers  bio_avescore  bio_numtakers  eng1_avescore  \
# 0        4254.0           43.0        4239.0           44.0         4082.0
# 1        4157.0          116.0        4030.0          113.0         3962.0
# 2        4278.0           90.0        4150.0           65.0         4033.0
# 3        3823.0           21.0        4280.0           20.0         4054.0
# 4        4062.0          240.0        4001.0          258.0         3781.0
#
#    eng1_numtakers  eng2_avescore  eng2_numtakers  us_avescore  us_numtakers
# 0            47.0         3962.0            37.0       4172.0          46.0
# 1           129.0         4029.0           100.0       4542.0          81.0
# 2            67.0         3944.0            63.0       4111.0          60.0
# 3            22.0         4165.0            34.0       4131.0          25.0
# 4           336.0         3896.0           305.0       4086.0         222.0

# %% [markdown]
# # Merge

# %%
descriptives = ddem.merge(dref, on = 'district', how = 'inner')
print("There is perfect overlap between ddem and dref. New dataset contains ", len(descriptives), " districts.")
# Out:
# There is perfect overlap between ddem and dref. New dataset contains  1203  districts.

# %%
descriptives = descriptives.merge(dscores, on = 'district', how = 'left', indicator = True)
descriptives = descriptives.dropna(how='all')
print(len(descriptives))
# Out:
# 1203

# %%
print('Some charter/specialty schools do not have any test scores. We can drop these from the dataset.')
descriptives.distname[descriptives._merge == 'left_only']
# Out:
# Some charter/specialty schools do not have any test scores. We can drop these from the dataset.
# 62     SAN ANTONIO SCHOOL FOR INQUIRY & C
# 258                FOCUS LEARNING ACADEMY
# 265                  ALPHA CHARTER SCHOOL
# 499    HOUSTON HEIGHTS LEARNING ACADEMY I
# 508                  ZOE LEARNING ACADEMY
# 517               GLOBAL LEARNING VILLAGE
# 519                       C O R E ACADEMY
# Name: distname, dtype: object

# %%
print('All schools with test scores have demographic and basic information')
descriptives.distname[descriptives._merge == 'right_only']
# Out:
# All schools with test scores have demographic and basic information
# Series([], Name: distname, dtype: object)

# %%
descriptives = descriptives[descriptives._merge != 'right_only']

# %% [markdown]
# # Descriptives of Missing Data

# %%
missing_elem_tests = []
elem_tests = [descriptives.r_3rd_avescore, descriptives.m_3rd_avescore,
              descriptives.r_4th_avescore, descriptives.m_4th_avescore,
             descriptives.r_5th_avescore, descriptives.m_5th_avescore,
             descriptives.r_6th_avescore, descriptives.m_6th_avescore]
for test in elem_tests:
    for district in list(descriptives.distname[test.isnull() == True]):
        if district not in missing_elem_tests: #add unique districts
            missing_elem_tests.append(district)
print(len(missing_elem_tests), 'districts missing elementary test scores.')
missing_elem_tests
# Out:
# 79 districts missing elementary test scores.
# ['RICHARD MILBURN ALTER HIGH SCHOOL',
#  'POR VIDA ACADEMY',
#  'POSITIVE SOLUTIONS CHARTER SCHOOL',
#  'SAN ANTONIO SCHOOL FOR INQUIRY & C',
#  'HENRY FORD ACADEMY ALAMEDA SCHOOL',
#  'CARPE DIEM SCHOOLS',
#  'MORGAN ISD',
#  'SAN VICENTE ISD',
#  'SOUTH TEXAS ISD',
#  'TRINITY CHARTER SCHOOL',
#  'TEXANS CAN ACADEMIES',
#  'ACADEMY FOR ACADEMIC EXCELLENCE',
#  'FOCUS LEARNING ACADEMY',
#  'WINFREE ACADEMY CHARTER SCHOOLS',
#  'ALPHA CHARTER SCHOOL',
#  'EVOLUTION ACADEMY CHARTER SCHOOL',
#  'RICHLAND COLLEGIATE HIGH SCHOOL',
#  'PIONEER TECHNOLOGY & ARTS ACADEMY',
#  'RAMIREZ CSD',
#  'PASO DEL NORTE ACADEMY CHARTER DIS',
#  'EL PASO ACADEMY',
#  'EL PASO LEADERSHIP ACADEMY',
#  'PREMIER HIGH SCHOOLS',
#  'ERATH EXCELS ACADEMY INC',
#  'DOSS CONSOLIDATED CSD',
#  'EAST TEXAS CHARTER SCHOOLS',
#  'GEORGE I SANCHEZ CHARTER',
#  'EXCEL ACADEMY',
#  'HOUSTON HEIGHTS HIGH SCHOOL',
#  'HOUSTON HEIGHTS LEARNING ACADEMY I',
#  'CALVIN NELMS CHARTER SCHOOLS',
#  'COMQUEST ACADEMY',
#  'YES PREP PUBLIC SCHOOLS INC',
#  'ZOE LEARNING ACADEMY',
#  'THE LAWSON ACADEMY',
#  'GLOBAL LEARNING VILLAGE',
#  'C O R E ACADEMY',
#  'A+ UNLIMITED POTENTIAL',
#  'KATHERINE ANNE PORTER SCHOOL',
#  'MIDVALLEY ACADEMY CHARTER DISTRICT',
#  'DELL CITY ISD',
#  'VALENTINE ISD',
#  'KAUFFMAN LEADERSHIP ACADEMY',
#  'LUEDERS-AVOCA ISD',
#  'DIVIDE ISD',
#  'SOUTH PLAINS ACADEMY CHARTER DISTR',
#  'PRIDDY ISD',
#  'GOLD BURG ISD',
#  'PANOLA CHARTER SCHOOL',
#  'CROSSTIMBERS ACADEMY',
#  'MORAN ISD',
#  'AUSTIN ACHIEVE PUBLIC SCHOOLS',
#  'THE EXCEL CENTER (FOR ADULTS)',
#  'THE EXCEL CENTER',
#  'RANCH ACADEMY',
#  'RAVEN SCHOOL',
#  'GATEWAY ACADEMY CHARTER DISTRICT',
#  'MARATHON ISD',
#  'LUMIN EDUCATION',
#  'TRINITY ENVIRONMENTAL ACADEMY',
#  'BOB HOPE SCHOOL',
#  'NOVA ACADEMY',
#  'TEXHOMA ISD',
#  'MALTA ISD',
#  'WALNUT BEND ISD',
#  'SIVELLS BEND ISD',
#  'UNIVERSITY OF HOUSTON CHARTER SCHO',
#  'ACADEMY OF ACCELERATED LEARNING IN',
#  'ALIEF MONTESSORI COMMUNITY SCHOOL',
#  'TWO DIMENSIONS PREPARATORY ACADEMY',
#  'SPRING CREEK ISD',
#  'WACO CHARTER SCHOOL',
#  'STEPHEN F AUSTIN STATE UNIVERSITY',
#  'BLACKWELL CISD',
#  'EAST FORT WORTH MONTESSORI ACADEMY',
#  'CHAPEL HILL ACADEMY',
#  'UNIVERSITY OF TEXAS ELEMENTARY CHA',
#  'NURSERY ISD',
#  'KELTON ISD']

# %%
missing_hs_tests = []
if year in ['yr1112', 'yr1214']:
    hs_tests = [descriptives.alg_avescore, descriptives.bio_avescore,
                  descriptives.eng1_avescore, descriptives.eng2_avescore,
                 descriptives.us_avescore]    
else:
    hs_tests = [descriptives.alg_avescore, descriptives.bio_avescore,
                  descriptives.eng1_avescore, descriptives.eng2_avescore,
                 descriptives.us_avescore]
for test in hs_tests:
    for district in list(descriptives.distname[test.isnull() == True]):
        if district not in missing_hs_tests: #add unique districts
            missing_hs_tests.append(district)
print(len(missing_hs_tests), 'districts missing hs test scores')
missing_hs_tests
# Out:
# 160 districts missing hs test scores
# ["ST MARY'S ACADEMY CHARTER SCHOOL",
#  'PAWNEE ISD',
#  'BEXAR COUNTY ACADEMY',
#  'SAN ANTONIO SCHOOL FOR INQUIRY & C',
#  'LIGHTHOUSE CHARTER SCHOOL',
#  'MALTA ISD',
#  'HUBBARD ISD',
#  'LEARY ISD',
#  'BRAZOS SCHOOL FOR INQUIRY & CREATI',
#  'ARROW ACADEMY',
#  'SAN VICENTE ISD',
#  'GROOM ISD',
#  'WALNUT BEND ISD',
#  'SIVELLS BEND ISD',
#  'LUMIN EDUCATION',
#  'NOVA ACADEMY',
#  'ACADEMY OF DALLAS',
#  'FOCUS LEARNING ACADEMY',
#  'JEAN MASSIEU ACADEMY',
#  'NOVA ACADEMY (SOUTHEAST)',
#  'ALPHA CHARTER SCHOOL',
#  'EDUCATION CENTER INTERNATIONAL ACA',
#  'GOLDEN RULE CHARTER SCHOOL',
#  'ST ANTHONY SCHOOL',
#  'RICHLAND COLLEGIATE HIGH SCHOOL',
#  'CITYSCAPE SCHOOLS',
#  'TRINITY ENVIRONMENTAL ACADEMY',
#  'DAWSON ISD',
#  'WALCOTT ISD',
#  'NORTH TEXAS COLLEGIATE ACADEMY',
#  'TRIVIUM ACADEMY',
#  'WESTHOFF ISD',
#  'MEYERSVILLE ISD',
#  'RAMIREZ CSD',
#  'COMPASS ACADEMY CHARTER SCHOOL',
#  'LA FE PREPARATORY SCHOOL',
#  'VISTA DEL FUTURO CHARTER SCHOOL',
#  'DOSS CONSOLIDATED CSD',
#  'GRANDVIEW-HOPKINS ISD',
#  'PRINGLE-MORSE CISD',
#  'UNIVERSITY OF HOUSTON CHARTER SCHO',
#  'ACADEMY OF ACCELERATED LEARNING IN',
#  'THE VARNETT PUBLIC SCHOOL',
#  'ALIEF MONTESSORI COMMUNITY SCHOOL',
#  'HOUSTON HEIGHTS LEARNING ACADEMY I',
#  'TWO DIMENSIONS PREPARATORY ACADEMY',
#  'BEATRICE MAYES INSTITUTE CHARTER S',
#  'ACCELERATED INTERMEDIATE ACADEMY',
#  'ZOE LEARNING ACADEMY',
#  'PROMISE COMMUNITY SCHOOL',
#  'MEYERPARK ELEMENTARY',
#  'DRAW ACADEMY',
#  'THE RHODES SCHOOL',
#  'THE LAWSON ACADEMY',
#  'GLOBAL LEARNING VILLAGE',
#  'C O R E ACADEMY',
#  'BETA ACADEMY',
#  'A+ UNLIMITED POTENTIAL',
#  'KARNACK ISD',
#  'TEXAS PREPARATORY SCHOOL',
#  'MURCHISON ISD',
#  'HORIZON MONTESSORI PUBLIC SCHOOLS',
#  'EXCELLENCE IN LEADERSHIP ACADEMY',
#  'MALONE ISD',
#  'SPRING CREEK ISD',
#  'VALENTINE ISD',
#  'EHRHART SCHOOL',
#  'LA GLORIA ISD',
#  'KENEDY COUNTY WIDE CSD',
#  'DIVIDE ISD',
#  'BENJAMIN ISD',
#  'VYSEHRAD ISD',
#  'EZZELL ISD',
#  'DARROUZETT ISD',
#  'RISE ACADEMY',
#  'MATAGORDA ISD',
#  'WACO CHARTER SCHOOL',
#  'HALLSBURG ISD',
#  'MIDLAND ACADEMY CHARTER SCHOOL',
#  'GAUSE ISD',
#  'MONTAGUE ISD',
#  'TEXAS SERENITY ACADEMY',
#  'STEPHEN F AUSTIN STATE UNIVERSITY',
#  'ETOILE ISD',
#  'PALO PINTO ISD',
#  'EXCELSIOR ISD',
#  'TEXHOMA ISD',
#  'EAST FORT WORTH MONTESSORI ACADEMY',
#  'TEXAS SCHOOL OF THE ARTS',
#  'CHAPEL HILL ACADEMY',
#  'UNIVERSITY OF TEXAS ELEMENTARY CHA',
#  'AUSTIN DISCOVERY SCHOOL',
#  'MONTESSORI FOR ALL',
#  'NURSERY ISD',
#  'KELTON ISD',
#  'SEYMOUR ISD',
#  'ELEANOR KOLITZ HEBREW LANGUAGE ACA',
#  'REDWATER ISD',
#  'RED LICK ISD',
#  'SILVERTON ISD',
#  'TRINITY BASIN PREPARATORY',
#  'A W BROWN-FELLOWSHIP LEADERSHIP AC',
#  'KIPP DALLAS-FORT WORTH',
#  'LA ACADEMIA DE ESTRELLAS',
#  'HEDLEY ISD',
#  'NUECES CANYON CISD',
#  'EL PASO LEADERSHIP ACADEMY',
#  'MORGAN MILL ISD',
#  'WESTPHALIA ISD',
#  'DEW ISD',
#  'AMBASSADORS PREPARATORY ACADEMY',
#  'HIGH ISLAND ISD',
#  'SER-NINOS CHARTER SCHOOL',
#  'AMIGOS POR VIDA-FRIENDS FOR LIFE P',
#  'STEP CHARTER SCHOOL',
#  'MOUNT CALM ISD',
#  'DELL CITY ISD',
#  'HUNT ISD',
#  'RICARDO ISD',
#  'SWEET HOME ISD',
#  'DEVERS ISD',
#  'PRIDDY ISD',
#  'DR M L GARZA-GONZALEZ CHARTER SCHO',
#  'CORPUS CHRISTI MONTESSORI SCHOOL',
#  'SEASHORE CHARTER SCHOOLS',
#  'DRISCOLL ISD',
#  'GORDON ISD',
#  'OLFEN ISD',
#  'WINFIELD ISD',
#  'HARTS BLUFF ISD',
#  'KIPP AUSTIN PUBLIC SCHOOLS INC',
#  'CENTERVILLE ISD',
#  'COUPLAND ISD',
#  'MARATHON ISD',
#  'GARNER ISD',
#  'THE EXCEL CENTER (FOR ADULTS)',
#  'MORGAN ISD',
#  'PIONEER TECHNOLOGY & ARTS ACADEMY',
#  'UTPB STEM ACADEMY',
#  'THREE WAY ISD',
#  'PAINT CREEK ISD',
#  'WILDORADO ISD',
#  'ARLINGTON CLASSICS ACADEMY',
#  'TEXAS EMPOWERMENT ACADEMY',
#  'DAMON ISD',
#  'HART ISD',
#  'SANTA ANNA ISD',
#  'FANNINDEL ISD',
#  'LEADERSHIP PREP SCHOOL',
#  'PATTON SPRINGS ISD',
#  'CROWELL ISD',
#  'GUTHRIE CSD',
#  "O'DONNELL ISD",
#  'WILSON ISD',
#  'ROCHELLE ISD',
#  'LOHN ISD',
#  'FORESTBURG ISD',
#  'LAZBUDDIE ISD',
#  'SONORA ISD',
#  'HIGH POINT ACADEMY']

# %%
missing_both = [value for value in missing_elem_tests 
                if value in missing_hs_tests] 
print(len(missing_both), 'districts missing elem and hs test scores')
print('of these', 
      len(descriptives[descriptives.distname.isin(missing_both)]
         [descriptives.distischarter == 'Y']),
      'are charters.')
# Out:
# 41 districts missing elem and hs test scores
# of these 25 are charters.
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
