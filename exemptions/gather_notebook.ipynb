# %%
import gather
import os

# %%
# List of seed links found on TEA website
tea_url = 'https://tea.texas.gov/Texas_Schools/District_Initiatives/Districts_of_Innovation/'

# %% [markdown]
# ## Scratch

# %% [markdown]
# ## First Level Links

# %%
first_level_links = gather.FirstLevelLinks(tea_url, print_interim = False)
first_level_links_df = first_level_links.docs_df
first_level_links_df['level'] = "First"
first_level_links_df.tail()
# Out:
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/kylieleblancKylie/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#                                                              link type  level
# Carlisle ISD    https://s3.amazonaws.com/scschoolfiles/83/carl...  pdf  First
# Lewisville ISD  https://www.lisd.net/cms/lib/TX01918037/Centri...  pdf  First
# Prosper ISD     http://www.prosper-isd.net/cms/lib5/TX01918217...  pdf  First
# Redwater ISD    https://s3.amazonaws.com/scschoolfiles/757/dis...  pdf  First
# Judson ISD      https://www.judsonisd.org/district/documents/J...  pdf  First

# %% [markdown]
# ## Second Level Links

# %%
seed_links = gather.SeedLinks(tea_url, print_interim = False).seed_links
seed_links
test_set = {v:seed_links[v] for v in [list(seed_links.keys())[k] for k in range(2)]}
# Out:
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/kylieleblancKylie/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
len(test_set)
# Out:
# 2

# %%
second_level_links = gather.SecondLevelLinks(test_set)
# Out:
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/kylieleblancKylie/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0272bf1507ec> in <module>()
# ----> 1 second_level_links = gather.SecondLevelLinks(test_set)
#
# ~/dofis/code/exemptions/gather.py in __init__(self, titles_urls)
#     203         self.doc_links = {}
#     204         self.crawl(titles_urls=titles_urls)
# --> 205         self.make_df()
#     206
#     207     def make_df(self):
#
# ~/dofis/code/exemptions/gather.py in make_df(self)
#     211         docs_df = docs_df.reset_index()
#     212         docs_df = docs_df.rename(columns={"index": "link"})
# --> 213         docs_df = docs_df.drop(['level_0'])
#     214         docs_df = docs_df.set_index('title')
#     215
#
# ~/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4386             if errors != 'ignore':
#    4387                 raise KeyError(
# -> 4388                     'labels %s not contained in axis' % labels[mask])
#    4389             indexer = indexer[~mask]
#    4390         return self.delete(indexer)
#
# KeyError: "labels ['level_0'] not contained in axis"

# %%
second_level_links.doc_links
# Out:
# {'https://www.austinisd.org/sites/default/files/dept/about-us/docs/AISD_2017-2018_FACT_SHEET_rev_010317.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/about-us/docs/DISTRICT_VISION_CORE_BELIEFS_AND_VALUE.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/default/docs/flyers/AISD_Anti-harassment_statementv2.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/default/docs/flyers/AISD_Org_Chart_2018-2019.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/idac/docs/IDAC_Charter_Final.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/idac/docs/IDAC_Membership_Website.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/ina/Austin_ISD_District_of_Innovation_Plan_Final_rev18.06.18.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/ina/DOI_Days_2018-19_Full_List_v8_By_Campus.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/ina/DOI_Days_2018-19_v8_By_Date.pdf': ('Austin ISD',
#   'pdf'),
#  'https://www.austinisd.org/sites/default/files/dept/technology/docs/AU_Guidelines_05.23.18_updated.pdf': ('Austin ISD',
#   'pdf')}

# %%
second_level_links.docs_df
# Out:
#                                                 link       title type
# 0  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 1  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 2  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 3  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 4  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 5  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 6  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 7  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 8  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf
# 9  https://www.austinisd.org/sites/default/files/...  Austin ISD  pdf

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(second_level_links.doc_links,
                                              orient='index',
                                              columns=['title', 'type'])

# %%
df = df.reset_index()
df
# Out:
#     level_0                                              index  \
# 0         0  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 1         1  https://www.bmtisd.com/site/handlers/filedownl...
# 2         2  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 3         3  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 4         4  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 5         5  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 6         6  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 7         7  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 8         8  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 9         9  https://www.bmtisd.com/site/handlers/filedownl...
# 10       10  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 11       11  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 12       12  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 13       13  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 14       14  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 15       15  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 16       16  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 17       17  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 18       18  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 19       19  https://www.bmtisd.com/site/handlers/filedownl...
# 20       20  https://s3.amazonaws.com/scschoolfiles/565/doi...
# 21       21  https://www.bmtisd.com/site/handlers/filedownl...
# 22       22  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 23       23  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 24       24  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 25       25  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 26       26  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 27       27  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 28       28  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 29       29  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# ..      ...                                                ...
# 36       36  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 37       37  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 38       38         https://www.irvingisd.net/drive.google.com
# 39       39  https://www.bmtisd.com/site/handlers/filedownl...
# 40       40  http://www.esc16.net/upload/page/0351/Handbook...
# 41       41  https://www.bmtisd.com/site/handlers/filedownl...
# 42       42  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 43       43  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 44       44  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 45       45  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 46       46  https://www.bmtisd.com/site/handlers/filedownl...
# 47       47  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 48       48  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 49       49  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 50       50  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 51       51  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 52       52  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 53       53  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 54       54  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 55       55  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 56       56  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 57       57  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 58       58  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 59       59  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 60       60  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 61       61  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 62       62  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 63       63  http://www.wfisd.net/cms/lib/TX01000557/Centri...
# 64       64  https://www.irvingisd.net/cms/lib/TX01917973/C...
# 65       65  http://www.wfisd.net/cms/lib/TX01000557/Centri...
#
#                 title    type
# 0   Wichita Falls ISD     pdf
# 1        Beaumont ISD     pdf
# 2   Wichita Falls ISD     pdf
# 3   Wichita Falls ISD     pdf
# 4   Wichita Falls ISD     pdf
# 5   Wichita Falls ISD     pdf
# 6   Wichita Falls ISD     pdf
# 7   Wichita Falls ISD     pdf
# 8   Wichita Falls ISD     pdf
# 9        Beaumont ISD     pdf
# 10         Irving ISD     pdf
# 11         Irving ISD     pdf
# 12         Irving ISD     pdf
# 13  Wichita Falls ISD     pdf
# 14         Irving ISD     pdf
# 15  Wichita Falls ISD     pdf
# 16         Irving ISD     pdf
# 17         Irving ISD     pdf
# 18         Irving ISD     pdf
# 19       Beaumont ISD     pdf
# 20     Tarkington ISD     pdf
# 21       Beaumont ISD     pdf
# 22  Wichita Falls ISD     pdf
# 23  Wichita Falls ISD     pdf
# 24  Wichita Falls ISD     pdf
# 25         Irving ISD     pdf
# 26         Irving ISD     pdf
# 27  Wichita Falls ISD     pdf
# 28  Wichita Falls ISD     pdf
# 29  Wichita Falls ISD     pdf
# ..                ...     ...
# 36  Wichita Falls ISD     pdf
# 37  Wichita Falls ISD     pdf
# 38         Irving ISD  google
# 39       Beaumont ISD     pdf
# 40  Wichita Falls ISD     pdf
# 41       Beaumont ISD     pdf
# 42  Wichita Falls ISD     pdf
# 43  Wichita Falls ISD     pdf
# 44         Irving ISD     pdf
# 45  Wichita Falls ISD     pdf
# 46       Beaumont ISD     pdf
# 47  Wichita Falls ISD     pdf
# 48  Wichita Falls ISD     pdf
# 49         Irving ISD     pdf
# 50  Wichita Falls ISD     pdf
# 51  Wichita Falls ISD     pdf
# 52         Irving ISD     pdf
# 53  Wichita Falls ISD     pdf
# 54  Wichita Falls ISD     pdf
# 55         Irving ISD     pdf
# 56  Wichita Falls ISD     pdf
# 57  Wichita Falls ISD     pdf
# 58  Wichita Falls ISD     pdf
# 59         Irving ISD     pdf
# 60  Wichita Falls ISD     pdf
# 61         Irving ISD     pdf
# 62  Wichita Falls ISD     pdf
# 63  Wichita Falls ISD     pdf
# 64         Irving ISD     pdf
# 65  Wichita Falls ISD     pdf
#
# [66 rows x 4 columns]
