# %%
import os
import pandas as pd
import extract_dates
import spacy
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %%
docs = pd.read_csv(os.path.join(os.getcwd(), '..', '..', 'data', 'text_narrowed.csv'))

# %%
test_docs = docs[100:105]
test_docs.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                title   level  \
# 100          98            98              98           Sunray ISD   First
# 101        3331          3331            3331        Sunnyvale ISD  Second
# 102         252           252             252          Sundown ISD   First
# 103        1140          1140            1140  Sulphur Springs ISD  Second
# 104         306           306             306    Sulphur Bluff ISD   First
#
#     type                                               link  \
# 100  pdf  https://1.cdn.edl.io/Rb3eNoIDEma2NVfd5LdmKpqLB...
# 101  pdf  http://www.sunnyvaleisd.com/site/handlers/file...
# 102  pdf  https://www.sundownisd.com/UserFiles/Servers/S...
# 103  pdf  http://www.ssisd.net/upload/page/0041/docs/Inn...
# 104  pdf  https://s3.amazonaws.com/scschoolfiles/837/sul...
#
#                                                   text  p_innovation
# 100  SUNRAY ISD District of Innovation Plan 2 Distr...      0.999829
# ...

# %%
output_dir = os.path.join(os.getcwd(), '..', '..', 'data', 'date_term_classifier')
nlp = spacy.load(output_dir)

# %%
start_dates = []
start_date_phrases = []
for text in test_docs.text:
    dates, phrases = extract_dates.get_date_phrase_list(text)
    cats = []
    for phrase in phrases:
        doc = nlp(phrase)
        cats.append(doc.cats)
    p_cat = extract_dates.get_max_p_from_dict_list(cats)
    if p_cat != -999:
        start_dates.append(dates[p_cat])
        start_date_phrases.append(phrases[p_cat])
    if p_cat == -999:
        start_dates.append('')
        start_date_phrases.append('')
    #p_cats.append(extract_dates.get_max_p_from_dict_list(cats))
# Out:
# SUNRAY
# ISD
# District
# of
# Innovation
# Plan
# 2
# District
# of
# Innovation
# Plan
# Table
# of
# Contents
# Introduction
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# Local
# Guidelines
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# Timeline
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# 4
# Term
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# Uniform
# School
# Start
# Date
# -
# Calendar
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# 5
# Contract
# Service
# Days
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# 5
# Teacher
# Certification
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# 6
# Contract
# Service
# Days
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# …
# District
# of
# Innovation
# Committee
# Members
# ...

# %%
start_dates
# Out:
# ['2017', '2017', '', '1842', '2022']

# %%
start_date_phrases
# Out:
# ['for five years, beginning April 27, 2017, and ending April 27,',
#  'years. The plan will begin Spring, 2017 and conclude Spring, 2022,',
#  '',
#  'as an exercise of the provisions of HB 1842, allows our SSISD Board of',
#  '2017-2018 School Year To 2021-2022 School Year INTRODUCTION House Bill 1842']

# %%
cats = []
for phrase in phrases:
    doc = nlp(phrase)
    cats.append(doc.cats)

# %%
cats
# Out:
# [{'TERM': 6.0811653384007514e-05},
#  {'TERM': 0.000637462770100683},
#  {'TERM': 0.7496848702430725},
#  {'TERM': 4.539787187241018e-05},
#  {'TERM': 4.539787187241018e-05},
#  {'TERM': 4.977573189535178e-05},
#  {'TERM': 0.9284722805023193},
#  {'TERM': 0.001019663061015308},
#  {'TERM': 0.0009384191362187266},
#  {'TERM': 0.00018428766634315252},
#  {'TERM': 0.0014342749491333961},
#  {'TERM': 0.0025924709625542164},
#  {'TERM': 0.9989855885505676},
#  {'TERM': 0.006762371398508549}]

# %%
phrases
# Out:
# ['Dec. 13, 2016 – Dec. 13, 2021 2 What is a District of',
#  'by the 84th Legislative Session in House Bill 1842 and has been codified in the',
#  'suits the district’s needs. Under HB 1842, districts may identify certain requirements',
#  '’s Innovation Plan? On September 20, 2016, the Lake Travis ISD’s',
#  'hold a public meeting on December 13, 2016 to consider and vote on the',
#  'final proposed plan during the December 13, 2016 board meeting. If two-',
#  'the date of adoption (December 13, 2016 – December 13, 2021)',
#  'December 13, 2016 – December 13, 2021). The District of Innovation',
#  'System (PDAS) teacher appraisal system since 1997. Beginning with the 2016-',
#  'appraisal system since 1997. Beginning with the 2016-2017 school year, the',
#  'since 1997. Beginning with the 2016-2017 school year, the state has',
#  'circumstances that are locally established. Starting the 2017-2018 school year, a',
# ...

# %%
test_docs.text.values
# Out:
# array(['Effective Dec. 13, 2016 – Dec. 13, 2021 2 What is a District of Innovation? The District of Innovation concept was passed by the 84th Legislative Session in House Bill 1842 and has been codified in the Texas Education Code Chapter 12a. A District of Innovation designation gives traditional school districts most of the flexibility currently available to Texas’ open-enrollment charter schools. It gives a district more local control and increases a district’s ability to decide what best suits the district’s needs. Under HB 1842, districts may identify certain requirements imposed by the Texas Education Code “that inhibit the goals of the plan and from which the district should exempt on adoption of the plan.” What are the benefits to Lake Travis ISD becoming a District of Innovation? A District of Innovation will have the flexibility to implement practices similar to charter schools and exercise local control over certain decisions about education and governance that are more ap
# ...
