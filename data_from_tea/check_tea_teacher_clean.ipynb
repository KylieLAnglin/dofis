# %%
import pandas as pd
import os
from library import start

# %%
file = 'teacher_cert_yr1718.csv'
certification = pd.read_csv(os.path.join(start.data_path, 'tea', 'teachers', file),
                           low_memory=False)

# %%
file = 'teacher_course_yr1718.csv'
assignments = pd.read_csv(os.path.join(start.data_path, 'tea', 'teachers', file))

# %%
assignments[assignments.teacher_id == 'Q3Q2QF*48']
# Out:
#         Unnamed: 0 teacher_id  district   campus  campus_elem  campus_middle  \
# 134944          24  Q3Q2QF*48      1902  1902001        False          False
#
#         campus_high  course_ela  course_elem  course_math  course_science  \
# 134944         True       False        False         True           False
#
#         course_cte
# 134944       False

# %%
certification[certification.teacher_id == 'Q3Q2QF*48']
# Out:
#        teacher_id  district  certification  vocational  cert_elem  \
# 362864  Q3Q2QF*48      1902           True       False       True
#
#         cert_middle  cert_high  cert_area_elem  cert_area_ela  cert_area_math  \
# 362864         True       True            True          False           False
#
#         cert_area_sci  cert_area_voc  cert_secondary_ela  cert_secondary_math  \
# 362864          False           True               False                False
#
#         cert_secondary_sci
# 362864               False

# %%
certification.cert_elem.value_counts()
# Out:
# True     284890
# False    236984
# Name: cert_elem, dtype: int64

# %%
teachers = assignments.merge(certification, on = ['teacher_id', 'district'], how = 'left', indicator = '_merge')
teachers[teachers.teacher_id == 'Q3Q2QF*48']
# Out:
#         Unnamed: 0 teacher_id  district   campus  campus_elem  campus_middle  \
# 134944          24  Q3Q2QF*48      1902  1902001        False          False
#
#         campus_high  course_ela  course_elem  course_math  ...  cert_high  \
# 134944         True       False        False         True  ...       True
#
#         cert_area_elem cert_area_ela cert_area_math cert_area_sci  \
# 134944            True         False          False         False
#
#        cert_area_voc cert_secondary_ela cert_secondary_math  \
# 134944          True              False               False
#
#        cert_secondary_sci _merge
# 134944              False   both
#
# [1 rows x 26 columns]

# %%
teachers[teachers.teacher_id == '*3106V240']
# Out:
#    Unnamed: 0 teacher_id  district    campus  campus_elem  campus_middle  \
# 3           3  *3106V240     31901  31901129         True          False
#
#    campus_high  course_ela  course_elem  course_math  ...  cert_high  \
# 3        False       False        False        False  ...       True
#
#    cert_area_elem cert_area_ela cert_area_math cert_area_sci cert_area_voc  \
# 3           False         False          False         False         False
#
#   cert_secondary_ela cert_secondary_math cert_secondary_sci _merge
# 3              False               False              False   both
#
# [1 rows x 26 columns]

# %%
teachers[teachers.certification == False]
# Out:
#         Unnamed: 0 teacher_id  district     campus  campus_elem  \
# 3                3  *3106V240     31901   31901129         True
# 16              16  *3305F547     31901   31901105         True
# 40              40  *35*3*P36     31901   31901007        False
# 127            127  *372QY144     31901   31901135         True
# 152            152  *37V50023     31901   31901009        False
# ...            ...        ...       ...        ...          ...
# 361739       31093  F35411035    247904  247904001        False
# 361740       31094  P3403Y133    247904  247904001        False
# 361882       31236  231261449    254901  254901106         True
# 361895       31249  D3752V*41    254901  254901001        False
# 361916       31270  Q3230D531    254901  254901106         True
#
#         campus_middle  campus_high  course_ela  course_elem  course_math  ...  \
# 3               False        False       False        False        False  ...
# 16              False        False       False         True        False  ...
# 40              False         True       False        False        False  ...
# 127             False        False       False         True        False  ...
# 152             False         True       False        False        False  ...
# ...               ...          ...         ...          ...          ...  ...
# 361739          False         True       False        False        False  ...
# 361740          False         True       False        False        False  ...
# 361882          False        False        True        False        False  ...
# 361895          False         True       False        False         True  ...
# 361916          False        False       False        False         True  ...
#
#         cert_high  cert_area_elem cert_area_ela cert_area_math cert_area_sci  \
# 3            True           False         False          False         False
# 16           True           False         False          False         False
# 40           True           False         False          False         False
# 127          True           False         False          False         False
# 152          True           False         False          False         False
# ...           ...             ...           ...            ...           ...
# 361739       True           False         False          False         False
# 361740       True           False         False          False         False
# 361882       True           False         False          False         False
# 361895       True           False         False          False         False
# 361916       True           False         False          False         False
#
#        cert_area_voc cert_secondary_ela cert_secondary_math  \
# 3              False              False               False
# 16             False              False               False
# 40             False              False               False
# 127            False              False               False
# 152            False              False               False
# ...              ...                ...                 ...
# 361739         False              False               False
# 361740         False              False               False
# 361882         False              False               False
# 361895         False              False               False
# 361916         False              False               False
#
#        cert_secondary_sci _merge
# 3                   False   both
# 16                  False   both
# 40                  False   both
# 127                 False   both
# 152                 False   both
# ...                   ...    ...
# 361739              False   both
# 361740              False   both
# 361882              False   both
# 361895              False   both
# 361916              False   both
#
# [2686 rows x 26 columns]

# %%
teachers.cert_elem.value_counts()
# Out:
# True     235989
# False    117585
# Name: cert_elem, dtype: int64

# %%
teachers['certification'] = teachers.certification.astype(bool)
teachers['vocational'] = teachers.vocational.astype(bool)
teachers['cert_elem'] = teachers.cert_elem.astype(bool)
teachers['cert_middle'] = teachers.cert_middle.astype(bool)
teachers['cert_high'] = teachers.cert_high.astype(bool)
teachers['cert_area_elem'] = teachers.cert_area_elem.astype(bool)
teachers['cert_area_ela'] = teachers.cert_area_ela.astype(bool)
teachers['cert_area_math'] = teachers.cert_area_math.astype(bool)
teachers['cert_area_sci'] = teachers.cert_area_sci.astype(bool)
teachers['cert_area_voc'] = teachers.cert_area_voc.astype(bool)
teachers['cert_secondary_ela'] = teachers.cert_secondary_ela.astype(bool)
teachers['cert_secondary_sci'] = teachers.cert_secondary_sci.astype(bool)
teachers['cert_secondary_math'] = teachers.cert_secondary_math.astype(bool)

# %%
teachers._merge.value_counts()
# Out:
# both          353574
# left_only       8439
# right_only         0
# Name: _merge, dtype: int64

# %%
any_cert = teachers[['district', 'certification']]
any_cert = any_cert.groupby(['district']).mean()

any_cert.sample(10)
# Out:
#           certification
# district
# 145902         1.000000
# 57906          0.971599
# 57835          1.000000
# 60914          1.000000
# 1904           0.966667
# 5902           1.000000
# 252902         1.000000
# 148903         1.000000
# 61903          1.000000
# 20904          1.000000

# %%
elem = teachers[(teachers.course_ela == True)]
elem = elem[(elem.campus_elem == True)]
elem = elem.groupby(['district']).mean()
elem = elem[['cert_area_elem']]
elem.sample(10)
# Out:
#           cert_area_elem
# district
# 108802          0.595238
# 161906          0.775862
# 107901          0.809524
# 109911          0.818182
# 152901          0.820388
# 1907            0.698113
# 7901            1.000000
# 3903            0.843750
# 81906           1.000000
# 57914           0.762619

# %%
high_math = teachers[(teachers.course_math == True)]
high_math = high_math[(high_math.campus_high == True) | (high_math.campus_middle == True)]
high_math[high_math.campus == 1902001]
high_math = high_math.groupby(['district']).mean()
high_math = high_math[['cert_secondary_math']]
high_math.sample(10)
# Out:
#           cert_secondary_math
# district
# 20908                0.446970
# 32902                0.388889
# 43917                0.428571
# 143901               0.600000
# 139911               0.285714
# 3907                 0.428571
# 209901               0.428571
# 70910                0.555556
# 108916               0.538462
# 20902                0.485714

# %%
high_sci = teachers[(teachers.course_science == True)]
high_sci = high_sci[(high_sci.campus_high == True)]
high_sci = high_sci.groupby(['district']).mean()
high_sci = high_sci[['cert_secondary_sci']]
high_sci.sample(10)
# Out:
#           cert_secondary_sci
# district
# 134901              0.666667
# 15826               1.000000
# 168901              0.750000
# 240904              1.000000
# 18904               0.400000
# 61905               0.857143
# 234905              0.500000
# 16901               1.000000
# 152909              0.800000
# 178908              0.800000

# %%
high_ela = teachers[(teachers.course_ela == True)]
high_ela = high_ela[(high_ela.campus_high == True)]
high_ela = high_ela.groupby(['district']).mean()
high_ela = high_ela[['cert_secondary_ela']]
high_ela.sample(10)
# Out:
#           cert_secondary_ela
# district
# 47902               0.375000
# 220910              0.923077
# 140908              0.666667
# 158906              0.600000
# 220907              0.809160
# 19906               0.833333
# 59901               0.750000
# 57829               0.600000
# 43908               0.714286
# 10902               0.800000

# %%
cte = teachers[(teachers.course_cte == True)]
cte = cte[(cte.campus_elem == True)]
cte = cte.groupby(['district']).mean()
cte = cte[['cert_area_voc']]
cte.sample(10)
# Out:
#           cert_area_voc
# district
# 15827          0.666667
# 184911         0.000000
# 101919         0.000000
# 15831          0.666667
# 101847         0.000000
# 61914          0.666667
# 57827          1.000000
# 246914         0.000000
# 101868         1.000000
# 165802         1.000000

# %%
all_certs = any_cert.merge(elem, on = 'district', how = 'left')
all_certs = all_certs.merge(high_math, on = 'district', how = 'left')
all_certs = all_certs.merge(high_ela, on = 'district', how = 'left')
all_certs = all_certs.merge(high_sci, on = 'district', how = 'left')
all_certs = all_certs.merge(cte, on = 'district', how = 'left', indicator = '_merge')
all_certs._merge.value_counts()
# Out:
# left_only     1170
# both            29
# right_only       0
# Name: _merge, dtype: int64

# %%
all_certs.sample(10)
# Out:
#           certification  cert_area_elem  cert_secondary_math  \
# district
# 246909         0.992800        0.774270             0.468750
# 101907         0.996376        0.775546             0.529503
# 234904         1.000000        0.866667             0.666667
# 229903         0.990476        0.772727             0.363636
# 128904         1.000000        0.800000             0.500000
# 246914         1.000000        0.625000                  NaN
# 228905         0.952381        1.000000             0.666667
# 226906         1.000000        0.935484             0.500000
# 127901         1.000000        0.857143             0.625000
# 131001         1.000000        1.000000                  NaN
#
#           cert_secondary_ela  cert_secondary_sci  cert_area_voc     _merge
# district
# 246909              0.779343            0.813793            NaN  left_only
# 101907              0.804878            0.800570            NaN  left_only
# 234904              0.666667            1.000000            NaN  left_only
# 229903              0.833333            0.600000            NaN  left_only
# 128904              0.375000            0.333333            NaN  left_only
# 246914                   NaN                 NaN            0.0       both
# 228905              0.375000            1.000000            NaN  left_only
# 226906              0.750000            0.666667            NaN  left_only
# 127901              0.800000            0.600000            NaN  left_only
# 131001                   NaN                 NaN            NaN  left_only

# %%
len(elem)
# Out:
# 947

# %%
len(any_cert)
# Out:
# 1199
