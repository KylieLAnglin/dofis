# %% [markdown]
# # Address missing data

# %%
import urllib
import urllib.request
import urllib.parse
import urllib.error
import requests
from bs4 import BeautifulSoup
import csv
import os
import pandas as pd
import clean_documents
from pathlib import Path
import spacy
from spacy import displacy
from spacy.matcher import Matcher
from functools import reduce
from start import data_path
import extract_laws

# %%
docs_df = pd.read_csv(os.path.join(data_path,'doi_exemptions_scraped.csv'))

# %%
docs_df[docs_df.title == "Blum ISD"]
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 757         757           351             351               351
#
#      Unnamed: 0.1.1.1.1     title  level type  \
# 757                 351  Blum ISD  First  pdf
#
#                                                   link  \
# 757  http://blumisd.net/UserFiles/Servers/Server_77...
#
#                                                   text  p_innovation  \
# 757  BLUM Independent School District District of I...      0.999955
#
#                                          possible_laws
# 757  [11.251, 21.352, 21.3541, 21.458, 21.353, 25.1...

# %%
extract_laws.get_laws(docs_df[docs_df.title == 'Blum ISD']['text'].values[0])
# Out:
# [11.251,
#  21.451,
#  21.102,
#  21.352,
#  21.003,
#  25.113,
#  25.082,
#  25.092,
#  25.087,
#  25.083,
#  29.0821,
#  25.112,
#  28.0214,
#  25.036,
#  25.084,
#  28.0216,
#  37.0012,
#  45.206,
#  25.081,
#  21.458,
#  21.353,
#  21.354,
#  21.401,
#  21.3541,
#  25.0811]

# %% [markdown]
# ## Check TEA website for new districts of innovation

# %%
add_new_dois = False

# %%
if add_new_dois:
    url = "https://tea.texas.gov/Texas_Schools/District_Initiatives/Districts_of_Innovation/"
    webcontent = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(webcontent, 'html.parser')
    links = soup.find_all('a')
    districts_list = [i for i in map(lambda x: x.get('title'), links) 
                      if i is not None and 'ISD' in i]
    districts_df = pd.DataFrame(districts_list, columns=['title'])
    len(districts_df)
    # Make a new DataFrame from a right join on dois with list of districts
    combined_df = docs_df.merge(districts_df, how='right', left_on='title', right_on='title')

    # Save the district name and link for those districts that we don't have laws for
    missing_districts = combined_df[(combined_df['possible_laws'] == '[]')][['title', 'link']]

    print("Number of missing districts: ", len(missing_districts))
    missing_districts.head()

# %%
if add_new_dois == False: 
    # Save the district name and link for those districts that we don't have laws for
    missing_districts = docs_df[(docs_df['possible_laws'] == '[]')][['title', 'link']]
    print("Number of missing districts: ", len(missing_districts))
    missing_districts.head()
# Out:
# Number of missing districts:  276

# %%
missing_districts.head()
# Out:
#                  title                                               link
# 3    Zapata County ISD  https://1.cdn.edl.io/VZ6fi1M6pn8Qk8tS3GetGewCD...
# 5           Yoakum ISD  http://www.yoakumisd.net/cms/lib3/TX01001553/C...
# 7   Wylie ISD (221912)  http://www.wyliebulldogs.org/cms/One.aspx?port...
# 10       Woodville ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 11         Woodson ISD  https://sites.google.com/a/woodsonisd.net/wood...

# %% [markdown]
# ## Address districts that are missing due to incorrect link.

# %% [markdown]
# ### Where possible, incorporate previously (manually) collected links before editing

# %%
missing_districts = missing_districts.rename({'link': 'link_scraped'}, axis = 'columns')

# Import previous link fixes
missing_links = pd.read_csv(os.path.join(data_path, 'missing_links_corrected.csv'))
missing_links = missing_links.rename({'link': 'link_manual'}, axis = 'columns')

# merge old and new
missing_links = missing_districts.merge(missing_links, how = 'left', left_on = 'title', right_on = 'title')
print("Number of missing links", len(missing_links))

# If I haven't manually fixed the link before, show the link with the highest p(doi)
missing_links['link'] = missing_links.link_manual
missing_links['link'] = missing_links['link'].fillna(missing_links['link_scraped'])
missing_links.tail(20)
# Out:
# Number of missing links 276
#               title                                       link_scraped  \
# 256  Blue Ridge ISD                        http://brisd.net/domain/355
# 257       Bland ISD  https://drive.google.com/file/d/0B0CSbOD5Zf1md...
# 258  Blackwell CISD  https://1.cdn.edl.io/b6KPkAODsZKMJ39nycXFAs2Gj...
# 259    Benjamin ISD  https://benjamin-isd.net/wp-content/uploads/20...
# 260   Benavides ISD    http://www.benavidesisd.net/Content2/Innovation
# 261      Belton ISD  http://www.bisd.net/cms/lib02/TX01001322/Centr...
# 262    Beeville ISD  https://s3.amazonaws.com/scschoolfiles/380/bis...
# 263   Beckville ISD  https://drive.google.com/embeddedfolderview?id...
# 264   Ballinger ISD  https://4.files.edl.io/0596/11/05/18/185313-05...
# 265      Austin ISD  https://www.austinisd.org/sites/default/files/...
# 266         Arp ISD  https://drive.google.com/file/d/0B_OXt7psO2lTS...
# 267      Argyle ISD  https://1.cdn.edl.io/YCLWQn79uIhdW6uQmDaeeAt8M...
# 268     Aquilla ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 269     Anthony ISD  http://www.anthonyisd.net/assets/aisd-district...
# 270     Andrews ISD  https://drive.google.com/uc?id=0B0Ss54AnCZcKc3...
# 271     Anahuac ISD  https://sites.google.com/aisdpanthers.com/anah...
# 272    Amarillo ISD  http://www.amaisd.org/UserFiles/Servers/Server...
# 273    Alvarado ISD  http://www.alvaradoisd.net/UserFiles/Servers/S...
# 274        Alto ISD  https://resources.finalsite.net/images/v154092...
# 275       Aledo ISD  https://www.aledoisd.org/cms/lib/TX02205721/Ce...
#
#      Unnamed: 0                                        link_manual  \
# 256       258.0  https://docs.google.com/document/d/1jJw9_M2mC_...
# 257       259.0  https://drive.google.com/file/d/0B0CSbOD5Zf1md...
# 258       260.0  https://1.cdn.edl.io/b6KPkAODsZKMJ39nycXFAs2Gj...
# 259       261.0  http://www.benjaminisd.net/vimages/shared/vnew...
# 260       262.0  http://www.benavidesisd.net/userfiles/56/my%20...
# 261       263.0  http://www.bisd.net/cms/lib02/TX01001322/Centr...
# 262       264.0  https://s3.amazonaws.com/scschoolfiles/380/bis...
# 263       265.0  https://drive.google.com/file/d/1bosBi0QjvukFz...
# 264       266.0  https://4.files.edl.io/0596/11/05/18/185313-05...
# 265       267.0  https://www.austinisd.org/sites/default/files/...
# 266       268.0  https://docs.google.com/document/d/1UWcW-OIEbm...
# 267       269.0  https://1.cdn.edl.io/YCLWQn79uIhdW6uQmDaeeAt8M...
# 268       270.0  https://core-docs.s3.amazonaws.com/documents/a...
# 269       271.0  http://www.anthonyisd.net/assets/aisd-district...
# 270       272.0  https://docs.google.com/document/d/1qky8k6WxWc...
# 271       273.0  https://drive.google.com/file/d/11uTSTuAcBFTdq...
# 272       274.0  http://www.amaisd.org/UserFiles/Servers/Server...
# 273       275.0  http://www.alvaradoisd.net/UserFiles/Servers/S...
# 274       276.0  https://resources.finalsite.net/images/v154092...
# 275       277.0  https://docs.google.com/viewerng/viewer?url=ht...
#
#                                                   link
# 256  https://docs.google.com/document/d/1jJw9_M2mC_...
# 257  https://drive.google.com/file/d/0B0CSbOD5Zf1md...
# 258  https://1.cdn.edl.io/b6KPkAODsZKMJ39nycXFAs2Gj...
# 259  http://www.benjaminisd.net/vimages/shared/vnew...
# 260  http://www.benavidesisd.net/userfiles/56/my%20...
# 261  http://www.bisd.net/cms/lib02/TX01001322/Centr...
# 262  https://s3.amazonaws.com/scschoolfiles/380/bis...
# 263  https://drive.google.com/file/d/1bosBi0QjvukFz...
# 264  https://4.files.edl.io/0596/11/05/18/185313-05...
# 265  https://www.austinisd.org/sites/default/files/...
# 266  https://docs.google.com/document/d/1UWcW-OIEbm...
# 267  https://1.cdn.edl.io/YCLWQn79uIhdW6uQmDaeeAt8M...
# 268  https://core-docs.s3.amazonaws.com/documents/a...
# 269  http://www.anthonyisd.net/assets/aisd-district...
# 270  https://docs.google.com/document/d/1qky8k6WxWc...
# 271  https://drive.google.com/file/d/11uTSTuAcBFTdq...
# 272  http://www.amaisd.org/UserFiles/Servers/Server...
# 273  http://www.alvaradoisd.net/UserFiles/Servers/S...
# 274  https://resources.finalsite.net/images/v154092...
# 275  https://docs.google.com/viewerng/viewer?url=ht...

# %%
missing_links = missing_links[['title', 'link']]
missing_links.to_csv(os.path.join(data_path, 'missing_links.csv'))

# %% [markdown]
# ### Manually edit links in missing_links.csv where wrong. Save as missing_links_corrected.csv. Then upload.

# %%
missing_links = pd.read_csv(os.path.join(data_path, 'missing_links_corrected.csv'))
missing_links.tail(5)
# Out:
#      Unnamed: 0         title  \
# 273         273   Anahuac ISD
# 274         274  Amarillo ISD
# 275         275  Alvarado ISD
# 276         276      Alto ISD
# 277         277     Aledo ISD
#
#                                                   link
# 273  https://drive.google.com/file/d/11uTSTuAcBFTdq...
# 274  http://www.amaisd.org/UserFiles/Servers/Server...
# 275  http://www.alvaradoisd.net/UserFiles/Servers/S...
# 276  https://resources.finalsite.net/images/v154092...
# 277  https://docs.google.com/viewerng/viewer?url=ht...

# %% [markdown]
# ### Extract text from missing_links

# %%
texts = []
for link in missing_links.link:
    text = clean_documents.get_plain_text(link)
    texts.append(text)
# Out:
# Current link: http://www.windthorstisd.net/Uploads/50/misc/f283384.pdfqSoIFMeyfvnuo.pdfoodville_ISD_DOI_Final_Plan.pdfAREAS%20%20OF%20%20INNOVATION.pdf
# 2019-06-30 14:44:42,016 [MainThread  ] [WARNI]  Tika server returned status: 422
# error: HTTP Error 404: Not Found link: http://www.windthorstisd.net/Uploads/50/misc/f283384.pdf
# Google Error: 'd' is not in listle.com/drive/folders/0B-ALJgmFKVDFZmxBb09rRE9aQ1UiewA_iIXKU5g/edit0Plan.pdff%20Innovation/Innovation%20Plan%20House%20Bill%201842.pdfExemptions-BoardApproved.pdf
# Google Error: 'd' is not in listle.com/open?id=1kC4Rn_OgoK8K-s3kvUh4xBPTluPJdtpKtes/News/Documents/FINAL_DOI_PDF_FIle.pdf%20Plan_2017-2022_Adopted%2005.09.2017_Revised%2006.2018.docx
# Google Error: 'd' is not in listle.com/open?id=1laYeq1xQHm2ZlQxMjVbDe2V2wdcCm-qFvP75DNtJO58ataid=50425&FileName=EDGEWOOD%20ISD%20Disrtict%20of%20Innovation%2010-05-17%20FINAL.pdf139420&response-cache-control=private%2C%20max-age%3D31536000&response-content-disposition=%3Bfilename%3D%22Adopted%2520DOI%2520V2%25204-2017.pdf%22&response-content-type=application%2Fpdf&Signature=UGyLWybPWLXoHZJnUXWxZQPKFgo%3D-fac0-412d-aa4f-100af8f54f2b
# Google Error: 'd' is not in listle.com/drive/folders/0B3zKmpprcZY1OHRBcEw1d2VFcFE2E.pdfr%20Colmesneil%20ISD%20%281%29.pdff%20School%20DistrictofInnovationFINAL2.14.18.pdf
# Current link: https://docs.google.com/viewerng/viewer?url=https://www.aledoisd.org//cms/lib/TX02205721/Centricity/Domain/2005/DOI_Plan.pdfnnovation%20Plan%20(FINAL).pdf

# %%
missing_links['text'] = texts
missing_links['text'] = missing_links['text'].fillna('No text')
len(missing_links)
# Out:
# 278

# %%
missing_links = clean_documents.remove_whitespace(missing_links, text_col = 'text')
missing_links.tail(25)
# Out:
#      Unnamed: 0           title  \
# 253         253   Brownwood ISD
# 254         254  Brownfield ISD
# 255         255      Bronte ISD
# 256         256  Brazosport ISD
# 257         257       Bowie ISD
# 258         258  Blue Ridge ISD
# 259         259       Bland ISD
# 260         260  Blackwell CISD
# 261         261    Benjamin ISD
# 262         262   Benavides ISD
# 263         263      Belton ISD
# 264         264    Beeville ISD
# 265         265   Beckville ISD
# 266         266   Ballinger ISD
# 267         267      Austin ISD
# 268         268         Arp ISD
# 269         269      Argyle ISD
# 270         270     Aquilla ISD
# 271         271     Anthony ISD
# 272         272     Andrews ISD
# 273         273     Anahuac ISD
# 274         274    Amarillo ISD
# 275         275    Alvarado ISD
# 276         276        Alto ISD
# 277         277       Aledo ISD
#
#                                                   link  \
# 253  https://tx02000872.schoolwires.net//cms/lib/TX...
# 254  https://s3.amazonaws.com/scschoolfiles/1457/fi...
# 255  http://www.bronteisd.net/storage/UserFileFolde...
# 256  https://www.brazosportisd.net/UserFiles/Server...
# 257  http://bowie.esc11.net//cms/lib6/TX02218883/Ce...
# 258  https://docs.google.com/document/d/1jJw9_M2mC_...
# 259  https://drive.google.com/file/d/0B0CSbOD5Zf1md...
# 260  https://1.cdn.edl.io/b6KPkAODsZKMJ39nycXFAs2Gj...
# 261  http://www.benjaminisd.net/vimages/shared/vnew...
# 262  http://www.benavidesisd.net/userfiles/56/my%20...
# 263  http://www.bisd.net/cms/lib02/TX01001322/Centr...
# 264  https://s3.amazonaws.com/scschoolfiles/380/bis...
# 265  https://drive.google.com/file/d/1bosBi0QjvukFz...
# 266  https://4.files.edl.io/0596/11/05/18/185313-05...
# 267  https://www.austinisd.org/sites/default/files/...
# 268  https://docs.google.com/document/d/1UWcW-OIEbm...
# 269  https://1.cdn.edl.io/YCLWQn79uIhdW6uQmDaeeAt8M...
# 270  https://core-docs.s3.amazonaws.com/documents/a...
# 271  http://www.anthonyisd.net/assets/aisd-district...
# 272  https://docs.google.com/document/d/1qky8k6WxWc...
# 273  https://drive.google.com/file/d/11uTSTuAcBFTdq...
# 274  http://www.amaisd.org/UserFiles/Servers/Server...
# 275  http://www.alvaradoisd.net/UserFiles/Servers/S...
# 276  https://resources.finalsite.net/images/v154092...
# 277  https://docs.google.com/viewerng/viewer?url=ht...
#
#                                                   text
# 253  BROWNWOOD INDEPENDENT SCHOOL DISTRICT 2707 Sou...
# 254                                            No text
# 255                                            No text
# 256  Brazosport Independent School District Local I...
# 257                                            No text
# 258  Blue Ridge ISD Innovation Plan 2016-2021 HB 18...
# 259  1 | P a g e Introduction The 84th legislature ...
# 260  SCHOOL START DATE (EB LEGAL) (Texas Education ...
# 261  Page not found – Benjamin ISD About Us Welcome...
# 262                                            No text
# 263                                            No text
# 264  BISD DOI 2 | P a g e 3 | P a g e 4 | P a g e 5...
# 265  Microsoft Word - Beckville ISD District of Inn...
# 266  Microsoft Word - District of Innovation Plan.d...
# 267  Austin ISD Local Innovation Plan Austin Indepe...
# 268  Google Docs: Sign-in Sign in to continue to Do...
# 269  AISD District of Innovation Plan 2017-2022 Arg...
# 270                                            No text
# 271  District of Innovation A District of Innovatio...
# 272  Google Docs: Sign-in Sign in to continue to Do...
# 273  ANAHUAC ISD DISTRICT OF INNOVATION PLAN PROPOS...
# 274                                            No text
# 275  District of Innovation Plan (FINAL) Inspiring ...
# 276  Microsoft Word - Alto ISD DOI 17-18 final2 (1)...
# 277                              DOI_Plan.pdf Loading…

# %% [markdown]
# ### Extract laws from missing_links

# %%
missing_links['possible_laws'] = missing_links.text.apply(extract_laws.get_matches)

# %%
print('There are', len(missing_links[missing_links.text == 'No text']), 'documents without text (photocopies, most likely)')
print('There are', len(missing_links[missing_links.text == 'UNAVAILABLE']), 'documents which we cannot access')
print('An additional', len(missing_links[missing_links['possible_laws'].astype(str) == '[]'][(missing_links.text != 'No text') & (missing_links.text != 'UNAVAILABLE')]), 'documents have text but do not contain laws.')
# Out:
# There are 62 documents without text (photocopies, most likely)
# There are 1 documents which we cannot access
# An additional 67 documents have text but do not contain laws.
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %% [markdown]
# ### Save now correct observations to 'missing_links_corrected'. Save districts that are still incorrect to missing_text.

# %%
missing_links_corrected = missing_links[missing_links['possible_laws'].astype(str) != '[]']
missing_text = missing_links[missing_links['possible_laws'].astype(str) == '[]']
missing_text.head()
# Out:
#     Unnamed: 0            title  \
# 3            3    Woodville ISD
# 6            6  Wink-Loving ISD
# 7            7   Windthorst ISD
# 9            9       Willis ISD
# 10          10      Whitney ISD
#
#                                                  link  \
# 3   https://core-docs.s3.amazonaws.com/documents/a...
# 6   https://1.cdn.edl.io/vQwTZvpBxb8PX0K2KFrGbN9Y0...
# 7   http://www.windthorstisd.net/Uploads/50/misc/f...
# 9   https://tx50000123.schoolwires.net//cms/lib/TX...
# 10  https://www.whitney.k12.tx.us/cms/lib3/TX01001...
#
#                                                  text possible_laws
# 3                                             No text            []
# 6   Wink-Loving ISD WLISD - The Best in Texas: Bui...            []
# 7                                         UNAVAILABLE            []
# 9   2 Approved by WISD School Board April 12, 2017...            []
# 10                                            No text            []

# %%
len(missing_text)
# Out:
# 130

# %%
print('We have added', len(missing_links_corrected), 'districts.')
print(len(missing_text), 'are still missing.')
# Out:
# We have added 148 districts.
# 130 are still missing.

# %% [markdown]
# ## Address districts that are missing due to missing or incorrect text.

# %% [markdown]
# ### Where possible, incorporate previously (manually) collected text before editing

# %%
# save as new
missing_text_new = missing_text.rename({'text': 'text_scraped'}, axis = 'columns')
# save old
missing_text_old = pd.read_csv(os.path.join(data_path, 'missing_text_corrected.csv'), encoding='latin-1')
missing_text_old = missing_text_old.rename({'text': 'text_manual'}, axis = 'columns')

# merge new and old
missing_text = missing_text_new[['title', 'link', 'text_scraped']].merge(missing_text_old[['title', 'text_manual']], how = 'left', left_on = 'title', right_on = 'title')
print("Number of missing texts", len(missing_text))

# set text equal to text manual
missing_text['text'] = missing_text.text_manual

# replace text to text scraped if text is missing
missing_text['text'] = missing_text['text'].fillna(missing_text['text_scraped'])

missing_text = missing_text[['title', 'link', 'text']]
missing_text.to_csv(os.path.join(data_path, 'missing_text.csv'))
# Out:
# Number of missing texts 130

# %% [markdown]
# ##### Manually add correct text. If no text (photocopy), put 'No text' in cell. If you cannot find the document, put 'No document found'. Save as missing_text_corrected.csv.

# %%
missing_texts = pd.read_csv(os.path.join(data_path, 'missing_text_corrected.csv'))
missing_texts = clean_documents.remove_whitespace(missing_texts, 'text')
missing_texts.head(20)
# Out:
#     Unnamed: 0            title  \
# 0            0    Woodville ISD
# 1            1  Wink-Loving ISD
# 2            2   Windthorst ISD
# 3            3       Willis ISD
# 4            4      Whitney ISD
# 5            5   Whitharral ISD
# 6            6    White Oak ISD
# 7            7  West Sabine ISD
# 8            8         Waco ISD
# 9            9    Valentine ISD
# 10          10        Troup ISD
# 11          11     Trinidad ISD
# 12          12      Trenton ISD
# 13          13     Tornillo ISD
# 14          14    Tidehaven ISD
# 15          15    Thorndale ISD
# 16          16      Texline ISD
# 17          17       Tenaha ISD
# 18          18      Sundown ISD
# 19          19        Sudan ISD
#
#                                                  link  \
# 0   https://core-docs.s3.amazonaws.com/documents/a...
# 1   https://1.cdn.edl.io/vQwTZvpBxb8PX0K2KFrGbN9Y0...
# 2   http://www.windthorstisd.net/Uploads/50/misc/f...
# 3   https://tx50000123.schoolwires.net//cms/lib/TX...
# 4   https://www.whitney.k12.tx.us/cms/lib3/TX01001...
# 5   https://docs.google.com/document/d/1QpBqSAmJNZ...
# 6   https://docs.google.com/document/d/1otlNz4M2pp...
# 7   http://www.westsabineisd.net/page/open/921/0/2...
# 8   https://docs.google.com/viewerng/viewer?url=ht...
# 9   http://www.valentineisd.com/search?orgId=14e1e...
# 10       https://www.troupisd.org/1617/innovation.pdf
# 11  http://www.trinidadisd.com/UserFiles/Servers/S...
# 12  https://docs.google.com/document/d/1RpjiOsZ-rv...
# 13  http://www.tisd.us/district_accountability/dis...
# 14  https://drive.google.com/drive/folders/0B-ALJg...
# 15  http://www.thorndale.txed.net/files/user/21/fi...
# 16                    http://www.texlineisd.net/board
# 17  https://docs.google.com/viewerng/viewer?url=ht...
# 18  https://www.sundownisd.com/UserFiles/Servers/S...
# 19  http://www.sudanisd.net/administration/documen...
#
#                                                  text
# 0                                             No text
# 1   Wink-Loving ISD WLISD - The Best in Texas: Bui...
# 2                                             No text
# 3   2 Approved by WISD School Board April 12, 2017...
# 4                                             No text
# 5   Whitharral ISD District of Innovation Ã ¢Comm...
# 6   A DISTRICT PLAN FOR INNOVATION & LOCAL CONTROL...
# 7                                             No text
# 8   WACO INDEPENDENT SCHOOL DISTRICT DISTRICT OF I...
# 9   Valentine ISD District of Innovation Plan Augu...
# 10                                            No text
# 11                                            No text
# 12  Trenton ISD District of Innovation Plan (HB 18...
# 13  2018 - 2023 District of Innovation Plan Tornil...
# 14  District of Innovation Plan Tidehaven ISD Augu...
# 15                                            No plan
# 16  Board of Trustees - Skip to Navigation Skip to...
# 17  TENAHA ISD DISTRICT OF INNOVATION PLAN (HB 184...
# 18                                            No text
# 19  Texas School Finance1 Texas School Finance : T...

# %% [markdown]
# ### Extract laws

# %%
missing_texts['possible_laws'] = missing_texts.text.apply(extract_laws.get_matches)

# %%
missing_texts.head(20)
# Out:
#     Unnamed: 0            title  \
# 0            0    Woodville ISD
# 1            1  Wink-Loving ISD
# 2            2   Windthorst ISD
# 3            3       Willis ISD
# 4            4      Whitney ISD
# 5            5   Whitharral ISD
# 6            6    White Oak ISD
# 7            7  West Sabine ISD
# 8            8         Waco ISD
# 9            9    Valentine ISD
# 10          10        Troup ISD
# 11          11     Trinidad ISD
# 12          12      Trenton ISD
# 13          13     Tornillo ISD
# 14          14    Tidehaven ISD
# 15          15    Thorndale ISD
# 16          16      Texline ISD
# 17          17       Tenaha ISD
# 18          18      Sundown ISD
# 19          19        Sudan ISD
#
#                                                  link  \
# 0   https://core-docs.s3.amazonaws.com/documents/a...
# 1   https://1.cdn.edl.io/vQwTZvpBxb8PX0K2KFrGbN9Y0...
# 2   http://www.windthorstisd.net/Uploads/50/misc/f...
# 3   https://tx50000123.schoolwires.net//cms/lib/TX...
# 4   https://www.whitney.k12.tx.us/cms/lib3/TX01001...
# 5   https://docs.google.com/document/d/1QpBqSAmJNZ...
# 6   https://docs.google.com/document/d/1otlNz4M2pp...
# 7   http://www.westsabineisd.net/page/open/921/0/2...
# 8   https://docs.google.com/viewerng/viewer?url=ht...
# 9   http://www.valentineisd.com/search?orgId=14e1e...
# 10       https://www.troupisd.org/1617/innovation.pdf
# 11  http://www.trinidadisd.com/UserFiles/Servers/S...
# 12  https://docs.google.com/document/d/1RpjiOsZ-rv...
# 13  http://www.tisd.us/district_accountability/dis...
# 14  https://drive.google.com/drive/folders/0B-ALJg...
# 15  http://www.thorndale.txed.net/files/user/21/fi...
# 16                    http://www.texlineisd.net/board
# 17  https://docs.google.com/viewerng/viewer?url=ht...
# 18  https://www.sundownisd.com/UserFiles/Servers/S...
# 19  http://www.sudanisd.net/administration/documen...
#
#                                                  text  \
# 0                                             No text
# 1   Wink-Loving ISD WLISD - The Best in Texas: Bui...
# 2                                             No text
# 3   2 Approved by WISD School Board April 12, 2017...
# 4                                             No text
# 5   Whitharral ISD District of Innovation Ã ¢Comm...
# 6   A DISTRICT PLAN FOR INNOVATION & LOCAL CONTROL...
# 7                                             No text
# 8   WACO INDEPENDENT SCHOOL DISTRICT DISTRICT OF I...
# 9   Valentine ISD District of Innovation Plan Augu...
# 10                                            No text
# 11                                            No text
# 12  Trenton ISD District of Innovation Plan (HB 18...
# 13  2018 - 2023 District of Innovation Plan Tornil...
# 14  District of Innovation Plan Tidehaven ISD Augu...
# 15                                            No plan
# 16  Board of Trustees - Skip to Navigation Skip to...
# 17  TENAHA ISD DISTRICT OF INNOVATION PLAN (HB 184...
# 18                                            No text
# 19  Texas School Finance1 Texas School Finance : T...
#
#                                         possible_laws
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [21.057, 21.057, 39.054, 28.004, 21.203, 21.35...
# 6   [21.003, 21.003, 21.003, 25.0811, 25.092, 22.0...
# 7                                                  []
# 8   [25.112, 25.085, 25.0915, 25.092, 25.094, 25.0...
# 9   [21.354, 21.353, 25.036, 25.036, 25.081, 21.10...
# 10                                                 []
# 11                                                 []
# 12  [25.112, 25.111, 25.113, 21.102, 25.0811, 21.003]
# 13  [21.003(a, 37.002, 25.112, 25.0812, 25.081, 25...
# 14  [21.102, 21.057a, 25.036, 21.057a, 25.0812, 21...
# 15                                                 []
# 16                                                 []
# 17  [11.252, 28.214, 25.111, 11.253, 28.0216, 25.1...
# 18                                                 []
# 19                                                 []

# %%
missing_text_corrected = missing_texts[missing_texts['possible_laws'].astype(str) != '[]']
missing_laws = missing_texts[missing_texts['possible_laws'].astype(str) == '[]']

# %%
print('We have added', len(missing_text_corrected), 'districts.')
print(len(missing_laws), 'are still missing.')
# Out:
# We have added 39 districts.
# 92 are still missing.

# %% [markdown]
# # Address districts that are photocopies

# %% [markdown]
# #### Incorporate previous edits

# %%
# Import old manual edits
missing_laws_old = pd.read_csv(os.path.join(data_path, 'missing_laws_corrected.csv'), encoding='latin-1')
missing_laws_old = missing_laws_old.rename({'possible_laws': 'laws_old'}, axis = 'columns')

# Merge with new missing obs
missing_laws = missing_laws.merge(missing_laws_old[['title',  'laws_old']], how = 'left', left_on = 'title', right_on = 'title')
print("Number of missing laws", len(missing_laws))

missing_laws['possible_laws'] = missing_laws.laws_old
missing_laws = missing_laws[['title', 'possible_laws','link']]
missing_laws.to_csv(os.path.join(data_path, 'missing_laws.csv'))
missing_laws.head()
# Out:
# Number of missing laws 92
#              title              possible_laws  \
# 0    Woodville ISD         [25.0811, 25.0812]
# 1  Wink-Loving ISD          [25.0811, 21.003]
# 2   Windthorst ISD          [21.401, 25.0811]
# 3       Willis ISD  [25.0811, 21.003, 21.102]
# 4      Whitney ISD                  [25.0811]
#
#                                                 link
# 0  https://core-docs.s3.amazonaws.com/documents/a...
# 1  https://1.cdn.edl.io/vQwTZvpBxb8PX0K2KFrGbN9Y0...
# 2  http://www.windthorstisd.net/Uploads/50/misc/f...
# 3  https://tx50000123.schoolwires.net//cms/lib/TX...
# 4  https://www.whitney.k12.tx.us/cms/lib3/TX01001...

# %%
missing_laws.head()
# Out:
#              title              possible_laws  \
# 0    Woodville ISD         [25.0811, 25.0812]
# 1  Wink-Loving ISD          [25.0811, 21.003]
# 2   Windthorst ISD          [21.401, 25.0811]
# 3       Willis ISD  [25.0811, 21.003, 21.102]
# 4      Whitney ISD                  [25.0811]
#
#                                                 link
# 0  https://core-docs.s3.amazonaws.com/documents/a...
# 1  https://1.cdn.edl.io/vQwTZvpBxb8PX0K2KFrGbN9Y0...
# 2  http://www.windthorstisd.net/Uploads/50/misc/f...
# 3  https://tx50000123.schoolwires.net//cms/lib/TX...
# 4  https://www.whitney.k12.tx.us/cms/lib3/TX01001...

# %% [markdown]
# ##### Manually add correct laws. If you cannot find the document, leave possible_laws blank. Save as missing_laws_corrected.csv.

# %%
missing_laws_corrected = pd.read_csv(os.path.join(data_path, 'missing_laws_corrected.csv'))
missing_laws_corrected.tail()
# Out:
#     Unnamed: 0          title  \
# 89          89  Beckville ISD
# 90          90    Aquilla ISD
# 91          91    Anthony ISD
# 92          92   Amarillo ISD
# 93          93   Alvarado ISD
#
#                                         possible_laws  \
# 89  [25.092, 25.082, 25.0811, 25.0812, 25.081, 37....
# 90  [25.0811, 25.083, 25.081, 25.082, 25.112, 25.1...
# 91                                  [21.003, 25.0811]
# 92                 [25.0811, 25.0812, 25.081, 25.082]
# 93                                                NaN
#
#                                                  link
# 89  https://drive.google.com/file/d/1bosBi0QjvukFz...
# 90  https://core-docs.s3.amazonaws.com/documents/a...
# 91  http://www.anthonyisd.net/assets/aisd-district...
# 92  http://www.amaisd.org/UserFiles/Servers/Server...
# 93  http://www.alvaradoisd.net/UserFiles/Servers/S...

# %% [markdown]
# # Update full dataset

# %%
missing_links_corrected = missing_links_corrected.set_index('title')
missing_text_corrected = missing_text_corrected.set_index('title')
missing_laws_corrected = missing_laws_corrected.set_index('title')
docs_df = docs_df.set_index('title')
docs_df = docs_df.sort_index()

# %%
docs_df.update(missing_links_corrected)
docs_df.update(missing_text_corrected)
docs_df.update(missing_laws_corrected)
docs_df.sample(10)
# Out:
#                     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# title
# Center ISD               695.0           312             312
# Hallettsville ISD        507.0          1156            1156
# Lamesa ISD                46.0          1983            1983
# Douglass ISD             609.0            15              15
# Lovelady ISD              40.0          1179            1179
# Mansfield ISD            350.0           986             986
# Venus ISD                 60.0          2848            2848
# Calhoun County ISD       713.0          3878            3878
# San Saba ISD             163.0           291             291
# Royse City ISD           176.0          3810            3810
#
#                     Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1   level    type  \
# title
# Center ISD                       312                 312   First     pdf
# Hallettsville ISD               1156                1266  Second     pdf
# Lamesa ISD                      1983                2188  Second     pdf
# Douglass ISD                      15                  15   First  google
# Lovelady ISD                    1179                1292  Second     pdf
# Mansfield ISD                    986                1075  Second     pdf
# Venus ISD                       2848                3161  Second     pdf
# Calhoun County ISD              3878                 278    html    html
# San Saba ISD                     291                 291   First     pdf
# Royse City ISD                  3810                 209    html    html
#
#                                                                  link  \
# title
# Center ISD          http://www.centerisd.org/upload/page/0063/docs...
# Hallettsville ISD   https://1.cdn.edl.io/FvsO0HQMGiiTwMHhA1rbf3N0m...
# Lamesa ISD          https://1.cdn.edl.io/8gWq2fZYq15StydveMhAEuuFu...
# Douglass ISD        https://drive.google.com/file/d/1_OzEr7LnngRcQ...
# Lovelady ISD        http://www.loveladyisd.net/files/user/3/file/L...
# Mansfield ISD       https://www.mansfieldisd.org/uploaded/main/abo...
# Venus ISD           http://www.venusisd.net/uploads/2/6/5/9/265913...
# Calhoun County ISD  http://www.calcoisd.org/common/pages/DisplayFi...
# San Saba ISD        https://www.san-saba.net/pdf/Revised_San_Saba_...
# Royse City ISD                             https://www.rcisd.org/doi/
#
#                                                                  text  \
# title
# Center ISD          Districts of Innovation may be exempt from sta...
# Hallettsville ISD   HJISD District of Innovation 2017-2021 HALLETT...
# Lamesa ISD                                                 Not a plan
# Douglass ISD        Douglass ISD District of Innovation Plan (HB 1...
# Lovelady ISD                                               Not a plan
# Mansfield ISD       Roscoe Collegiate ISD District of Innovation P...
# Venus ISD           Venus Independent School District Local Innova...
# Calhoun County ISD  CCISD District of Innovation Plan Committee Vo...
# San Saba ISD        Microsoft Word - Preliminary Revision San Saba...
# Royse City ISD      District of Innovation | Royse City ISD Home D...
#
#                     p_innovation  \
# title
# Center ISD              0.999955
# Hallettsville ISD       0.999955
# Lamesa ISD              0.024562
# Douglass ISD            0.999955
# Lovelady ISD            0.007645
# Mansfield ISD           0.999936
# Venus ISD               0.999903
# Calhoun County ISD      0.999955
# San Saba ISD            0.944715
# Royse City ISD          0.999955
#
#                                                         possible_laws
# title
# Center ISD                  [25.082, 21.057, 21.003, 25.0811, 25.081]
# Hallettsville ISD   [21.055, 25.081, 21.458, 21.003, 25.113, 21.05...
# Lamesa ISD          [25.0811, 25.082, 21.003, 21.352, 21.3541, 21....
# Douglass ISD        [21.352, 21.3541, 21.102, 21.203, 25.0811, 21....
# Lovelady ISD        [25.0811, 21.003, 21.401, 25.112, 21.102, 21.352]
# Mansfield ISD       [25.0811, 25.111, 21.352, 21.003, 25.113, 25.112]
# Venus ISD           [25.113, 25.111, 21.352, 21.003, 21.401, 21.10...
# Calhoun County ISD  [25.082, 21.057, 21.003, 21.053, 25.081, 25.0811]
# San Saba ISD                       [25.0811, 21.0003, 21.102, 21.003]
# Royse City ISD      [102.1307, 25.0811, 12.0522, 28.0216, 21.401, ...

# %%
for law in docs_df[docs_df.index == "Blum ISD"].possible_laws:
    print(law)
# Out:
# [11.251, 21.352, 21.3541, 21.458, 21.353, 25.113, 25.082, 25.0811, 25.083, 25.092, 25.036, 28.0216, 29.0821, 25.087, 28.0214, 37.0012, 45.206, 25.112, 21.451, 21.354, 21.102, 21.401, 21.003, 25.084, 25.081]

# %%
print("Only missing", len(docs_df[docs_df['possible_laws'].astype(str) == '[]']), " of ", len(docs_df),  "- unable to find plans.")
# Out:
# Only missing 13  of  824 - unable to find plans.

# %% [markdown]
# # Save

# %%
docs_df.to_csv(os.path.join(data_path, 'doi_exemptions_temp.csv'))
