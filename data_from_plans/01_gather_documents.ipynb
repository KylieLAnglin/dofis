# %% [markdown]
# ## Gather documents from district websites

# %% [markdown]
# The goal of this script is to create a single data frame containing all of the possible links to DOI plans. Once run, the dataframe will have four columns: district, file type, level, link.

# %%
import gather_documents
import os
import pandas as pd
from start import data_path

# %%
test_sample = False
sample_size = 5

# %% [markdown]
# ## First Level Links

# %% [markdown]
# First level links are document urbls (identified by .doc, .pdf. drive.google) linking directly from the TEA website. They are almost certianly DOI plans.

# %%
tea_url = 'https://tea.texas.gov/Texas_Schools/District_Initiatives/Districts_of_Innovation/'

# %%
def pipe_dataframe(df):
    df = df.copy()
    df = df.reset_index()
    df = df.rename(columns={'index': 'title'})
    df['level'] = 'First'
    return df

# %%
first_level_links = gather_documents.FirstLevelLinks(tea_url, print_interim=False)
first_level_links_df = first_level_links.docs_df.pipe(pipe_dataframe)
print('There are {} first level links.'.format(len(first_level_links_df)))
first_level_links_df.tail()
# Out:
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/kylieleblancKylie/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# There are 435 first level links.
#                     title                                               link  \
# 430       Burkburnett ISD  https://1.cdn.edl.io/NmmgpAdINIeQ8MlcQQx6MB0zP...
# 431            Malone ISD  http://www.maloneisd.org/pdf/doi/MaloneISDInno...
# 432           Ricardo ISD  http://www.ricardoisd.us/UserFiles/Servers/Ser...
# 433      Raymondville ISD  https://s3.amazonaws.com/scschoolfiles/1444/ri...
# 434  Mount Enterprise ISD  http://www.meisd.org/PDFs/District%20of%20Inno...
#
#     type  level
# 430  pdf  First
# 431  pdf  First
# 432  pdf  First
# 433  pdf  First
# 434  pdf  First

# %% [markdown]
# ## Seed Links

# %% [markdown]
# Seed links are district URLs from the TEA website which do not have a document identifier (like .pdf). These are the websites we will search for additional documents.

# %%
seed_links = gather_documents.SeedLinks(tea_url, print_interim = False).seed_links
print("There are", len(seed_links), "seed links.")
seed_links
# Out:
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/kylieleblancKylie/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# There are 401 seed links.
# {'Abbott ISD': 'https://www.abbottisd.org/apps/bbmessages/show_bbm.jsp?REC_ID=110632',
#  'Abernathy ISD': 'http://www.abernathyisd.com/apps/pages/index.jsp?uREC_ID=284545&type=d&pREC_ID=1134133',
#  'Academy ISD': 'https://www.academyisd.net/apps/pages/index.jsp?uREC_ID=1218559&type=d&pREC_ID=1452890',
#  'Agua Dulce ISD': 'https://www.adisd.net/domain/47',
#  'Alamo Heights ISD': 'http://www.ahisd.net/news/what_s_new/district_of_innovation_plan_2016-2021',
#  'Albany ISD': 'http://www.albanyisd.net/district-of-innovation.html',
#  'Aldine ISD': 'http://www.aldineisd.org/cms/one.aspx?portalId=750&pageId=10168641',
#  'Aledo ISD': 'https://www.aledoisd.org/Domain/2005',
#  'Alief ISD': 'http://www.aliefisd.net/Page/8915',
#  'Allen ISD': 'http://www.allenisd.org/Page/47067',
#  'Alvin ISD': 'http://www.alvinisd.net/innovation',
#  'Anahuac ISD': 'https://sites.google.com/aisdpanthers.com/anahuacisd/about/district-of-innovation?authuser=0',
#  'Andrews ISD': 'https://www.andrews.esc18.net',
#  'Angleton ISD': 'https://www.angletonisd.net//site/default.aspx?PageID=3636',
#  'Anna ISD': 'http://annaisd.org/departments/curriculum___technology/district_of_innovation',
#  'Anson ISD': 'http://ansontigers.com/page/admin_postings',
#  'Apple Springs ISD': 'http://www.asisd.com/o/Apple%20Springs%20ISD/page/district-of-innovation--2',
#  'Archer City ISD': 'https://www.archercityisd.net/about_us/district_of_innovation',
#  'Aspermont ISD': 'http://www.aspermontisd.com/apps/bbmessages/show_bbm.jsp?REC_ID=101482',
#  'Athens ISD': 'http://athensisd.net/cms/One.aspx?portalId=84113&pageId=4174444',
#  'Aubrey ISD': 'http://www.aubreyisd.net/domain/470',
#  'Avalon ISD': 'http://www.avalonisd.net/apps/pages/index.jsp?uREC_ID=111233&type=d&pREC_ID=1152678',
#  'Avery ISD': 'http://www.averyisd.net/vnews/display.v/SEC/District%20of%20Innovation',
#  'Avinger ISD': 'http://www.avingerisd.net/140920_2',
#  'Banquete ISD': 'https://www.banqueteisd.esc2.net/domain/18',
#  'Bastrop ISD': 'https://www.bisdtx.org/Page/1442',
#  'Bay City ISD': 'https://www.bcblackcats.net/site/default.aspx?PageType=14&DomainID=24&PageID=1027&ModuleInstanceID=1347&ViewID=1e008a8a-8e8a-4ca0-9472-a8f4a723a4a7&IsMoreExpandedView=True',
#  'Beaumont ISD': 'https://www.bmtisd.com/Page/5523',
#  'Beckville ISD': 'https://sites.google.com/beckvilleisd.net/beckvilleisd/home/required-postings/district-plans?authuser=0',
#  'Benavides ISD': 'http://www.benavidesisd.net/Content2/Innovation',
#  'Big Sandy ISD': 'http://www.bigsandyisd.net/331880_3',
#  'Birdville ISD': 'http://www.birdvilleschools.net/Page/52899',
#  'Blackwell CISD': 'http://www.blackwellhornets.org/apps/news/article/682927',
#  'Blanco ISD': 'http://blancoisd.com/176530_2',
#  'Bloomburg ISD': 'http://www.bloomburgisd.net/160405_2',
#  'Blooming Grove ISD': 'https://www.bgisd.org/apps/pages/index.jsp?uREC_ID=420340&type=d&pREC_ID=1450741',
#  'Blue Ridge ISD': 'http://brisd.net/domain/355',
#  'Bluff Dale ISD': 'https://www.bdisd.net/Page/955',
#  'Boerne ISD': 'https://www.boerneisd.net/Page/5225',
#  'Boling ISD': 'http://www.bolingisd.net/DOI/',
#  'Bonham ISD': 'http://www.bonhamisd.org/319501_3',
#  'Bosqueville ISD': 'https://www.bosquevilleisd.org/110802_2?articleID=19601',
#  'Brazosport ISD': 'http://www.brazosportisd.net/cms/one.aspx?portalid=415458&pageid=7056761',
#  'Bremond ISD': 'https://www.bremondisd.net/vnews/display.v/ART/590a0398c020a',
#  'Brenham ISD': 'http://www.brenhamisd.net/page/doi.home',
#  'Bridgeport ISD': 'https://www.bridgeportisd.net/apps/pages/index.jsp?uREC_ID=434830&type=d&pREC_ID=1176817',
#  'Brock ISD': 'http://www.brockisd.net/311612_3',
#  'Brookesmith ISD': 'https://www.brookesmithisd.net/167785_2',
#  'Brooks County ISD': 'http://www.bcisdistrict.net/LinkClick.aspx?fileticket=-CMOLrQwdUs%3d&tabid=65695&portalid=1007&mid=-1',
#  'Brownfield ISD': 'http://www.brownfieldisd.net/',
#  'Brownsville ISD': 'http://www.bisd.us/DistrictofInnovation/',
#  'Brownwood ISD': 'http://www.brownwoodisd.org/doi',
#  'Bryan ISD': 'http://www.bryanisd.org/apps/pages/index.jsp?uREC_ID=680095&type=d&pREC_ID=1123068',
#  'Bullard ISD': 'http://www.bullardisd.net/Page/1308',
#  'Bynum ISD': 'http://bynumisd.net/cms/One.aspx?portalId=205483&pageId=205500',
#  'Caddo Mills ISD': 'http://www.caddomillsisd.org/Domain/705',
#  'Caldwell ISD': 'http://www.caldwellschools.net/apps/pages/DOI',
#  'Calhoun County ISD': 'http://www.calcoisd.org/common/pages/DisplayFile.aspx?itemId=11213478',
#  'Callisburg ISD': 'http://www.cisdtx.net/domain/420',
#  'Carroll ISD': 'https://www.southlakecarroll.edu/Page/2359',
#  'Carrollton Farmers Branch ISD': 'https://cfbisd.edu/about-us/our-vision-history/our-vision-mission-and-goal/district-of-innovation/',
#  'Carthage ISD': 'http://www.carthageisd.org/public_notice/district_of_innovation_plan',
#  'Castleberry ISD': 'http://www.castleberryisd.net/cms/One.aspx?portalId=825806&pageId=45514505',
#  'Cedar Hill ISD': 'http://www.chisd.net/Page/9668',
#  'Celeste ISD': ' http://www.celesteisd.org/137144_2',
#  'Celina ISD': 'https://www.celinaisd.com/required-postings/',
#  'Center Point ISD': 'http://www.cpisd.net/192984_2',
#  'Centerville ISD (145902)': 'http://www.centerville.k12.tx.us/140724_2',
#  'Centerville ISD (228904)': 'http://www.centervilleisd.net',
#  'Channing ISD': 'http://www.channingisd.net/vnews/display.v/ART/58dbe8de02d04',
#  'Chapel Hill ISD (212909)': 'http://districtofinnovation.weebly.com/',
#  'Chapel Hill ISD (225906)': 'http://www.chisddevils.com/269515_3',
#  'Chillicothe ISD': 'http://www.cisd-tx.net/school_info/district_information_and_required_postings',
#  'Christoval ISD': 'http://www.christovalisd.org/district-of-innovation-31f5818f',
#  'Cisco ISD': 'http://www.ciscoisd.net/197066_2',
#  'Clarendon CISD': 'https://clarendonisd.socs.net/vnews/display.v/SEC/District%7CRequired%20Postings%3E%3EDistrict%20of%20Innovation',
#  'Claude ISD': 'http://www.claudeisd.net/293354_4',
#  'Clear Creek ISD': 'http://www.ccisd.net/explore_c_c_i_s_d/district_of_innovation',
#  'Cleveland ISD': 'https://www.clevelandisd.org/214843_2',
#  'Clint ISD': 'https://www.clintweb.net/Domain/94',
#  'Collinsville ISD': 'http://www.collinsvilleisd.org/domain/48',
#  'Como-Pickton CISD': 'http://www.cpcisd.net/141155_2',
#  'Comstock ISD': 'http://comstockisd.net/20775',
#  'Coolidge ISD': 'http://www.coolidgeisd.org/page/article/35',
#  'Copperas Cove ISD': 'http://www.ccisd.com/174488_2',
#  'Corrigan-Camden ISD': 'http://www.ccisdtx.com/25393?articleID=21715',
#  'Coupland ISD': 'http://www.couplandisd.org/Page/259',
#  'Crandall ISD': 'http://www.crandall-isd.net/apps/news/article/682754',
#  'Crowell ISD': 'http://www.crowellisd.net/159837_2',
#  'Crowley ISD': 'http://www.crowleyisdtx.org/DistrictOfInnovation',
#  'Daingerfield-Lone Star ISD': 'http://www.dlsisd.org/apps/pages/index.jsp?uREC_ID=442633&type=d&pREC_ID=955033',
#  'Dalhart ISD': 'http://www.dalhartisd.org/apps/pages/index.jsp?uREC_ID=318016&type=d&pREC_ID=774962',
#  'Danbury ISD': 'http://www.danburyisd.org/vnews/display.v/ART/5a81a0988532d',
#  'Dayton ISD': 'http://www.daytonisd.net/153681_2',
#  'DeKalb ISD': 'http://www.dekalbisd.net/144514_2',
#  'DeSoto ISD': 'http://desotoisd.ss10.sharpschool.com/cms/one.aspx?pageId=5844603',
#  'Decatur ISD': 'http://www.decaturisd.us/Domain/839',
#  'Deer Park ISD': 'http://www.dpisd.org/domain/2209',
#  'Denton ISD': 'http://www.dentonisd.org/Page/84561',
#  'Dickinson ISD': 'http://www.dickinsonisd.org/upload/page/0016/docs/District%20of%20Innovation%20Plan_FINAL.PDF',
#  'Dilley ISD': 'http://www.dilleyisd.net/o/district/browse/24239',
#  'Dimmitt ISD': 'http://www.dimmittisd.net/vnews/display.v/ART/58418922e32fe?in_archive=1',
#  'Eanes ISD': 'https://www.eanesisd.net/district/doi',
#  'East Central ISD': 'https://www.ecisd.net/Page/11074',
#  'Eastland ISD': 'https://tea.texas.gov/Texas_Schools/District_Initiatives/Districts_of_Innovation/',
#  'Eden CISD': 'http://www.edencisd.net/170881_2',
#  'Edgewood ISD (015905)': 'http://www.edgewood-isd.net/page/dis.district_of_innovation',
#  'El Campo ISD': 'http://www.ecisd.org/district-innovation',
#  'El Paso ISD': 'https://www.episd.org/Page/542',
#  'Elgin ISD': 'http://www.elginisd.net/Page/4372',
#  'Elkhart ISD': 'https://www.elkhartisd.org/apps/pages/index.jsp?uREC_ID=289562&type=d&pREC_ID=666425',
#  'Era ISD': 'http://www.eraisd.net/site/Default.aspx?PageID=62',
#  'Etoile ISD': 'http://www.etoile.esc7.net/?PageName=%27SchoolPublications&CategoryID=17262&SubCategoryID=38693&PublicationID=113207',
#  'Eustace ISD': 'https://www.eustaceisd.net/386353_3',
#  'Evant ISD': 'http://www.evantisd.org/332142_3',
#  'Everman ISD': 'https://www.eisd.org/domain/68',
#  'Fabens ISD': 'http://www.fabensisd.net/apps/pages/index.jsp?uREC_ID=683449&type=d&pREC_ID=1124630',
#  'Fairfield ISD': 'http://www.fairfieldisd.net/261124_4',
#  'Fannindel ISD': 'http://www.fannindelisd.net/158709_2',
#  'Ferris ISD': 'http://nebula.wsimg.com/0e5eba548323b487c339b012901b328c?AccessKeyId=9C6C4AFDA7BFE6452915&disposition=0&alloworigin=1',
#  'Flatonia ISD': 'http://www.flatoniaisd.net/147848_2',
#  'Florence ISD': 'http://www.florenceisd.net/139918_2',
#  'Forestburg ISD': 'https://www.forestburgisd.net/200185_2',
#  'Forsan ISD': 'http://www.forsan.esc18.net/Page/212',
#  'Fort Bend ISD': 'http://www.fortbendisd.com/innovation',
#  'Fort Elliott CISD': 'http://www.fecisd.net/',
#  'Fort Sam Houston ISD': 'http://www.fshisd.net/apps/pages/index.jsp?uREC_ID=698533&type=d&pREC_ID=1132221',
#  'Franklin ISD': 'https://www.franklinisd.net/apps/news/article/805390',
#  'Fredericksburg ISD': 'https://www.fisd.org/Page/2153',
#  'Frenship ISD': 'https://www.frenship.net/apps/pages/index.jsp?uREC_ID=1107515&type=d&pREC_ID=1387819',
#  'Gainesville ISD': 'http://www.gainesvilleisd.org/page/4852',
#  'Galena Park ISD': 'https://www.galenaparkisd.com/Domain/799',
#  'Galveston ISD': 'https://www.gisd.org/Page/9697',
#  'Ganado ISD': 'http://www.ganadoisd.org/Page/465',
#  'Garner ISD': 'https://docs.google.com/a/garnerisd.net/viewer?a=v&pid=sites&srcid=Z2FybmVyaXNkLm5ldHxnYXJuZXItaXNkfGd4OjJlMDhhMzM0ZmQ3NjAxMjE',
#  'Garrison ISD': 'http://www.garrisonisd.com/district-of-innovation.html',
#  'Gary ISD': 'https://www.garyisd.org/apps/pages/index.jsp?uREC_ID=245130&type=d&pREC_ID=1145477',
#  'Gause ISD': 'http://www.gauseisd.net/apps/news/article/882214',
#  'George West ISD': 'http://www.gwisd.esc2.net/vnews/display.v/SEC/GWISD%20District%7CDistrict%20of%20Innovation',
#  'Georgetown ISD': 'http://www.georgetownisd.org/domain/1818',
#  'Giddings ISD': 'https://www.giddingsisd.net/apps/pages/index.jsp?uREC_ID=187591&type=d&pREC_ID=1390842',
#  'Glen Rose ISD': 'http://www.grisd.net/required-postings/',
#  'Godley ISD': 'http://www.godleyisd.net/apps/pages/index.jsp?uREC_ID=1167738&type=d&pREC_ID=1418045',
#  'Goldthwaite ISD': 'http://www.goldisd.net/board-of-education-6515b0ec',
#  'Goliad ISD': 'http://www.goliadisd.org/apps/pages/index.jsp?uREC_ID=548354&type=d&pREC_ID=1157574',
#  'Gonzales ISD': 'https://www.gonzalesisd.net/Domain/354',
#  'Gorman ISD': 'https://www.gormanisd.net/apps/pages/index.jsp?uREC_ID=220038&type=d&pREC_ID=1408942',
#  'Granbury ISD': ' http://www.granburyisd.org/innovation',
#  'Grandfalls-Royalty ISD': 'https://www.grisd.com/301428_4',
#  'Grapeland ISD': 'http://www.grapelandisd.net/domain/94',
#  'Grapevine-Colleyville ISD': 'http://www.gcisd-k12.org/cms/one.aspx?portalid=96313&pageid=572981',
#  'Greenville ISD': 'http://www.greenvilleisd.com/Page/1842',
#  'Groesbeck ISD': 'https://www.groesbeckisd.net/321772_4',
#  'Hallettsville ISD': 'http://www.hisdbrahmas.org/apps/pages/index.jsp?uREC_ID=750341&type=d&pREC_ID=1159713',
#  'Hamlin ISD': 'http://www.hamlin.esc14.net/page/HISD_District_of_Innovation',
#  'Harleton ISD': 'https://www.harletonisd.net/220977_2',
#  'Harlingen CISD': 'http://www.hcisd.org/apps/pages/index.jsp?uREC_ID=1230292&type=d&pREC_ID=1484202',
#  'Hart ISD': 'https://www.hartisd.net/vnews/display.v/ART/5bcdd0b5a0704',
#  'Haskell ISD': 'http://www.haskell.esc14.net/',
#  'Hawkins ISD': 'https://www.hawkinsisd.org/public_information/district_of_innovation',
#  'Hawley ISD': 'http://www.hawley.esc14.net/page/dis.LegalPostings',
#  'Hays CISD': 'https://www.hayscisd.net/doi',
#  'Highland Park ISD (188903)': 'http://www.hpisd.net/147726_2',
#  'Hillsboro ISD': 'https://www.hillsboroisd.org/Domain/245',
#  'Holliday ISD': 'https://www.hollidayisd.net/357156_3',
#  'Hooks ISD': 'http://www.hooksisd.net/',
#  'Howe ISD': 'https://www.howeisd.net/domain/160',
#  'Hubbard ISD (019913)': 'http://www.hubbardisd.net/138780_2',
#  'Hubbard ISD (109905)': 'https://www.hubbardisd.com/apps/pages/index.jsp?uREC_ID=1284527&type=d&pREC_ID=1494354',
#  'Huckabay ISD': 'https://www.hisd.us/domain/70',
#  'Huffman ISD': 'http://www.huffmanisd.net/apps/news/article/601847',
#  'Hughes Springs ISD': 'http://www.hsisd.net/page/DOI_Page',
#  'Humble ISD': 'http://www.humbleisd.net/Page/82270',
#  'Huntington ISD': 'https://docs.google.com/document/d/1uhkYjvm3qiK58nbOSrZ9xDP46fCuveF85ujjF5TY0Tc/edit',
#  'Hurst-Euless-Bedford ISD': 'http://www.hebisd.edu/page.cfm?p=2550 ',
#  'Industrial ISD': 'http://www.industrialisd.org/district-of-innovation',
#  'Iola ISD': 'https://www.iolaisd.net/domain/13',
#  'Irion County ISD': 'https://www.irion-isd.org/domain/210',
#  'Irving ISD': 'https://www.irvingisd.net/DOI',
#  'Itasca ISD': 'https://docs.google.com/document/d/1UIolnjz0Or1C6KjTpz6YYy3fPkDYqhJk6cn8DYC2q4E/edit',
#  'Jacksboro ISD': 'https://www.jacksboroisd.net/Page/1385',
#  'Jayton-Girard ISD': 'https://www.jaytonjaybirds.com/apps/news/article/815274',
#  'Johnson City ISD': 'https://www.jc.txed.net/Page/9813',
#  'Jonesboro ISD': 'https://www.jonesboroisd.net/33633_1',
#  'Joshua ISD': 'http://www.joshuaisd.org/domain/1605',
#  'Jourdanton ISD': 'http://www.jourdantonisd.net/vnews/display.v/ART/58d185ae768a8?in_archive=1',
#  'Keller ISD': 'https://www.kellerisd.net/domain/93',
#  'Kelton ISD': 'http://www.keltonisd.com/24549',
#  'Kenedy ISD': 'http://kenedyisd.ss14.sharpschool.com/cms/one.aspx?portalId=55807&pageId=311520',
#  'Kennard ISD': 'http://kennardisd.net/Page/470',
#  'Kennedale ISD': 'https://www.kennedaleisd.net/domain/12',
#  'Kerrville ISD': 'https://www.kerrvilleisd.net/domain/41',
#  'Kilgore ISD': 'http://www.kisd.org/apps/pages/index.jsp?uREC_ID=675415&type=d&pREC_ID=1120125',
#  'Klein ISD': 'https://www.kleinisd.net/cms/one.aspx?portalId=568125&pageId=1974044',
#  'Knippa ISD': 'https://docs.google.com/viewer?a=v&pid=sites&srcid=a25pcHBhaXNkLm5ldHxob21lfGd4OjQ5ZjA5ZWVhMzg5ODQ1NDU',
#  'Knox City-O’Brien CISD': 'http://www.knoxcityschools.net/vnews/display.v/ART/4a9c1f69776fd',
#  'Kopperl ISD': 'http://www.kopperlisd.org/109465_2?articleID=9866',
#  'Kress ISD': 'http://www.kressonline.net/administration/district_and_campus_reports___plans',
#  'La Grange ISD': 'http://www.lgisd.net/district-of-innovation--4',
#  'La Joya ISD': 'https://www.lajoyaisd.com/362783_3',
#  'La Porte ISD': 'http://www.lpisd.org/apps/pages/index.jsp?uREC_ID=697607&type=d&pREC_ID=1131730',
#  'La Vernia ISD': 'https://www.lvisd.org/Page/1083',
#  'Lago Vista ISD': 'http://www.lagovistaisd.net/page/annualreports',
#  'Lake Dallas ISD': 'http://www.ldisd.net/Page/4495',
#  'Lake Worth ISD': 'http://www.lake-worth.k12.tx.us/Page/4786',
#  'Lamesa ISD': 'http://www.lamesaisd.net/apps/pages/index.jsp?uREC_ID=131106&type=d&pREC_ID=1151368',
#  'Lampasas ISD': 'https://www.lisdtx.org/domain/11',
#  'Laneville ISD': 'http://www.lanevilleisd.org/apps/news/article/691650',
#  'Laredo ISD': 'http://laredo.ss11.sharpschool.com/cms/One.aspx?portalId=328992&pageId=4249801',
#  'Lazbuddie ISD': 'http://www.lazbuddieisd.org/apps/news/article/679305',
#  'Leander ISD': 'https://www.leanderisd.org/about/district_of_innovation',
#  'Leary ISD': 'http://www.learyisd.net/6253_1',
#  'Lefors ISD ': 'https://docs.google.com/document/d/1qN_8_DgXYLLaD7tx1Daq3QGMoi3FG7bFH8DaOwsAViE/edit',
#  'Leon ISD': 'http://www.leonisd.net/apps/pages/index.jsp?uREC_ID=1173034&type=d&pREC_ID=1410266',
#  'Leonard ISD': 'http://www.leonardisd.net/page/District%20of%20Innovation',
#  'Lexington ISD': 'http://www.lexingtonisd.net/apps/pages/index.jsp?uREC_ID=1084855&type=d&pREC_ID=1371783',
#  'Liberty Hill ISD': 'https://www.libertyhill.txed.net/Domain/294',
#  'Liberty ISD': 'http://www.libertyisd.net/ ',
#  'Lindale ISD': 'http://www.lindaleeagles.org/community',
#  'Linden-Kildare CISD': 'http://www.lkcisd.net/144406_2',
#  'Little Elm ISD': 'http://www.littleelmisd.net/domain/1418',
#  'Livingston ISD': 'http://www.livingstonisd.com/districtofinnovationplan',
#  'Lohn ISD': 'http://www.lohnisd.net/?PageName=LatestNews&Section=LatestNews&ItemID=531200&ISrc=School&Itype=News',
#  'Lovejoy ISD': 'http://www.lovejoyisd.net/apps/pages/index.jsp?uREC_ID=388930&type=d&pREC_ID=1113514',
#  'Lovelady ISD': 'http://www.loveladyisd.net/',
#  'Lubbock ISD': 'https://www.lubbockisd.org/Innovation',
#  'Lubbock-Cooper ISD': 'https://www.lcisd.net/apps/pages/districtofinnovationplan',
#  'Lueders-Avoca ISD': 'http://www.laisd.esc14.net/page/APPROVEDDOI',
#  'Lumberton ISD': 'http://www.lumberton.k12.tx.us/District/12531-Untitled.html',
#  'Lytle ISD': 'https://www.lytleisd.org/Page/1235',
#  'Magnolia ISD': 'https://www.magnoliaisd.org/apps/pages/index.jsp?uREC_ID=256419&type=d&pREC_ID=1357102',
#  'Mansfield ISD': 'https://www.mansfieldisd.org/page.cfm?p=6010',
#  'Marathon ISD': 'https://www.marathonisd.net/required-postings',
#  'Marble Falls ISD': 'https://www.marblefallsisd.org/Page/10542',
#  'Mason ISD': 'http://www.masonisd.net/apps/pages/index.jsp?uREC_ID=682677&type=d&pREC_ID=1188726',
#  'Mathis ISD': 'http://www.mathisisd.org/userfiles/62/my%20files/mathis%20innovation%20plan%20(board%20approved%2005.17.17).docx?id=1040',
#  'McCamey ISD': 'http://www.mcisd.esc18.net/176428_2',
#  'McGregor ISD': 'http://mcgregor-isd.org/about/district_of_innovation',
#  'McKinney ISD': 'https://www.mckinneyisd.net/about-misd/accountability-evaluation/district-of-innovation/',
#  'McLean ISD': 'http://www.mcleanisd.com/vnews/display.v/ART/58d3e3a7debd0',
#  'McLeod ISD': 'http://www.mcleodisd.net/news/mcleod-isd-district-innovation-plan',
#  'McMullen County ISD': 'https://www.mcisd.us/29028_1',
#  'Menard ISD': 'http://www.menardisd.net/district-of-innovation/',
#  'Merkel ISD': 'https://sites.google.com/merkelisd.net/districtofinnovation/district-of-innovation-plan',
#  'Mexia ISD': 'http://mexiaisd.net/18900?articleID=8257 ',
#  'Midland ISD': 'https://www.midlandisd.net/Page/31604',
#  'Midlothian ISD': 'http://www.misd.gs/Page/3258',
#  'Midway ISD (161903) ': 'https://www.midwayisd.org/site/Default.aspx?PageID=20427',
#  'Milano ISD': 'https://docs.google.com/document/d/1irpKI3kN9ewHiHSRRSjeA3WScE6awvOVBe_hNqegNlw/edit?usp=sharing',
#  'Mildred ISD': 'http://www.mildredisd.org/apps/pages/index.jsp?uREC_ID=918080&type=d&pREC_ID=1226052',
#  'Miller Grove ISD': 'https://docs.google.com/document/d/1VXGGMvUftkgLYa8itzbiFYuAKpZD3y3Orzi-RnNSmbc/edit',
#  'Millsap ISD': 'http://www.millsapisd.net/site/Default.aspx?PageID=775',
#  'Mineola ISD': 'http://www.mineolaisd.net/page/District-of-Innovation',
#  'Mission CISD': 'https://www.mcisd.net/apps/pages/index.jsp?uREC_ID=217505&type=d&pREC_ID=1647849',
#  'Monahans-Wickett-Pyote ISD': 'http://www.mwpisd.esc18.net/147692_2',
#  'Montgomery ISD': ' http://www.misd.org/page/dis.innovation',
#  'Morgan Mill ISD': 'http://www.mmisd.us/',
#  'Motley County ISD': 'http://www.motleyco.org/',
#  'Mount Calm ISD': 'https://www.mcisd1.org/apps/pages/index.jsp?uREC_ID=103585&type=d&pREC_ID=1410287',
#  'Mt. Vernon ISD': 'http://www.mtvernonisd.net/about_us/required_postings',
#  'Muenster ISD': 'http://www.muensterisd.net/Page/2307',
#  'Mumford ISD': 'http://www.mumford.k12.tx.us/page173.html',
#  'Munday CISD': 'http://www.mundaycisd.net/146659_2',
#  'Murchison ISD': 'http://www.murchisonisd.com/district-of-innovation.html',
#  'Navarro ISD': 'http://www.nisd.us/apps/pages/index.jsp?uREC_ID=141671&type=d&pREC_ID=1151809',
#  'Nederland ISD': 'https://www.nederland.k12.tx.us/District/Department/14956-District-of-Innovation',
#  'New Boston ISD': 'https://www.nbschools.net/',
#  'Newton ISD': 'http://www.newtonisd.net/138641_2',
#  'Nocona ISD': 'http://www.noconaisd.net/141152_2',
#  'Normangee ISD': 'http://www.normangeeisd.org/271151_3',
#  'North East ISD': 'https://www.neisd.net/Page/19905',
#  'North Lamar ISD': ' http://www.northlamar.net/page/doi',
#  'Northside ISD (244905)': 'https://www.northsideisd.us/',
#  'Nueces Canyon CISD': 'http://www.nccisd.net/Page/1212',
#  "O'Donnell ISD": 'http://odonnell.esc17.net/page/District_of_Innovation',
#  'Paint Creek ISD': 'http://www.pcisd.org/domain/20',
#  'Palacios ISD': 'http://palaciosisd.org/required-postings/',
#  'Pawnee ISD': 'https://www.pawneeisd.net/o/pawnee-isd/page/pawnee-isd-district-of-innovation-plan',
#  'Pearsall ISD': 'https://www.pearsallisd.org/apps/pages/index.jsp?uREC_ID=1113445&type=d&pREC_ID=1390413',
#  'Peaster ISD': 'http://www.peaster.net/Page/3910',
#  'Perrin-Whitt CISD': 'http://www.pwcisd.net/328170_3',
#  'Petersburg ISD': 'http://www.petersburgisd.net/DOI',
#  'Pflugerville ISD': 'http://www.pflugervilleisd.net/Page/7004',
#  'Pilot Point ISD': 'http://www.pilotpointisd.com/Domain/531',
#  'Plemons-Stinnett-Phillips CISD': 'http://www.pspcisd.net/141159_2',
#  'Ponder ISD': 'http://www.ponderisd.net/Page/6349',
#  'Port Aransas ISD': 'http://www.paisd.net/home/district-of-innovation',
#  'Port Arthur ISD': 'http://www.paisd.org/apps/spotlightmessages/5447',
#  'Port Neches-Groves ISD': 'https://www.pngisd.org/domain/15',
#  'Post ISD': 'http://www.postisd.net/apps/news/article/684196',
#  'Pottsboro ISD': 'https://www.pottsboroisd.org/district-of-innovation',
#  'Prairie Valley ISD': 'http://www.prairievalleyisd.net/vnews/display.v/ART/5adf8c0c02fb2',
#  'Priddy ISD': 'http://priddy.sharpschool.net/required_postings',
#  'Princeton ISD': 'https://www.princetonisd.net/Page/6824',
#  'Quinlan ISD': 'http://www.quinlanisd.net/apps/pages/index.jsp?uREC_ID=360147&type=d&pREC_ID=1164206',
#  'Rankin ISD': 'http://www.rankinisd.net/index.php?pageID=162665_2',
#  'Red Lick ISD': 'https://docs.google.com/document/d/1NgfNhnenLenKX8ymcxi5rwpYBzEzdufJTw0D2R73XO4/edit',
#  'Red Oak ISD': 'http://www.redoakisd.org/?DivisionID=10785&DepartmentID=25199',
#  'Rio Vista ISD': 'http://www.rvisd.net/domain/378',
#  'Robinson ISD': 'http://www.risdweb.org/o/robinson-isd/page/curriculum-accountability-and-assessment',
#  'Robstown ISD': 'http://www.robstownisd.org/apps/pages/index.jsp?uREC_ID=290090&type=d&pREC_ID=1123475',
#  'Roby CISD': 'https://docs.google.com/document/d/1H8XRcRNhFnHnWFG33oJqvt-3Bw7D8c-NUgBG5YYTlLQ/edit',
#  'Rochelle ISD': 'http://www.rochelleisd.net/district/district_of_innovation_plan/',
#  'Rockdale ISD': 'http://www.rockdaleisd.net/apps/pages/index.jsp?uREC_ID=708881&type=d&pREC_ID=1138535',
#  'Rockwall ISD': 'http://www.rockwallisd.com/domain/2115',
#  'Rosebud-Lott ISD': 'https://www.rlisd.org/apps/bbmessages/show_bbm.jsp?REC_ID=112680',
#  'Rotan ISD': 'http://www.rotan.org/district-of-innovation-plan-19883a7e',
#  'Round Rock ISD': 'https://roundrockisd.org/district-of-innovation/',
#  'Royse City ISD': 'https://www.rcisd.org/doi/',
#  'Rusk ISD': 'http://www.ruskisd.net/about-us/district-of-innovation',
#  'Saint Jo ISD': 'http://www.saintjoisd.net/vnews/display.v/SEC/District%7CDistrict%20of%20Innovation%3E%3EApproved%20District%20of%20Innovation%20Plan',
#  'Sam Rayburn ISD': 'http://www.srisd.org/apps/pages/index.jsp?uREC_ID=1014217&type=d&pREC_ID=1368535',
#  'San Angelo ISD': 'http://www.saisd.org/District/DistrictOfInnovation.asp',
#  'San Antonio ISD': 'http://www.saisd.net/main/documents/2016/DOILocalInnovationPlan2.PDF',
#  'San Augustine ISD': 'http://www.saisd.us/apps/pages/index.jsp?uREC_ID=234648&type=d&pREC_ID=1187306',
#  'Sanford-Fritch ISD': 'http://www.sfisd.net/apps/pages/index.jsp?uREC_ID=1472915&type=d&pREC_ID=1625521',
#  'Santa Anna ISD': 'http://www.santaannaisd.net/docs/district/district%20plans/revised%20innovation%20plan.docx?id=1499',
#  'Santa Gertrudis ISD': 'http://www.sgisd.net/apps/pages/index.jsp?uREC_ID=925191&type=d&pREC_ID=1323196',
#  'Schertz-Cibolo-Universal City ISD': 'https://www.scuc.txed.net/Domain/2507',
#  'Schleicher County ISD': 'https://www.scisd.net/domain/196',
#  'Scurry-Rosser ISD': 'http://www.scurry-rosser.com/Common/News2/HomePagePopUps/Default.asp?ItemID=91217&ISrc=District&Itype=News',
#  'Seguin ISD': 'http://www.seguin.k12.tx.us/page/doi.home',
#  'Seminole ISD': 'http://www.seminoleisd.net/page/article/98',
#  'Seymour ISD': 'http://www.seymour-isd.net/189253_2',
#  'Shamrock ISD': 'https://www.shamrockisd.net/333974_3',
#  'Sharyland ISD': 'https://sharyland.ss8.sharpschool.com/cms/One.aspx?portalId=416234&pageId=27969037',
#  'Shelbyville ISD': 'http://www.shelbyville.k12.tx.us/',
#  'Sheldon ISD': 'https://www.sheldonisd.com/apps/pages/index.jsp?uREC_ID=1424662&type=d&pREC_ID=1592242',
#  'Sherman ISD': 'https://www.shermanisd.net/domain/13',
#  'Sidney ISD': 'http://www.sidney.esc14.net/default.aspx?SidneyISD/DistrictofInnovation',
#  'Sinton ISD': 'http://www.sintonisd.net/wp/index.php/district-of-innovation-doi/',
#  'Slaton ISD': 'http://www.slatonisd.net/cms/One.aspx?portalId=20790439&pageId=34810401',
#  'Slocum ISD': 'https://docs.google.com/viewer?a=v&pid=sites&srcid=c2xvY3VtaXNkLm9yZ3xzbG9jdW18Z3g6NzZjYWI1MjI5M2FlYTAyMA',
#  'Smithville ISD': 'https://www.smithvilleisd.org/apps/pages/index.jsp?uREC_ID=186546&type=d&pREC_ID=1396163',
#  'South San Antonio ISD': 'https://www.southsanisd.net/Page/5705',
#  'South Texas ISD': 'http://www.stisd.net/about_us/district_of_innovation',
#  'Spearman ISD': 'http://www.spearmanisd.net/?DivisionID=20362&ToggleSideNav',
#  'Splendora ISD: ': 'http://www.splendoraisd.org/domain/241',
#  'Spring Branch ISD': 'https://www.springbranchisd.com/about/board-of-trustees/district-of-innovation-doi',
#  'Spring Creek ISD': 'http://www.springcreekisd.net/vnews/display.v/SEC/District%7CDistrict%20of%20Innovation%3E%3EAbout',
#  'Spring ISD': 'http://www.springisd.org/doi',
#  'Springtown ISD': 'http://www.springtownisd.net/Page/8826',
#  'Stockdale ISD': 'http://www.stockdaleisd.org/vnews/display.v/SEC/Public%20Notice%7CDistrict%20of%20Innovation',
#  'Stratford ISD': 'http://www.stratfordisd.net/373775_3',
#  'Sudan ISD': 'http://www.sudanisd.net/administration/administration.asp',
#  'Sulphur Springs ISD': 'http://www.ssisd.net/page/District.Innovation',
#  'Sunnyvale ISD': 'http://www.sunnyvaleisd.com/site/default.aspx?PageType=3&ModuleInstanceID=8169&ViewID=C9E0416E-F0E7-4626-AA7B-C14D59F72F85&RenderLoc=0&FlexDataID=11226&PageID=6802',
#  'Sweet Home ISD': 'http://www.sweethomeisd.org/domain/46',
#  'Tarkington ISD': 'https://www.tarkingtonisd.net/279362_3',
#  'Teague ISD': 'http://www.teagueisd.org/domain/325',
#  'Temple ISD': 'https://www.tisd.org/apps/pages/index.jsp?uREC_ID=339306&type=d&pREC_ID=1511637',
#  'Tenaha ISD': 'http://www.tenahaisd.com/Page/1008',
#  'Texas City ISD': 'https://www.tcisd.org/our-district/district-of-innovation',
#  'Texline ISD': 'http://www.texlineisd.net/board',
#  'Thrall ISD': 'https://www.thrallisd.com/apps/pages/index.jsp?uREC_ID=285561&type=u&pREC_ID=1379313',
#  'Three Rivers ISD': 'http://www.trisd.org/district-reports-bd48d186',
#  'Three Way ISD': 'https://www.twisd.us/144516_2',
#  'Throckmorton ISD': 'https://throck.socs.net/vnews/display.v/ART/48ce762e8414b',
#  'Tidehaven ISD': 'http://www.tidehavenisd.com/home/district-information',
#  'Tom Bean ISD': 'http://www.tombean-isd.org/Page/1015',
#  'Tornillo ISD': 'http://www.tisd.us/district_accountability/district_of_innovation',
#  'Tyler ISD': 'https://www.tylerisd.org/Domain/5622',
#  'Union Grove ISD': 'http://www.ugisd.org/news/district-of-innovation',
#  'Utopia ISD': 'https://www.utopiaisd.net/district/district-of-innovation-plan',
#  'Uvalde CISD': 'https://www.ucisd.net/domain/82',
#  'Valentine ISD': 'http://www.valentineisd.com/search?orgId=14e1ec03-a9d7-410b-9ed6-68e6980bcb76&q=innovation',
#  'Van ISD': 'https://www.vanisd.org/Page/1213',
#  'Venus ISD': 'http://www.venusisd.net/news/district-of-innovation-plan',
#  'Vysehrad ISD': 'https://www.vysehrad.k12.tx.us/vnews/display.v/ART/5a7355dbc91bc',
#  'Waco ISD': 'https://www.wacoisd.org/doi',
#  'Waelder ISD': 'http://www.waelderisd.org/apps/news/article/700683',
#  'Wall ISD': 'http://www.wallisd.net/DocumentCenter/View/10597',
#  'Waskom ISD': 'http://www.waskomisd.net/District/1113-Required-Postings.html',
#  'Weatherford ISD': 'https://www.weatherfordisd.com/apps/pages/index.jsp?uREC_ID=236826&type=d&pREC_ID=1103946',
#  'Weimar ISD': 'http://www.weimarisd.org/page/district_info',
#  'West ISD': 'http://www.westisd.net/apps/pages/index.jsp?uREC_ID=669210&type=d&pREC_ID=1116410',
#  'West Orange-Cove CISD': 'http://www.woccisd.net/apps/pages/DOI',
#  'Westhoff ISD': 'http://westhoffisd.org/index.php/district-information',
#  'Wharton ISD': 'http://whartonisd.net/page/innovation',
#  'Wheeler ISD': 'http://www.wheelerschools.net/144389_2',
#  'White Deer ISD': 'https://www.whitedeerisd.net/23095_1',
#  'White Oak ISD': 'http://www.woisd.net/district-of-innovation/',
#  'White Settlement ISD': 'http://www.wsisd.com/apps/pages/index.jsp?uREC_ID=425104&type=d&pREC_ID=1145181',
#  'Whitharral ISD': 'https://docs.google.com/document/d/1QpBqSAmJNZKjmICICvlZ3JHEPmgfF2HCTBuUts9CBBI/edit',
#  'Whitney ISD': 'http://www.whitney.k12.tx.us/',
#  'Wichita Falls ISD': 'http://www.wfisd.net/Page/20552',
#  'Wildorado ISD': 'https://wildoradoisd.socs.net/vnews/display.v/ART/597b37c5393e1',
#  'Willis ISD': 'https://www.willisisd.org/Page/84',
#  'Wills Point ISD': 'https://resource.echalk.com/sr/wZAwqqL0',
#  'Winters ISD': 'http://www.wintersisd.org/apps/pages/index.jsp?uREC_ID=702554&type=d&pREC_ID=1135205',
#  'Woden ISD': 'http://www.wodenisd.org/home/district-announcements/districtofinnovation',
#  'Woodsboro ISD': 'https://docs.google.com/document/d/1dg3O2cF88tqTy1OCTPbUv9S2_oPegKY2dnDVXpczoEU/pub',
#  'Woodson ISD': 'https://sites.google.com/a/woodsonisd.net/woodsonisd/home/woodson-isd-s-district-of-innovation-plan',
#  'Wortham ISD': 'http://www.worthamisd.org/PublicAnnouncementsRequiredPostings',
#  'Wylie ISD (221912)': 'http://www.wyliebulldogs.org/cms/One.aspx?portalId=425740&pageId=10238852',
#  'Yantis ISD': 'http://www.yantisisd.net/',
#  'Yorktown ISD': 'http://www.yisd.org/News/11290#sthash.uv4FjhBq.dpbs',
#  'Zapata County ISD': 'https://www.zcisd.org/apps/pages/index.jsp?uREC_ID=1025460&type=d&pREC_ID=1328059',
#  'Zavalla ISD': 'http://www.zavallaisd.org/386577_3',
#  'Zephyr ISD': 'http://zephyrisd.net/policies-and-reporting/',
#  '\xa0Lake Travis ISD': 'https://www.ltisdschools.org/Page/2188'}

# %% [markdown]
# If we only want test the crawler, we should use a sample of seed links. Otherwise crawling can take up to half an hour to run.

# %%
if test_sample:
    seed_links = {v:seed_links[v] for v in [list(seed_links.keys())[k] for k in range(sample_size)]}

# %% [markdown]
# ## Second Level Links

# %%
print("Crawling", len(seed_links), "seed links.")
second_level_links = gather_documents.SecondLevelLinks(seed_links)
second_level_links_df = second_level_links.docs_df
second_level_links_df = second_level_links_df.reset_index()
second_level_links_df['level'] = "Second"
print("There are", len(second_level_links_df), "second level links.")
second_level_links_df.head()
# Out:
# Crawling 401 seed links.
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/kylieleblancKylie/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# error: Merkel ISD 'src'
# error: Merkel ISD 'src'
# error: Merkel ISD 'src'
# error: Galena Park ISD <urlopen error [Errno 8] nodename nor servname provided, or not known>
# error: Galena Park ISD <urlopen error [Errno 8] nodename nor servname provided, or not known>
# error: Galena Park ISD <urlopen error [Errno 8] nodename nor servname provided, or not known>
# error: Kress ISD [Errno 54] Connection reset by peer
# error: Lake Dallas ISD <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Lake Dallas ISD <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Lake Dallas ISD <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Lindale ISD 'src'
# error: Lindale ISD 'src'
# error: Lindale ISD 'src'
# error: Granbury ISD <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Granbury ISD <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Granbury ISD <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Pottsboro ISD 'src'
# error: Pottsboro ISD 'src'
# error: Pottsboro ISD 'src'
# error: Midway ISD (161903)  <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Midway ISD (161903)  <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Midway ISD (161903)  <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:719)>
# error: Anahuac ISD 'src'
# error: Anahuac ISD 'src'
# error: Anahuac ISD 'src'
# There are 3579 second level links.
#             title                                               link    type  \
# 0    Coolidge ISD  https://drive.google.com/open?id=1uIeBVaCcOaqN...  google
# 1      Celina ISD  https://www.celinaisd.com/wp-documents/Require...     pdf
# 2       Hooks ISD  http://www.hooksisd.net/users/STAAR%20Informat...     pdf
# 3      Albany ISD  http://www.albanyisd.net/uploads/4/4/4/1/44419...     pdf
# 4  Lago Vista ISD  http://www.lagovistaisd.net/upload/page/0026/d...     pdf
#
#     level
# 0  Second
# 1  Second
# 2  Second
# 3  Second
# 4  Second

# %% [markdown]
# ## HTML Links

# %% [markdown]
# A few DOI plans are simply stored as HTML. So we will also collect the seed links and treat these as possible documents as well.

# %%
html_links_df = pd.DataFrame.from_dict(seed_links, orient = 'index', columns = ['link'])
html_links_df = html_links_df.reset_index()
html_links_df = html_links_df.rename(index=str, columns={'index': 'title'})
type_col = ['html'] * len(html_links_df.index)
level_col = ['html'] * len(html_links_df.index)
html_links_df['type'] = type_col
html_links_df['level'] = level_col
print("We added", len(seed_links), "HTML links as possible documents.")
html_links_df.head(10)
# Out:
# We added 401 HTML links as possible documents.
#                title                                               link  type  \
# 0      Dickinson ISD  http://www.dickinsonisd.org/upload/page/0016/d...  html
# 1         Knippa ISD  https://docs.google.com/viewer?a=v&pid=sites&s...  html
# 2    Weatherford ISD  https://www.weatherfordisd.com/apps/pages/inde...  html
# 3       Banquete ISD         https://www.banqueteisd.esc2.net/domain/18  html
# 4  Alamo Heights ISD  http://www.ahisd.net/news/what_s_new/district_...  html
# 5     Round Rock ISD   https://roundrockisd.org/district-of-innovation/  html
# 6      La Vernia ISD                    https://www.lvisd.org/Page/1083  html
# 7   Port Aransas ISD   http://www.paisd.net/home/district-of-innovation  html
# 8       Angleton ISD  https://www.angletonisd.net//site/default.aspx...  html
# 9          Alvin ISD                 http://www.alvinisd.net/innovation  html
#
#   level
# 0  html
# 1  html
# 2  html
# 3  html
# 4  html
# 5  html
# 6  html
# 7  html
# 8  html
# 9  html

# %% [markdown]
# ## Combine first, second, and html links

# %%
links_scraped = first_level_links_df.append(second_level_links_df)
links_scraped = links_scraped.reset_index()
links_scraped = links_scraped.append(html_links_df, sort = True)
links_scraped = links_scraped.drop(['index'], axis = 1)
links_scraped = links_scraped[['title', 'level', 'type', 'link']]
print("We have", len(links_scraped), "scraped links which may be DOI documents.")
links_scraped.head()
# Out:
# We have 4415 scraped links which may be DOI documents.
#            title  level type  \
# 0    Abilene ISD  First  pdf
# 1   Carlisle ISD  First  pdf
# 2    Lockney ISD  First  pdf
# 3  Arlington ISD  First  pdf
# 4      Paris ISD  First  pdf
#
#                                                 link
# 0  https://www.abileneisd.org/wp-content/uploads/...
# 1  https://s3.amazonaws.com/scschoolfiles/83/carl...
# 2  https://s3.amazonaws.com/scschoolfiles/777/doi...
# 3  http://w4.aisd.net/pdf/District-of-Innovation-...
# 4  https://s3.amazonaws.com/scschoolfiles/167/doi...

# %% [markdown]
# But some of these are duplicates

# %%
links_scraped = links_scraped.drop_duplicates(subset = 'link')
print(len(links_scraped), "after dropping duplicates.")
# Out:
# 3995 after dropping duplicates.

# %% [markdown]
# ## Save

# %%
if test_sample == False:
    links_scraped.to_csv(os.path.join(data_path, 'links_scraped.csv'))

# %%
links = pd.read_csv(os.path.join(data_path, 'links_scraped.csv'))
links.head()
# Out:
#    Unnamed: 0          title  level type  \
# 0           0    Abilene ISD  First  pdf
# 1           1   Carlisle ISD  First  pdf
# 2           2    Lockney ISD  First  pdf
# 3           3  Arlington ISD  First  pdf
# 4           4      Paris ISD  First  pdf
#
#                                                 link
# 0  https://www.abileneisd.org/wp-content/uploads/...
# 1  https://s3.amazonaws.com/scschoolfiles/83/carl...
# 2  https://s3.amazonaws.com/scschoolfiles/777/doi...
# 3  http://w4.aisd.net/pdf/District-of-Innovation-...
# 4  https://s3.amazonaws.com/scschoolfiles/167/doi...

# %%
links[(links.title == "Abbott ISD")][['title', 'link']].sort_values(by = 'title').to_csv(os.path.join(data_path, 'links_scraped_snippet.csv'))

# %%
for link in links[(links.title == "Broaddus ISD")].link:
    print(link)
# Out:
# https://core-docs.s3.amazonaws.com/documents/asset/uploaded_file/283241/Broaddus_ISD_Dist_of_Innov_2018-2019.pdf

# %%
len(links)
# Out:
# 3995
