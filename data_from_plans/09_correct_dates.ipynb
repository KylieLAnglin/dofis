# %%
import os
# %matplotlib inline
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from start import data_path

# %%
data = pd.read_csv(os.path.join(data_path,'doi_dates_and_exemptions.csv'), sep=",")
data = data[['title', 'link', 'date_year', 'date_phrase']]
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x90 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-22-4f09d5a9b83c> in <module>()
# ----> 1 data = pd.read_csv(os.path.join(data_path,'doi_dates_and_exemptions.csv'), sep=",")
#       2 data = data[['title', 'link', 'date_year', 'date_phrase']]
#       3 data.head()
#
# ...

# %%
data.to_csv(os.path.join(data_path,'fix_dates.csv'))

# %% [markdown]
# ### Add column called correct. Put correct year in this column. Save as fix_dates_corrected.csv. Then upload.

# %%
#TODO move this to cleaning file
old_year = pd.read_csv(os.path.join(data_path,'doi_dates_and_exemptions.csv'), sep=",").drop(['doi_year'], axis = 1)
new_year = pd.read_csv(os.path.join(data_path, 'fix_dates_corrected.csv'), sep=",")
new_year = new_year[['title', 'correct']]
new_year = new_year.rename(columns = {'correct':'doi_year'})
new_year = new_year[['title', 'doi_year']]
new_year.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-5fd000e1a10d> in <module>()
#       1 #TODO move this to cleaning file
# ----> 2 old_year = pd.read_csv(os.path.join(data_path,'doi_dates_and_exemptions.csv'), sep=",").drop(['doi_year'], axis = 1)
#       3 new_year = pd.read_csv(os.path.join(data_path, 'fix_dates_corrected.csv'), sep=",")
#       4 new_year = new_year[['title', 'correct']]
#       5 new_year = new_year.rename(columns = {'correct':'doi_year'})
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
# ...

# %%
data = old_year.merge(new_year, left_on = 'title', right_on = 'title', how = 'left')
data.to_csv(os.path.join(data_path,'doi_dates_and_exemptions.csv'),
                  sep=",")
data.head()
# Out:
#    Unnamed: 0          title  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0     Abbott ISD         780.0          2481.0              2481
# 1           1  Abernathy ISD         779.0           871.0               871
# 2           2    Abilene ISD         778.0            85.0                85
# 3           3    Academy ISD         777.0          2845.0              2845
# 4           4     Adrian ISD         776.0           169.0               169
#
#    Unnamed: 0.1.1.1.1   level  type  \
# 0                2481  Second   pdf
# 1                 871  Second   pdf
# 2                  85   First   pdf
# 3                2845  Second  docx
# 4                 169   First   pdf
#
#                                                 link  \
# 0  https://www.abbottisd.org/ourpages/auto/2018/3...
# 1  https://1.cdn.edl.io/epGD4mZXjWUcPl8yA7IhlcDol...
# 2  https://www.abileneisd.org/wp-content/uploads/...
# 3  https://4.files.edl.io/1a8f/06/29/18/204245-44...
# ...

# %%
data.doi_year.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-bb4b19ccf5ad> in <module>()
# ----> 1 data.doi_year.value_counts()
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'doi_year'

# %%
data
# Out:
#      Unnamed: 0                 title  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0             0            Abbott ISD         780.0          2481.0
# 1             1         Abernathy ISD         779.0           871.0
# 2             2           Abilene ISD         778.0            85.0
# 3             3           Academy ISD         777.0          2845.0
# 4             4            Adrian ISD         776.0           169.0
# 5             5        Agua Dulce ISD         775.0          1868.0
# 6             6     Alamo Heights ISD         774.0          1824.0
# 7             7            Albany ISD         773.0          1886.0
# 8             8            Aldine ISD         772.0          2681.0
# 9             9             Alice ISD         771.0           176.0
# 10           10             Alief ISD         770.0          2454.0
# 11           11             Allen ISD         769.0          1301.0
# 12           12            Alpine ISD         768.0            84.0
# ...
