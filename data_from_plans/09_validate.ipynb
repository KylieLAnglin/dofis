# %%
import pandas as pd
import os
from start import data_path

# %%
labeled_docs = pd.read_csv(os.path.join(data_path, 'sample_laws_filledin.csv'))
labeled_docs
# Out:
#     Unnamed: 0              title  \
# 0          552          Evant ISD
# 1          687           Buna ISD
# 2          759          Anson ISD
# 3           31     White Deer ISD
# 4          692          Bryan ISD
# 5          392        La Vega ISD
# 6          135         Sidney ISD
# 7           62    Valley View ISD
# 8          686    Burkburnett ISD
# 9          621      Community ISD
# 10         701     Bridgeport ISD
# 11         592        De Leon ISD
# 12          30      White Oak ISD
# 13         668       Carlisle ISD
# 14         722         Blanco ISD
# 15         575         Dublin ISD
# 16         194        Ricardo ISD
# 17         624       Comanche ISD
# 18         477         Hardin ISD
# 19         685     Burkeville ISD
# 20         187     River Road ISD
# 21         426  Jayton-Girard ISD
# 22         393       La Porte ISD
# 23         312          Miami ISD
# 24         571          Eanes ISD
# 25         582            Dew ISD
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fcb26bcc00cc> in <module>()
# ----> 1 len(labeled_docs[(labeled_docs.label == NaN)])
#
# NameError: name 'NaN' is not defined

# %%
labeled_docs
# Out:
#      Unnamed: 0                   title  label  \
# 0          3816           Big Sandy ISD  False
# 1           372              Conroe ISD   True
# 2          1412          Montgomery ISD  False
# 3          3971          Brazosport ISD  False
# 4           602         Shelbyville ISD  False
# 5          3162      Hughes Springs ISD   True
# 6          1306              Weimar ISD  False
# 7          3783             Bremond ISD  False
# 8          3327        Rosebud-Lott ISD   True
# 9          3935              Ponder ISD  False
# 10         1950         Chillicothe ISD  False
# 11         3324        Marble Falls ISD   True
# 12         2417              Thrall ISD  False
# 13          315      Patton Springs ISD   True
# 14         2431         Chillicothe ISD  False
# 15         2317           Jacksboro ISD  False
# 16         3365     Sulphur Springs ISD  False
# 17          949              Celina ISD  False
# 18         2623          Clarendon CISD  False
# ...
