# %% [markdown]
# # One hot save and clean

# %%
import pandas as pd
import csv
import os


from start import data_path

# %%
laws_df = pd.read_csv(os.path.join(data_path, 'doi_exemptions_list.csv'))
dates_df = pd.read_csv(os.path.join(data_path, 'doi_dates.csv'))
doi_df = laws_df.merge(dates_df, left_on = 'title', right_on = 'title', how = 'left')
print(len(laws_df))
print(len(dates_df))
print(len(doi_df))
doi_df.sample(5)
# Out:
# 824
# 824
# 824
#                  title  Unnamed: 0_x  Unnamed: 0.1  Unnamed: 0.1.1  \
# 540  Nixon-Smiley CISD          39.0           428             428
# 168  Como-Pickton CISD         655.0          2038            2038
# 47        Bay City ISD         776.0          1692            1692
# 822         Zephyr ISD           1.0          1913            1913
# 204         Denton ISD         619.0          3735            3735
#
#      Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1   level  type  \
# 540               428                 428   First   pdf
# 168              2038                2251  Second   pdf
# 47               1692                1864  Second   pdf
# 822              1913                2108  Second  docx
# 204              3735                 132    html  html
#
#                                                   link  \
# 540  https://core-docs.s3.amazonaws.com/documents/a...
# 168  https://s3.amazonaws.com/scschoolfiles/976/rev...
# 47   https://www.bcblackcats.net/site/handlers/file...
# 822  http://zephyrisd.net/wp-content/uploads/2014/0...
# 204                http://www.dentonisd.org/Page/84561
#
#                                                   text  p_innovation  \
# 540  DOI Plan Final Feb 7.pdf 1 Final February 7, 2...      0.999955
# 168  Original Board Approval 3/23/2017 Revised Boar...      0.999955
# 47   Bay City ISD DISTRICT OF INNOVATION PLAN Intro...      0.999498
# 822  Zephyr ISD District of Innovation Plan Introdu...      0.999955
# 204  District of Innovation / Denton ISD District o...      0.544300
#
#                                          possible_laws  Unnamed: 0_y  \
# 540  [11.251, 11.252, 11.253, 11.255, 21.003, 21.05...           283
# 168          [25.0811, 21.003, 21.102, 21.401, 25.081]           655
# 47                                           [25.0811]           776
# 822                  [25.036, 21.003, 21.102, 25.0811]             1
# 204  [11.255, 11.252, 11.251, 28.214, 28.0021, 28.2...           619
#
#        doi_date
# 540  2018-02-01
# 168  2016-08-01
# 47   2017-04-01
# 822  2018-09-01
# 204  2017-01-01

# %%
doi_df.to_csv(os.path.join(data_path,'doi_exemptions_and_dates.csv'))

# %%
dates_df
# Out:
#      Unnamed: 0              title    doi_date
# 0             0    Lake Travis ISD  2016-12-01
# 1             1         Zephyr ISD  2018-09-01
# 2             2        Zavalla ISD  2017-08-01
# 3             3  Zapata County ISD  2018-08-01
# 4             4       Yorktown ISD  2017-08-01
# ..          ...                ...         ...
# 819         819         Adrian ISD  2018-08-01
# 820         820        Academy ISD  2018-08-01
# 821         821        Abilene ISD  2018-08-01
# 822         822      Abernathy ISD  2017-01-01
# 823         823         Abbott ISD  2018-03-01
#
# [824 rows x 3 columns]
