# %% [markdown]
# # Extract dates from text

# %%
import os
import pandas as pd
import extract_dates
import spacy
from start import data_path

# %%
docs = pd.read_csv(os.path.join(data_path, 'text_narrowed.csv'))
docs
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1               title   level  \
# 0          1323          1323            1451     Lake Travis ISD  Second
# 1          1913          1913            2108          Zephyr ISD  Second
# 2          1895          1895            2089         Zavalla ISD  Second
# 3           577           577             596   Zapata County ISD  Second
# 4          1784          1784            1967        Yorktown ISD  Second
# 5           163           163             163          Yoakum ISD   First
# 6          2173          2173            2410          Yantis ISD  Second
# 7          3713          3713             109  Wylie ISD (221912)    html
# 8            32            32              32  Wylie ISD (043914)   First
# 9          1659          1659            1828         Wortham ISD  Second
# 10           48            48              48       Woodville ISD   First
# 11         3634          3634              29         Woodson ISD    html
# 12           41            41              41       Woodsboro ISD   First
# 13          389           389             389      Wolfe City ISD   First
# 14         3870          3870             269           Woden ISD    html
# 15         2820          2820            3129         Winters ISD  Second
# 16          102           102             102       Winnsboro ISD   First
# 17          129           129             129     Wink-Loving ISD   First
# 18           45            45              45      Windthorst ISD   First
# 19          196           196             196       Wimberley ISD   First
# 20         3946          3946             350     Wills Point ISD    html
# 21         1837          1837            2023          Willis ISD  Second
# 22         2494          2494            2773       Wildorado ISD  Second
# 23         1389          1389            1532   Wichita Falls ISD  Second
# 24          699           699             740         Whitney ISD  Second
# 25          282           282             282      Whitharral ISD   First
# 26          232           232             232     Whitewright ISD   First
# 27          326           326             326      Whitesboro ISD   First
# 28          127           127             127     Whitehouse ISD    First
# 29          287           287             287      Whiteface CISD   First
# ..          ...           ...             ...                 ...     ...
# 794         176           176             176          Argyle ISD   First
# 795        3401          3401            3786     Archer City ISD  Second
# 796          43            43              43  Aransas County ISD   First
# 797         175           175             175         Aquilla ISD   First
# 798        3799          3799             198   Apple Springs ISD    html
# 799         288           288             288         Anthony ISD   First
# 800        2457          2457            2730           Anson ISD  Second
# 801        2835          2835            3145            Anna ISD  Second
# 802        2996          2996            3326        Angleton ISD  Second
# 803        1614          1614            1780         Andrews ISD  Second
# 804        3937          3937             339         Anahuac ISD    html
# 805          65            65              65        Amarillo ISD   First
# 806         391           391             391          Alvord ISD   First
# 807        1151          1151            1261           Alvin ISD  Second
# 808         214           214             214        Alvarado ISD   First
# 809         264           264             264            Alto ISD   First
# 810         329           329             329          Alpine ISD   First
# 811        3105          3105            3451           Allen ISD  Second
# 812        1422          1422            1569           Alief ISD  Second
# 813         113           113             113           Alice ISD   First
# 814        3507          3507            3906           Aledo ISD  Second
# 815        1974          1974            2176          Aldine ISD  Second
# 816         438           438             438          Albany ISD  Second
# 817        2586          2586            2876   Alamo Heights ISD  Second
# 818         627           627             658      Agua Dulce ISD  Second
# 819         125           125             125          Adrian ISD   First
# 820         893           893             962         Academy ISD  Second
# 821           0             0               0         Abilene ISD   First
# 822         820           820             878       Abernathy ISD  Second
# 823        1941          1941            2139          Abbott ISD  Second
#
#        type                                               link  \
# 0       pdf  https://www.ltisdschools.org//cms/lib/Tx018000...
# 1      docx  http://zephyrisd.net/wp-content/uploads/2014/0...
# 2       pdf  https://s3.amazonaws.com/scschoolfiles/1772/za...
# 3       pdf  https://1.cdn.edl.io/VZ6fi1M6pn8Qk8tS3GetGewCD...
# 810  Alpine Independent School District Alpine ISD ...      0.999955
# 811  Allen Independent School District Local Innova...      0.999342
# 812  Alief District of Innovation Plan Approved by ...      0.999894
# 813  Microsoft Word - District of Innovation Docume...      0.998974
# 814  BLT & DOI Committee Activity District of Innov...      0.143208
# 815  Aldine District of Innovation Plan Approved by...      0.999702
# 816  Microsoft Word - innovation_plan.docx Albany I...      0.999931
# 817  1 | P a g e Mission Statement The Alamo Height...      0.997152
# 818  Microsoft Word - DOI 2017-2022.docx Agua Dulce...      0.999955
# 819  Adrian ISD District of Innovation Plan House B...      0.999945
# 820  District of Innovation Plan Developed in coope...      0.999836
# 821  0 ABILENE INDEPENDENT SCHOOL DISTRICT Local In...      0.999955
# 822  Abernathy ISD District of Innovation Plan – Dr...      0.998340
# 823  1 Abbott Independent School District District ...      0.999949
#
# [824 rows x 9 columns]

# %% [markdown]
# ## Term Dates
# Identify most likely term date phrase from text using classifier. Extract earliest year (and month, if available) from that phrase.

# %%
output_dir = os.path.join(data_path, 'date_term_classifier')
nlp = spacy.load(output_dir)

# %%
start_dates = []
date_phrases = []
p_terms = []
months = []
for text in docs.text:
    year, month, phrase, p = extract_dates.get_term_date_and_phrase(text, output_dir)
    start_dates.append(year)
    months.append(month)
    date_phrases.append(phrase)        
    p_terms.append(p)

# %%
docs['term_year'] = start_dates
docs['term_month'] = months
docs['term_phrase'] = date_phrases
docs['term_p'] = p_terms

# %% [markdown]
# ## Finalize plan date
# Identify most likely finalize date phrase from text using classifier and use latest (in terms of both year and month) as the date of finalization.

# %%
output_dir = os.path.join(data_path, 'date_finalize_classifier')
nlp = spacy.load(output_dir)

# %%
finalize_years = []
finalize_months = []
finalize_phrases = []
finalize_p = []
for text in docs.text:
    year, month, phrase, p  = extract_dates.get_finalize_month_year_phrase(text, output_dir)
    finalize_years.append(year)
    finalize_months.append(month)
    finalize_phrases.append(phrase)
    finalize_p.append(p)

# %%
docs['finalize_year'] = finalize_years
docs['finalize_month'] = finalize_months
docs['finalize_phrase'] = finalize_phrases
docs['finalize_p'] = finalize_p

# %% [markdown]
# # Create year and month column
# For now, term is prioritized. If there is a likely term year (> .9 probability) use that year as the term year. If there is a month, extract that as well. If there is no month, we assume the term is referring to an academic year.
#
# If there is no term phrase, use the finalize phrase instead.

# %%
docs.loc[docs.term_p >= .9, 'date_year'] = docs.term_year
docs.loc[docs.term_p >= .9, 'date_month'] = docs.term_month
docs.loc[docs.term_p >= .9, 'date_phrase'] = docs.term_phrase

docs.loc[docs.term_p < .9, 'date_year'] = docs.finalize_year
docs.loc[docs.term_p < .9, 'date_month'] = docs.finalize_month
docs.loc[docs.term_p < .9, 'date_phrase'] = docs.finalize_phrase

docs.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1              title   level  type  \
# 0        1323          1323            1451    Lake Travis ISD  Second   pdf
# 1        1913          1913            2108         Zephyr ISD  Second  docx
# 2        1895          1895            2089        Zavalla ISD  Second   pdf
# 3         577           577             596  Zapata County ISD  Second   pdf
# 4        1784          1784            1967       Yorktown ISD  Second   pdf
#
#                                                 link  \
# 0  https://www.ltisdschools.org//cms/lib/Tx018000...
# 1  http://zephyrisd.net/wp-content/uploads/2014/0...
# 2  https://s3.amazonaws.com/scschoolfiles/1772/za...
# 3  https://1.cdn.edl.io/VZ6fi1M6pn8Qk8tS3GetGewCD...
# 4  http://www.yisd.org/userfiles/57/my%20files/fi...
#
#                                                 text  p_innovation  term_year  \
# 0  LTISD Plan of Innovation LAKE TRAVIS INDEPENDE...      0.999890       2017
# 1  Zephyr ISD District of Innovation Plan Introdu...      0.999922       2018
# 2  Zavalla ISD District of Innovation Plan (HB 18...      0.999619       2017
# 3  Microsoft Word - Document1 ZAPATA COUNTY INDEP...      0.452118       2017
# 4  Yorktown Independent School District Final Dis...      0.999877       2017
#
#           term_month                                        term_phrase  \
# 0            (999, )  : 1. Beginning with the 2017-2018 academic yea...
# 1  (2018, September)  Term The District of Innovation Plan will beco...
# 2            (999, )  This plan will be in effect for the 2017-2018 ...
# 3   (2017, December)  a District of Innovation on Tuesday, December ...
# 4            (999, )  Yorktown Independent School District Final Dis...
#
#      term_p  finalize_year finalize_month  \
# 0  0.999955           2016       December
# 1  0.999955           2018          April
# 2  0.999955           2017       February
# 3  0.000187           2017       December
# 4  0.999955           2017            May
#
#                                      finalize_phrase  finalize_p  date_year  \
# 0  hold a public meeting on December 13, 2016 to ...    0.996723     2017.0
# 1  go to the Board on April 16th, 2018. Term The ...    0.889274     2018.0
# 2  27,2017 Final version plan posted January 27, ...    0.999955     2017.0
# 3  a District of Innovation on Tuesday, December ...    0.999884     2017.0
# 4  of the letter. On May 15, 2017 the District Co...    0.972258     2017.0
#
#           date_month                                        date_phrase
# 0            (999, )  : 1. Beginning with the 2017-2018 academic yea...
# 1  (2018, September)  Term The District of Innovation Plan will beco...
# 2            (999, )  This plan will be in effect for the 2017-2018 ...
# 3           December  a District of Innovation on Tuesday, December ...
# 4            (999, )  Yorktown Independent School District Final Dis...

# %% [markdown]
# ## Create academic year column
# 2017 refers to 2017-18 ay. 2016 to 2016-17 ay, etc. Standardized testing occurs generally occurs in April. So, a district will be considered 'treated' for the current academic year if their implementation occurs before April.

# %%
docs['date_ay'] = docs.date_year
docs.loc[docs.date_month.isin(['January', 'February', 'March']), 'date_ay'] = docs.date_year - 1

# %% [markdown]
# # Save

# %%
docs.to_csv(os.path.join(data_path, 'doi_dates_scraped.csv'))

# %% [markdown]
# # Descriptives

# %% [markdown]
# ### Export to csv to manually note whether year and month are correct.

# %%
test_docs = docs[docs.p_innovation > .5].sample(n = 30, random_state = 5)
test_docs['correct_month'] = ''
test_docs['correct_year'] = ''
test_docs['correct_ay'] = ''

# %%
test_docs.to_csv(os.path.join(data_path, 'sample_dates.csv'))

# %% [markdown]
# ### Fill in TRUE or FALSE in correct_month and correct_year if correct month/year were extracted. If there is no year or month and one wasn't extracted, consider the month and/or year correct.

# %%
#TODO change test to academic year instead of month and year separately

# %%
test_docs_correct = pd.read_csv(os.path.join(data_path, 'sample_dates_filledin.csv'))
test_docs_correct = test_docs_correct.replace({'FALSE': 'False', 'TRUE': 'True'})

# %%
print('Approximately {0:.0%} percent of extracted years are correct.'.format(test_docs_correct['correct_year'].mean()))
print('Approximately {0:.0%} percent of extracted months are correct.'.format(test_docs_correct['correct_month'].mean()))
print('Approximately {0:.0%} percent of extracted academic years are correct.'.format(test_docs_correct['correct_ay'].mean()))
# Out:
# Approximately 93% percent of extracted years are correct.
# Approximately 81% percent of extracted months are correct.
# Approximately 93% percent of extracted academic years are correct.
