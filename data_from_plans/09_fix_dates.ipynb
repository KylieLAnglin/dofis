# %%
import os
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
from random import randint
from start import data_path

# %%
data = pd.read_csv(os.path.join(data_path,'doi_dates_scraped.csv'), sep=",")
len(data)
# Out:
# 824

# %% [markdown]
# There are two ways we can determine dates - the term put forward in the plan (this is almost always just a school year) or the date a plan was finalized. We prefer the term date. However, when the term is not notes, we count the implementation date as the latest date in the DOI timeline (hopefully, the date the plan was adopted - finalize_year).

# %%
data[['title', 'term_phrase', 'term_year', 'term_month', 'finalize_phrase', 'finalize_year', 'finalize_month', 'link']].head()
# Out:
#                title                                        term_phrase  \
# 0    Lake Travis ISD  : 1. Beginning with the 2017-2018 academic yea...
# 1         Zephyr ISD  Term The District of Innovation Plan will beco...
# 2        Zavalla ISD  This plan will be in effect for the 2017-2018 ...
# 3  Zapata County ISD                                                NaN
# 4       Yorktown ISD  Yorktown Independent School District Final Dis...
#
#    term_year           term_month  \
# 0       2017            (999, '')
# 1       2018  (2018, 'September')
# 2       2017            (999, '')
# 3       -999            (999, '')
# 4       2017            (999, '')
#
#                                      finalize_phrase  finalize_year  \
# 0  hold a public meeting on December 13, 2016 to ...           2016
# 1  go to the Board on April 16th, 2018. Term The ...           2018
# 2  27,2017 Final version plan posted January 27, ...           2017
# 3                                                NaN           -999
# 4  of the letter. On May 15, 2017 the District Co...           2017
#
#   finalize_month                                               link
# 0       December  https://www.ltisdschools.org//cms/lib/Tx018000...
# 1          April  http://zephyrisd.net/wp-content/uploads/2014/0...
# 2       February  https://s3.amazonaws.com/scschoolfiles/1772/za...
# 3            NaN  https://1.cdn.edl.io/VZ6fi1M6pn8Qk8tS3GetGewCD...
# 4            May  http://www.yisd.org/userfiles/57/my%20files/fi...

# %%
# Scraped links
fixdates_scraped = data[['title', 'term_phrase', 'term_year',
                        'finalize_phrase', 'finalize_year', 'finalize_month', 'link']]
fixdates_scraped = fixdates_scraped.rename(columns = 
                                           {'term_year': 'term_year_scraped',
                                            'finalize_year': 'finalize_year_scraped',
                                            'finalize_month': 'finalize_month_scraped'})
fixdates_scraped
# Out:
#                  title                                        term_phrase  \
# 0      Lake Travis ISD  : 1. Beginning with the 2017-2018 academic yea...
# 1           Zephyr ISD  Term The District of Innovation Plan will beco...
# 2          Zavalla ISD  This plan will be in effect for the 2017-2018 ...
# 3    Zapata County ISD                                                NaN
# 4         Yorktown ISD  Yorktown Independent School District Final Dis...
# ..                 ...                                                ...
# 819         Adrian ISD  term of up to five years beginning June 2018 a...
# 820        Academy ISD  2018-2019 school year and concluding at the en...
# 821        Abilene ISD  ABILENE INDEPENDENT SCHOOL DISTRICT Local Inno...
# 822      Abernathy ISD  of Innovation Plan – Draft Introduction House ...
# 823         Abbott ISD  for the next five years (March 2018-February 2...
#
#      term_year_scraped                                    finalize_phrase  \
# 0                 2017  hold a public meeting on December 13, 2016 to ...
# 1                 2018  go to the Board on April 16th, 2018. Term The ...
# 2                 2017  27,2017 Final version plan posted January 27, ...
# 3                 -999                                                NaN
# 4                 2017  of the letter. On May 15, 2017 the District Co...
# ..                 ...                                                ...
# 819               2018                                                NaN
# 820               2018  regularly scheduled board meeting on June 28, ...
# 821               2018  the AISD Board of Trustees April 9, 2018 1 Boa...
# 822               -999  the Texas Education Code. On Thursday, January...
# 823               2023  Abbott Independent School District District of...
#
#      finalize_year_scraped finalize_month_scraped  \
# 0                     2016               December
# 1                     2018                  April
# 2                     2017               February
# 3                     -999                    NaN
# 4                     2017                    May
# ..                     ...                    ...
# 819                   -999                    NaN
# 820                   2018                   June
# 821                   2018                  April
# 822                   2017                January
# 823                   2018               February
#
#                                                   link
# 0    https://www.ltisdschools.org//cms/lib/Tx018000...
# 1    http://zephyrisd.net/wp-content/uploads/2014/0...
# 2    https://s3.amazonaws.com/scschoolfiles/1772/za...
# 3    https://1.cdn.edl.io/VZ6fi1M6pn8Qk8tS3GetGewCD...
# 4    http://www.yisd.org/userfiles/57/my%20files/fi...
# ..                                                 ...
# 819  http://www.adrianisd.net/UserFiles/Servers/Ser...
# 820  https://4.files.edl.io/1a8f/06/29/18/204245-44...
# 821  https://www.abileneisd.org/wp-content/uploads/...
# 822  https://1.cdn.edl.io/epGD4mZXjWUcPl8yA7IhlcDol...
# 823  https://www.abbottisd.org/ourpages/auto/2018/3...
#
# [824 rows x 7 columns]

# %%
# Manual links
fixdates_manual = pd.read_csv(os.path.join(data_path, 'fix_dates_corrected.csv'), 
                              encoding = 'latin-1')
fixdates_manual = fixdates_manual[['title','corrected', 'term_year',
                                   'finalize_year', 'finalize_month']]
print(len(fixdates_manual))
fixdates_manual.sample(10)
# Out:
# 824
#                    title  corrected  term_year  finalize_year finalize_month
# 299          Mumford ISD          1     2017.0            NaN            NaN
# 578        Fairfield ISD          1        NaN         2017.0           June
# 647  Corrigan-Camden ISD          1     2018.0         2018.0            May
# 762            Bland ISD          1     2017.0         2017.0          April
# 442         Jim Ned CISD          1     2019.0         2019.0          March
# 772         Bellevue ISD          1     2017.0         2017.0          April
# 257       Palo Pinto ISD          1     2017.0         2017.0          April
# 363         Lovelady ISD          1     2018.0            NaN            NaN
# 513        Groesbeck ISD          1     2019.0         2019.0       February
# 298          Munday CISD          1     2017.0         2017.0          March

# %%
# Merge scraped with manual
fixdates = fixdates_scraped.merge(fixdates_manual, how = 'left', 
                                  left_on = 'title', right_on = 'title')

fixdates.loc[fixdates.corrected > 0, 'term_year'] = fixdates_manual.term_year
fixdates.loc[fixdates.corrected == 0, 'term_year'] = fixdates_scraped.term_year_scraped
fixdates.loc[fixdates.corrected > 0, 'finalize_year'] = fixdates_manual.finalize_year
fixdates.loc[fixdates.corrected == 0, 'finalize_year'] = fixdates_scraped.finalize_year_scraped
fixdates.loc[fixdates.corrected > 0, 'finalize_month'] = fixdates_manual.finalize_month
fixdates.loc[fixdates.corrected == 0, 'finalize_month'] = fixdates_scraped.finalize_month_scraped

fixdates = fixdates[['corrected',  'title', 'term_phrase', 'term_year', 'finalize_phrase', 'finalize_year', 'finalize_month', 'link']]
fixdates.to_csv(os.path.join(data_path,'fix_dates.csv'))
fixdates.sample(10)
# Out:
#      corrected               title  \
# 8          1.0  Wylie ISD (043914)
# 602        1.0    East Bernard ISD
# 616        1.0          Devers ISD
# 21         1.0          Willis ISD
# 473        1.0     Honey Grove ISD
# 67         1.0         Uvalde CISD
# 670        1.0         Clifton ISD
# 816        1.0          Albany ISD
# 757        1.0            Blum ISD
# 762        1.0           Bland ISD
#
#                                            term_phrase  term_year  \
# 8    INNOVATION PLAN INTRODUCTION House Bill (HB) 1...     2017.0
# 602  August 1, 2017 and ending July 31, 2022, unles...     2017.0
# 616  will be in effect from July 1, 2017 through Ju...     2017.0
# 21                                                 NaN        NaN
# 473  in effect for the next five years (2017-2022)....     2017.0
# 67                                                 NaN     2017.0
# 670  2018-2019 school year and concluding at the en...     2018.0
# 816  The Local Innovation Plan Committee met Februa...     2017.0
# 757  BLUM Independent School District District of I...     2017.0
# 762                                                NaN     2017.0
#
#                                        finalize_phrase  finalize_year  \
# 8    . The Committee met on December 14, 2016 and J...            NaN
# 602  Adopted by EBISD Board: March 6, 2017 East Ber...         2017.0
# 616                                                NaN            NaN
# 21                                                 NaN         2017.0
# 473  for the next five years (2017-2022). Timeline ...         2017.0
# 67                                                 NaN         2017.0
# 670                                                NaN            NaN
# 816  Local Innovation Plan at the March 20, 2017 re...         2017.0
# 757  to the Commissioner of Education May 15, 2017 ...         2017.0
# 762                                                NaN         2017.0
#
#     finalize_month                                               link
# 8            March  http://www.wylieisd.net/cms/lib09/TX01918453/C...
# 602          March  https://1.cdn.edl.io/m2Y7mQEE9cI2UzC82atSqsOMQ...
# 616            NaN  https://drive.google.com/file/d/0B0nU_nqsdRSKZ...
# 21           April  https://tx50000123.schoolwires.net//cms/lib/TX...
# 473       February  https://s3.amazonaws.com/scschoolfiles/1549/di...
# 67           March                    https://www.ucisd.net/domain/82
# 670            NaN  https://1.cdn.edl.io/gwZxglY39ZfMkIchj28gRYDXK...
# 816          March  http://www.albanyisd.net/uploads/4/4/4/1/44419...
# 757            May  http://blumisd.net/UserFiles/Servers/Server_77...
# 762          April  https://drive.google.com/file/d/0B0CSbOD5Zf1md...

# %% [markdown]
# ### Check term and finalize year and month. Edit if incorrect if incorrectly missing. Then change corrected to 1 if corrected, zero if correct (2 if corrected from TEA). Delete -999 if correctly missing.

# %%
fixed_dates = pd.read_csv(os.path.join(data_path, 'fix_dates_corrected.csv'), 
                          encoding = 'latin-1')

# %%
value = randint(0, 824)
value
# Out:
# 267

# %%
# Ensure order does not change between data and fixed_dates

# %%
fixed_dates.loc[value].title
# Out:
# 'Olton ISD'

# %%
data.loc[value].title
# Out:
# 'Olton ISD'

# %%
# If order does not change,
fixed_dates['title'] = data.title

# %%
fixed_dates.loc[fixed_dates.term_year == -999, 'term_year'] = np.nan

print(fixed_dates.term_year.value_counts())
len(fixed_dates[pd.isnull(fixed_dates.term_year)])
# Out:
# 2017.0    491
# 2018.0    115
# 2016.0     46
# 2019.0     18
# 2015.0      1
# Name: term_year, dtype: int64
# 153

# %%
fixed_dates.loc[fixed_dates.finalize_year == -999, 'finalize_year'] = np.nan

print(fixed_dates.finalize_year.value_counts())
len(fixed_dates[pd.isnull(fixed_dates.finalize_year)])
# Out:
# 2017.0    484
# 2018.0    125
# 2016.0     60
# 2019.0     17
# Name: finalize_year, dtype: int64
# 138

# %% [markdown]
# Set doi_year as term year if available. Otherwise, finalize year

# %%
fixed_dates['doi_year'] = np.nan
fixed_dates.loc[pd.notnull(fixed_dates.term_year), 'doi_year'] = fixed_dates.term_year
fixed_dates.loc[pd.isnull(fixed_dates.term_year), 'doi_year'] = fixed_dates.finalize_year
fixed_dates.sample(10)
# Out:
#      Unnamed: 0  corrected                 title  \
# 54           54          1              Waco ISD
# 341         341          1               May ISD
# 198         198          1            Riesel ISD
# 242         242          1          Perryton ISD
# 403         403          1        Lago Vista ISD
# 723         723          1       Burkburnett ISD
# 514         514          1  Gregory-Portland ISD
# 176         176          1        Royse City ISD
# 495         495          1           Harrold ISD
# 584         584          1           Eustace ISD
#
#                                            term_phrase  term_year term_month  \
# 54                                                 NaN     2017.0      March
# 341  District of Innovation Plan Start Date August ...     2017.0     August
# 198                                                NaN     2017.0      April
# 242                                                NaN     2017.0     August
# 403  Therefore, this plan will begin with the 2017-...     2017.0       June
# 723  District of Innovation Plan February 2017 - Fe...     2017.0   February
# 514                                                NaN        NaN        NaN
# 176  before the 4th Monday of August. For 2017-18, ...     2017.0        NaN
# 495  a new teacher appraisal system in 2016-2017, c...        NaN        NaN
# 584  its recommendation for teacher evaluation begi...        NaN        NaN
#
#                                        finalize_phrase  finalize_year  \
# 54                                                 NaN         2017.0
# 341  the May ISD Board of Trustees. On March 26, 20...         2017.0
# 198                                                NaN         2017.0
# 242                                                NaN         2017.0
# 403  approved the final plan on March 22, 2017. On ...         2017.0
# 723  District of Innovation Plan February 2017 - Fe...         2017.0
# 514                                                NaN            NaN
# 176  proposed plan. Monday, January 23, 2017, Speci...         2017.0
# 495  of Innovation Plan Approved / March 30, 2017 I...         2017.0
# 584  started at 4:00 PM. February 14, 2017 â A pu...         2017.0
#
#     finalize_month                                               link  \
# 54           March                        https://www.wacoisd.org/doi
# 341            May  http://toolbox1.s3-website-us-west-2.amazonaws...
# 198          April  https://www.rieselisd.org/cms/lib/TX02215234/C...
# 242          April  http://s3.amazonaws.com/scschoolfiles/1204/doi...
# 403            NaN  http://www.lagovistaisd.net/upload/page/0030/d...
# 723       February  https://1.cdn.edl.io/NmmgpAdINIeQ8MlcQQx6MB0zP...
# 514            NaN  http://www.g-pisd.org/uploaded/_District/Publi...
# 176        January                         https://www.rcisd.org/doi/
# 495          March  https://harroldisd.socs.net/vimages/shared/vne...
# 584       February  https://s3.amazonaws.com/scschoolfiles/1670/di...
#
#      doi_year
# 54     2017.0
# 341    2017.0
# 198    2017.0
# 242    2017.0
# 403    2017.0
# 723    2017.0
# 514       NaN
# 176    2017.0
# 495    2017.0
# 584    2017.0

# %%
print('District not missing doi year:', len(fixed_dates[pd.notnull(fixed_dates.doi_year)]))
fixed_dates.doi_year.value_counts()
# Out:
# District not missing doi year: 812
# 2017.0    588
# 2018.0    133
# 2016.0     68
# 2019.0     22
# 2015.0      1
# Name: doi_year, dtype: int64

# %% [markdown]
# ## Save

# %%
fixed_dates[['title', 'term_year', 'term_month', 'finalize_year', 'finalize_month']].to_csv(os.path.join(data_path, 'doi_dates.csv'))

# %%
len(fixed_dates)
# Out:
# 824
