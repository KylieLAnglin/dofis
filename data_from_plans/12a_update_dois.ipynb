# %% [markdown]
# # Update DOIs

# %%
import urllib
import urllib.request
import urllib.parse
import urllib.error

import numpy as np
import pandas as pd
import os


import requests
from bs4 import BeautifulSoup
import csv

from pathlib import Path
import spacy

from start import data_path
import gather_documents
import clean_documents
import extract_laws
import extract_dates

# %%
# import cleaned exemptions list
docs_df = pd.read_csv(os.path.join(data_path,'doi_exemptions_and_dates.csv'))
print(len(docs_df))
docs_df[docs_df.title == "South San Antonio ISD"]
# Out:
# 824
#      Unnamed: 0                  title  Unnamed: 0_x  Unnamed: 0.1  \
# 693         693  South San Antonio ISD         130.0           614
#
#      Unnamed: 0.1.1  Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1   level type  \
# 693             614               614                 640  Second  pdf
#
#                                                   link  \
# 693  https://www.southsanisd.net//cms/lib/TX0191831...
#
#                                                   text  p_innovation  \
# 693  South San Antonio Independent School District ...      0.999955
#
#                                          possible_laws  Unnamed: 0_y  \
# 693  [25.0811, 21.003, 25.112, 25.1113, 21.051, 25....           130
#
#        doi_date
# 693  2017-08-01

# %%
# old districts with missing laws
missing_laws = docs_df[docs_df.possible_laws == '[]']
len(missing_laws)
missing_laws_list = list(missing_laws.title)
missing_laws_list
# Out:
# ['Bronte\xa0ISD',
#  'Burleson ISD',
#  'Crosbyton CISD',
#  'Dimmitt ISD',
#  'Gregory-Portland ISD',
#  'Henrietta ISD',
#  'La Joya ISD',
#  'Liberty Hill ISD',
#  'Marathon ISD',
#  'Midway ISD (161903) ']

# %%
# import cleaned dates

# %% [markdown]
# ## Check TEA website for new districts of innovation

# %%
url = "https://tea.texas.gov/Texas_Schools/District_Initiatives/Districts_of_Innovation/"
webcontent = urllib.request.urlopen(url).read()
soup = BeautifulSoup(webcontent, 'html.parser')
links = soup.find_all('a')
districts_list = [i for i in map(lambda x: x.get('title'), links) 
                  if i is not None and 'ISD' in i]
print("Number of districts on DOI website", len(districts_list))
# Out:
# Number of districts on DOI website 899

# %%
new_districts_list = []
for dist in districts_list:
    if dist not in list(docs_df.title):
        new_districts_list.append(dist)

print("Number of new districts: ", len(new_districts_list))
# Out:
# Number of new districts:  78

# %%
new_districts_list = new_districts_list + missing_laws_list
new_df = pd.DataFrame(new_districts_list, columns=['title'])
print(len(new_df))
# Out:
# 88

# %% [markdown]
# # Gather

# %%
first_level_links = gather_documents.FirstLevelLinks(url, print_interim=False)
first_level_df = first_level_links.docs_df.reset_index().rename(columns={'index': 'title'})
print(len(first_level_df))
first_level_df
# Out:
# /Users/kylie/dofis/src/data_from_plans/gather_documents.py:109: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 109 of the file /Users/kylie/dofis/src/data_from_plans/gather_documents.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(html)
# 355
#                title                                               link  \
# 0    Denver City ISD  http://www.dcisd.org/cms/lib011/TX01917797/Cen...
# 1         Marion ISD  http://www.marionisd.net/upload/page/0020/DofI...
# 2           Post ISD  https://1.cdn.edl.io/I2a9qAWX4QHUGdG5HRdQP38Ja...
# 3       Bartlett ISD  http://www.bartlett.txed.net/UserFiles/Servers...
# 4       Beeville ISD  https://s3.amazonaws.com/scschoolfiles/380/bis...
# ..               ...                                                ...
# 350     Red Lick ISD  https://drive.google.com/file/d/1frzMb5ZIGyOzk...
# 351        Roby CISD  https://docs.google.com/document/d/1H8XRcRNhFn...
# 352    Tidehaven ISD  https://drive.google.com/drive/folders/1qk4W6P...
# 353  Whitehouse ISD   https://docs.google.com/document/d/1lxtD2uHrmK...
# 354       Winona ISD  https://docs.google.com/document/d/1kDyG_vaZ0F...
#
#        type
# 0      docx
# 1      docx
# 2      docx
# 3       pdf
# 4       pdf
# ..      ...
# 350  google
# 351  google
# 352  google
# 353  google
# 354  google
#
# [355 rows x 3 columns]

# %%
new_df = new_df.merge(first_level_df, how = 'left')
print(len(new_df))
new_df
new_df.to_csv(os.path.join(data_path, 'update_links.csv'))
# Out:
# 88

# %%
updated_df = pd.read_csv(os.path.join(data_path,'update_links_corrected.csv'))
updated_df = updated_df[['title', 'link']]

# %% [markdown]
# ## Extract

# %% [markdown]
# ### Clean Text

# %%
texts = []
for link in updated_df.link:
    if not isinstance(link, str):
        texts.append("no link")
    elif isinstance(link, str):
        text = clean_documents.get_plain_text(link)
        texts.append(text)
updated_df['text'] = texts
updated_df = updated_df.fillna('No text') # replace None with 'None'
updated_df
# Out:
# Current link: https://www.libertyhill.txed.net/domain/294ers/Server_420297/File/Henrietta%20Ind%20School%20District/District%20Information/Mandatory%20Postings/District%20of%20Innovation/District%20of%20Innovation.pdf
#                   title                                               link  \
# 0       Alba-Golden ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 1           Amherst ISD  https://irp-cdn.multiscreensite.com/c65082d6/f...
# 2   Anderson-Shiro CISD  https://drive.google.com/file/d/1MkjdvYCX6GN6l...
# 3             Baird ISD                                            No text
# 4          Bartlett ISD  http://www.bartlett.txed.net/UserFiles/Servers...
# ..                  ...                                                ...
# 81        Henrietta ISD  http://www.henrietta-isd.net/UserFiles/Servers...
# 82          La Joya ISD                 https://www.lajoyaisd.com/362783_3
# 83     Liberty Hill ISD        https://www.libertyhill.txed.net/domain/294
# 84         Marathon ISD                                            No text
# 85  Midway ISD (161903)                                            No text
#
#                                                  text
# 0   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1                                             No text
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 3                                             no link
# 4                                             No text
# ..                                                ...
# 81  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 82  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 83  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 84                                            no link
# 85                                            no link
#
# [86 rows x 3 columns]

# %%
updated_df = clean_documents.remove_whitespace(updated_df, text_col = 'text')
updated_df.head()
# Out:
#                  title                                               link  \
# 0      Alba-Golden ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 1          Amherst ISD  https://irp-cdn.multiscreensite.com/c65082d6/f...
# 2  Anderson-Shiro CISD  https://drive.google.com/file/d/1MkjdvYCX6GN6l...
# 3            Baird ISD                                            No text
# 4         Bartlett ISD  http://www.bartlett.txed.net/UserFiles/Servers...
#
#                                                 text
# 0  ALBA-GOLDEN ISD District of Innovation Plan In...
# 1                                            No text
# 2  Anderson-Shiro CISD District of Innovation Pla...
# 3                                            no link
# 4                                            No text

# %% [markdown]
# ## Extract laws

# %%
updated_df['possible_laws'] = updated_df.text.apply(extract_laws.get_laws)
updated_df.sample(10)
# Out:
#                   title                                               link  \
# 0       Alba-Golden ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 3             Baird ISD                                            No text
# 79          Dimmitt ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 66      San Perlita ISD  https://s3.amazonaws.com/scschoolfiles/1769/do...
# 72        Southland ISD  https://img1.wsimg.com/blobby/go/d31ac773-fbc2...
# 2   Anderson-Shiro CISD  https://drive.google.com/file/d/1MkjdvYCX6GN6l...
# 83     Liberty Hill ISD        https://www.libertyhill.txed.net/domain/294
# 46         Meridian ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 43     Madisonville ISD  https://4.files.edl.io/4b72/07/15/20/194259-bb...
# 1           Amherst ISD  https://irp-cdn.multiscreensite.com/c65082d6/f...
#
#                                                  text  \
# 0   ALBA-GOLDEN ISD District of Innovation Plan In...
# 3                                             no link
# 79  District of Innovation Dimmitt ISD Local Innov...
# 66  Microsoft Word - DOI Plan - cover San Perlita ...
# 72  Southland Independent School District District...
# 2   Anderson-Shiro CISD District of Innovation Pla...
# 83  District of Innovation / District of Innovatio...
# 46  Meridian ISD District of Innovation Plan Intro...
# 43                                            No text
# 1                                             No text
#
#                                         possible_laws
# 0   [37.0012, 25.0811, 25.036, 21.003, 21.401, 25....
# 3                                                  []
# 79                 [25.0812, 21.003, 21.401, 25.0811]
# 66  [11.251, 21.057, 21.003, 21.053, 21.401, 25.03...
# 72  [45.206, 45.205, 45.204, 21.102, 21.003, 25.08...
# 2                                                  []
# 83                                                 []
# 46  [37.01, 37.007, 37.105, 25.087, 21.102, 21.003...
# 43                                                 []
# 1                                                  []

# %% [markdown]
# ## Extract dates

# %% [markdown]
# ### Term

# %%
classifier_dir = os.path.join(data_path, 'date_term_classifier')
nlp = spacy.load(classifier_dir)

# %%
start_dates = []
date_phrases = []
p_terms = []
months = []
for text in updated_df.text:
    year, month, phrase, p = extract_dates.get_term_date_and_phrase(text, classifier_dir)
    start_dates.append(year)
    months.append(month)
    date_phrases.append(phrase)        
    p_terms.append(p)
updated_df['term_year'] = start_dates
updated_df['term_month'] = months
updated_df['term_phrase'] = date_phrases
updated_df['term_p'] = p_terms

# %%
updated_df
# Out:
#                   title                                               link  \
# 0       Alba-Golden ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 1           Amherst ISD  https://irp-cdn.multiscreensite.com/c65082d6/f...
# 2   Anderson-Shiro CISD  https://drive.google.com/file/d/1MkjdvYCX6GN6l...
# 3             Baird ISD                                            No text
# 4          Bartlett ISD  http://www.bartlett.txed.net/UserFiles/Servers...
# ..                  ...                                                ...
# 81        Henrietta ISD  http://www.henrietta-isd.net/UserFiles/Servers...
# 82          La Joya ISD                 https://www.lajoyaisd.com/362783_3
# 83     Liberty Hill ISD        https://www.libertyhill.txed.net/domain/294
# 84         Marathon ISD                                            No text
# 85  Midway ISD (161903)                                            No text
#
#                                                  text  \
# 0   ALBA-GOLDEN ISD District of Innovation Plan In...
# 1                                             No text
# 2   Anderson-Shiro CISD District of Innovation Pla...
# 3                                             no link
# 4                                             No text
# ..                                                ...
# 81  District of Innovation Resolution Board of Edu...
# 82  La Joya ISD - Curriculum and Evaluation Skip t...
# 83  District of Innovation / District of Innovatio...
# 84                                            no link
# 85                                            no link
#
#                                         possible_laws  term_year term_month  \
# 0   [37.0012, 25.0811, 25.036, 21.003, 21.401, 25....       2020     August
# 1                                                  []       -999
# 2                                                  []       2019
# 3                                                  []       -999
# 4                                                  []       -999
# ..                                                ...        ...        ...
# 81                                                 []       7515
# 82                                                 []       -999
# 83                                                 []       2020
# 84                                                 []       -999
# 85                                                 []       -999
#
#                                           term_phrase    term_p
# 0   is for five years, beginning August, 2020 and ...  0.999955
# 1                                                      0.000000
# 2   of Innovation Plan 2019-2024 House Bill 1842, ...  0.999630
# 3                                                      0.000000
# 4                                                      0.000000
# ..                                                ...       ...
# 81  Assistant Secretary 720-7910(940) 720-7900 Fax...  0.595147
# 82  AEIS Public Hearing Report 2010-2011 AEIS Publ...  0.999955
# 83  Updated) | Terms of Use Copyright © 2002-2020 ...  0.999955
# 84                                                     0.000000
# 85                                                     0.000000
#
# [86 rows x 8 columns]

# %% [markdown]
# ## finalize date

# %%
finalize_classifier = os.path.join(data_path, 'date_finalize_classifier')
nlp = spacy.load(finalize_classifier)

# %%
test = extract_dates.get_finalize_month_year_phrase('We will hold a school board meeting on May 5, 1991', finalize_classifier)
test
# Out:
# (-999, '', '', 0)

# %%
finalize_years = []
finalize_months = []
finalize_phrases = []
finalize_p = []
for text in updated_df.text:
    year, month, phrase, p  = extract_dates.get_finalize_month_year_phrase(text, finalize_classifier)
    finalize_years.append(year)
    finalize_months.append(month)
    finalize_phrases.append(phrase)
    finalize_p.append(p)
updated_df['finalize_year'] = finalize_years
updated_df['finalize_month'] = finalize_months
updated_df['finalize_phrase'] = finalize_phrases
updated_df['finalize_p'] = finalize_p

# %%
updated_df
# Out:
#                   title                                               link  \
# 0       Alba-Golden ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 1           Amherst ISD  https://irp-cdn.multiscreensite.com/c65082d6/f...
# 2   Anderson-Shiro CISD  https://drive.google.com/file/d/1MkjdvYCX6GN6l...
# 3             Baird ISD                                            No text
# 4          Bartlett ISD  http://www.bartlett.txed.net/UserFiles/Servers...
# ..                  ...                                                ...
# 81        Henrietta ISD  http://www.henrietta-isd.net/UserFiles/Servers...
# 82          La Joya ISD                 https://www.lajoyaisd.com/362783_3
# 83     Liberty Hill ISD        https://www.libertyhill.txed.net/domain/294
# 84         Marathon ISD                                            No text
# 85  Midway ISD (161903)                                            No text
#
#                                                  text  \
# 0   ALBA-GOLDEN ISD District of Innovation Plan In...
# 1                                             No text
# 2   Anderson-Shiro CISD District of Innovation Pla...
# 3                                             no link
# 4                                             No text
# ..                                                ...
# 81  District of Innovation Resolution Board of Edu...
# 82  La Joya ISD - Curriculum and Evaluation Skip t...
# 83  District of Innovation / District of Innovatio...
# 84                                            no link
# 85                                            no link
#
#                                         possible_laws  term_year term_month  \
# 0   [37.0012, 25.0811, 25.036, 21.003, 21.401, 25....       2020     August
# 1                                                  []       -999
# 2                                                  []       2019
# 3                                                  []       -999
# 4                                                  []       -999
# ..                                                ...        ...        ...
# 81                                                 []       7515
# 82                                                 []       -999
# 83                                                 []       2020
# 84                                                 []       -999
# 85                                                 []       -999
#
#                                           term_phrase    term_p  \
# 0   is for five years, beginning August, 2020 and ...  0.999955
# 1                                                      0.000000
# 2   of Innovation Plan 2019-2024 House Bill 1842, ...  0.999630
# 3                                                      0.000000
# 4                                                      0.000000
# ..                                                ...       ...
# 81  Assistant Secretary 720-7910(940) 720-7900 Fax...  0.595147
# 82  AEIS Public Hearing Report 2010-2011 AEIS Publ...  0.999955
# 83  Updated) | Terms of Use Copyright © 2002-2020 ...  0.999955
# 84                                                     0.000000
# 85                                                     0.000000
#
#     finalize_year finalize_month  \
# 0            -999
# 1            -999
# 2            2019
# 3            -999
# 4            -999
# ..            ...            ...
# 81           2016       December
# 82           2018
# 83           2017       February
# 84           -999
# 85           -999
#
#                                       finalize_phrase  finalize_p
# 0   for all allowable TEC requirements under the H...    0.966373
# 1                                                        0.000000
# 2   a period of 5 years, from August 2019 to July ...    0.999716
# 3                                                        0.000000
# 4                                                        0.000000
# ..                                                ...         ...
# 81  . Adopted this 8th day of December, 2016, by t...    0.998921
# 82  2008-2009 School Report Cards Report Cards 201...    0.981234
# 83  public hearing was held on February 1, 2017 to...    0.999955
# 84                                                       0.000000
# 85                                                       0.000000
#
# [86 rows x 12 columns]

# %%
updated_df.loc[updated_df.term_p >= .9, 'date_year'] = updated_df.term_year
updated_df.loc[updated_df.term_p >= .9, 'date_month'] = updated_df.term_month
updated_df.loc[updated_df.term_p >= .9, 'date_phrase'] = updated_df.term_phrase

updated_df.loc[updated_df.term_p < .9, 'date_year'] = updated_df.finalize_year
updated_df.loc[updated_df.term_p < .9, 'date_month'] = updated_df.finalize_month
updated_df.loc[updated_df.term_p < .9, 'date_phrase'] = updated_df.finalize_phrase

updated_df.head()
# Out:
#                  title                                               link  \
# 0      Alba-Golden ISD  https://core-docs.s3.amazonaws.com/documents/a...
# 1          Amherst ISD  https://irp-cdn.multiscreensite.com/c65082d6/f...
# 2  Anderson-Shiro CISD  https://drive.google.com/file/d/1MkjdvYCX6GN6l...
# 3            Baird ISD                                            No text
# 4         Bartlett ISD  http://www.bartlett.txed.net/UserFiles/Servers...
#
#                                                 text  \
# 0  ALBA-GOLDEN ISD District of Innovation Plan In...
# 1                                            No text
# 2  Anderson-Shiro CISD District of Innovation Pla...
# 3                                            no link
# 4                                            No text
#
#                                        possible_laws  term_year term_month  \
# 0  [37.0012, 25.0811, 25.036, 21.003, 21.401, 25....       2020     August
# 1                                                 []       -999
# 2                                                 []       2019
# 3                                                 []       -999
# 4                                                 []       -999
#
#                                          term_phrase    term_p  finalize_year  \
# 0  is for five years, beginning August, 2020 and ...  0.999955           -999
# 1                                                     0.000000           -999
# 2  of Innovation Plan 2019-2024 House Bill 1842, ...  0.999630           2019
# 3                                                     0.000000           -999
# 4                                                     0.000000           -999
#
#   finalize_month                                    finalize_phrase  \
# 0                 for all allowable TEC requirements under the H...
# 1
# 2                 a period of 5 years, from August 2019 to July ...
# 3
# 4
#
#    finalize_p  date_year date_month  \
# 0    0.966373     2020.0     August
# 1    0.000000     -999.0
# 2    0.999716     2019.0
# 3    0.000000     -999.0
# 4    0.000000     -999.0
#
#                                          date_phrase
# 0  is for five years, beginning August, 2020 and ...
# 1
# 2  of Innovation Plan 2019-2024 House Bill 1842, ...
# 3
# 4

# %%
updated_df = updated_df[['title', 'link', 'text', 'possible_laws', 'term_year', 'term_month', 'term_phrase',
                         'finalize_year', 'finalize_month', 'finalize_phrase']]

# %% [markdown]
# ### update dates and laws

# %%
updated_df.to_csv(os.path.join(data_path,'update_dates_and_laws.csv'))

# %%
# select dates

# %%
fixed_dates['doi_year'] = np.nan
fixed_dates.loc[pd.notnull(fixed_dates.term_year), 'doi_year'] = fixed_dates.term_year
fixed_dates.loc[pd.isnull(fixed_dates.term_year), 'doi_year'] = fixed_dates.finalize_year
fixed_dates.sample(10)

# %% [markdown]
# Open update_dates_and_laws and save as update_dates_and_laws_corrected.csv. Correct term month and year, finalize month and year, and dates. If data is not available in plan, delete -999 and leave blank (for dates) or as an empty list (for laws)

# %% [markdown]
# # import and append

# %%
new_df = pd.read_csv(os.path.join(data_path,'update_dates_and_laws_corrected.csv'))
old_df = docs_df.loc[~docs_df.title.isin(missing_laws_list)]
final_df = old_df.append(new_df)
final_df.sample(5)
# Out:
#      Unnamed: 0           title  Unnamed: 0_x  Unnamed: 0.1  Unnamed: 0.1.1  \
# 453         453      Lometa ISD         140.0          19.0            19.0
# 798         798  Whitharral ISD           5.0         282.0           282.0
# 1             1   Abernathy ISD         822.0         820.0           820.0
# 74           74   Van Vleck ISD           NaN           NaN             NaN
# 406         406      Knippa ISD          60.0           7.0             7.0
#
#      Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1   level    type  \
# 453              19.0                19.0   First  google
# 798             282.0               282.0   First  google
# 1               820.0               878.0  Second     pdf
# 74                NaN                 NaN     NaN     NaN
# 406               7.0                 7.0   First  google
#
#                                                   link  ... p_innovation  \
# 453  https://drive.google.com/file/d/1DqPY5G88CnmpB...  ...     0.999955
# 798  https://docs.google.com/document/d/1QpBqSAmJNZ...  ...     0.999795
# 1    https://1.cdn.edl.io/epGD4mZXjWUcPl8yA7IhlcDol...  ...     0.999904
# 74   https://core-docs.s3.amazonaws.com/documents/a...  ...          NaN
# 406  https://docs.google.com/viewer?a=v&pid=sites&s...  ...     0.000045
#
#                                          possible_laws Unnamed: 0_y  \
# 453  [25.114, 25.111, 25.081, 21.102, 21.354, 21.00...        370.0
# 798  [37.008, 25.081, 25.036, 21.003, 21.3541, 21.2...         25.0
# 1    [25.113, 37.0012, 28.214, 21.003, 21.057, 25.0...        822.0
# 74   [25.0811, 28.0214, 21.057, 21.053, 25.092, 21....          NaN
# 406  [21.003, 21.053, 21.04, 21.005, 25.0811, 25.08...        417.0
#
#        doi_date term_year  term_month  \
# 453  2018-01-01       NaN         NaN
# 798  2018-05-01       NaN         NaN
# 1    2017-01-01       NaN         NaN
# 74          NaN    2019.0      August
# 406  2016-08-01       NaN         NaN
#
#                                            term_phrase finalize_year  \
# 453                                                NaN           NaN
# 798                                                NaN           NaN
# 1                                                  NaN           NaN
# 74   for five years, beginning August 1, 2019 and e...        2019.0
# 406                                                NaN           NaN
#
#      finalize_month                                    finalize_phrase
# 453             NaN                                                NaN
# 798             NaN                                                NaN
# 1               NaN                                                NaN
# 74            March  January 25, 2019 Approval by VVISD Board: Marc...
# 406             NaN                                                NaN
#
# [5 rows x 21 columns]

# %%
final_df = old_df.append(new_df)

# %%
len(final_df)
# Out:
# 900
