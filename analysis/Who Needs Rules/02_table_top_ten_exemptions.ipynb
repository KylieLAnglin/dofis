# %%
import pandas as pd
import os
from openpyxl import load_workbook

data_path = '/Users/kylieleblancKylie/domino/dofis/data/clean'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/Who Needs Rules/'

# %%
data_path
# Out:
# '/Users/kylieleblancKylie/domino/dofis/data/clean'

# %%
data = pd.read_csv((os.path.join(data_path, 'master_data_district.csv')))
data
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Unnamed: 0  year  district           distname distischarter  \
# 0              0  2012      1902         CAYUGA ISD             N
# 1              1  2012      1903        ELKHART ISD             N
# 2              2  2012      1904      FRANKSTON ISD             N
# 3              3  2012      1906         NECHES ISD             N
# 4              4  2012      1907      PALESTINE ISD             N
# ...          ...   ...       ...                ...           ...
# 8506        8506  2018    252902      NEWCASTLE ISD             N
# 8507        8507  2018    252903          OLNEY ISD             N
# 8508        8508  2018    253901  ZAPATA COUNTY ISD             N
# 8509        8509  2018    254901   CRYSTAL CITY ISD             N
# 8510        8510  2018    254902       LA PRYOR ISD             N
#
#      rating_academic rating_financial type             type_description  \
# 0                NaN              NaN    H                        RURAL
# 1                NaN              NaN    G      NON-METROPOLITAN STABLE
# 2                NaN              NaN    H                        RURAL
# 3                NaN              NaN    H                        RURAL
# 4                NaN              NaN    E             INDEPENDENT TOWN
# ...              ...              ...  ...                          ...
# 8506    Met Standard             Pass    H                        RURAL
# 8507               A             Pass    H                        RURAL
# 8508               B             Pass    D  OTHER CENTRAL CITY SUBURBAN
# 8509               C             Pass    G      NON-METROPOLITAN STABLE
# 8510               C             Pass    H                        RURAL
#
#       cntyname  ...  district_status  type_urban  type_suburban  type_town  \
# 0     ANDERSON  ...              doi           0              0          0
# 1     ANDERSON  ...              doi           0              0          1
# 2     ANDERSON  ...              doi           0              0          0
# 3     ANDERSON  ...              doi           0              0          0
# 4     ANDERSON  ...              doi           0              0          1
# ...        ...  ...              ...         ...            ...        ...
# 8506     YOUNG  ...              doi           0              0          0
# 8507     YOUNG  ...              doi           0              0          0
# 8508    ZAPATA  ...              doi           0              1          0
# 8509    ZAVALA  ...              tps           0              0          1
# 8510    ZAVALA  ...              doi           0              0          0
#
#       type_rural  eligible  teachers_nodegree  teachers_badegree  \
# 0              1         1           0.000000           0.880443
# 1              0         1           0.000000           0.827979
# 2              1         1           0.000000           0.826226
# 3              1         1           0.000000           0.969697
# 4              0         1           0.004019           0.808958
# ...          ...       ...                ...                ...
# 8506           1         1           0.000000           0.783784
# 8507           1         1           0.000000           0.784000
# 8508           0         1           0.009183           0.881543
# 8509           0         1           0.013846           0.862308
# 8510           1         1           0.000000           0.873563
#
#       teachers_msdegree  teachers_phddegree
# 0              0.119557            0.000000
# 1              0.171917            0.000000
# 2              0.173774            0.000000
# 3              0.030303            0.000000
# 4              0.182775            0.004261
# ...                 ...                 ...
# 8506           0.216216            0.000000
# 8507           0.212000            0.004000
# 8508           0.109275            0.000000
# 8509           0.115385            0.007692
# 8510           0.126437            0.000000
#
# [8511 rows x 321 columns]

# %%
stubnames = sorted(
    set([match[0] for match in data.columns.str.findall(
    r'reg.*').values if match != [] ])
    )

proportion = []
number = []
for reg in stubnames:
    proportion.append(data[reg].mean())
    number.append(data[reg].sum())

regs = pd.DataFrame(
    {'law': stubnames,
     'proportion': proportion,
     'number': number
    }).sort_values(by = ['proportion'], ascending = False)
regs.head(10)
# Out:
#             law  proportion  number
# 90   reg25_0811    0.970788  5583.0
# 19    reg21_003    0.868545  4995.0
# 43    reg21_102    0.509650  2931.0
# 104   reg25_112    0.441662  2540.0
# 89    reg25_081    0.433316  2492.0
# 105   reg25_113    0.363763  2092.0
# 60    reg21_401    0.352982  2030.0
# 38    reg21_057    0.329508  1895.0
# 35    reg21_053    0.291775  1678.0
# 91   reg25_0812    0.281168  1617.0

# %%
from openpyxl import load_workbook

def df_to_excel(file, df, df_columns, start_col, start_row, all_ints = True):
    wb = load_workbook(file)
    ws = wb.active

    col_n = start_col
    for col in df_columns:
        row_n = start_row
        for ob in df[col]:
            ws.cell(row=row_n, column=col_n).value = ob
            row_n = row_n + 1
        col_n = col_n + 1
    wb.save(file)

# %%
df_to_excel(file = os.path.join(table_path, 'table1_exemptions.xlsx'),
            df = regs, df_columns = ['law', 'proportion'],
            start_col = 4, start_row = 3)
