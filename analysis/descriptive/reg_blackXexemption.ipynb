# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm

from library import regulations
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'),
                  sep=",")
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = data[data.year == 'yr1415']
data
# Out:
#       Unnamed: 0  district                      distname    year    cntyname  \
# 3619        3619      1902                    CAYUGA ISD  yr1415    ANDERSON
# 3620        3620      1903                   ELKHART ISD  yr1415    ANDERSON
# 3621        3621      1904                 FRANKSTON ISD  yr1415    ANDERSON
# 3622        3622      1906                    NECHES ISD  yr1415    ANDERSON
# 3623        3623      1907                 PALESTINE ISD  yr1415    ANDERSON
# 3624        3624      1908                  WESTWOOD ISD  yr1415    ANDERSON
# 3625        3625      1909                    SLOCUM ISD  yr1415    ANDERSON
# 3626        3626      2901                   ANDREWS ISD  yr1415     ANDREWS
# 3627        3627      3801  PINEYWOODS COMMUNITY ACADEMY  yr1415    ANGELINA
# 3628        3628      3902                    HUDSON ISD  yr1415    ANGELINA
# 3629        3629      3903                    LUFKIN ISD  yr1415    ANGELINA
# 3630        3630      3904                HUNTINGTON ISD  yr1415    ANGELINA
# 3631        3631      3905                    DIBOLL ISD  yr1415    ANGELINA
# 3632        3632      3906                   ZAVALLA ISD  yr1415    ANGELINA
# 3633        3633      3907                   CENTRAL ISD  yr1415    ANGELINA
# 3634        3634      4901            ARANSAS COUNTY ISD  yr1415     ARANSAS
# 3635        3635      5901               ARCHER CITY ISD  yr1415      ARCHER
# 3636        3636      5902                  HOLLIDAY ISD  yr1415      ARCHER
# 3637        3637      5904                WINDTHORST ISD  yr1415      ARCHER
# 3638        3638      6902                    CLAUDE ISD  yr1415   ARMSTRONG
# 3639        3639      7901                 CHARLOTTE ISD  yr1415    ATASCOSA
# 3640        3640      7902                JOURDANTON ISD  yr1415    ATASCOSA
# 3641        3641      7904                     LYTLE ISD  yr1415    ATASCOSA
# 3642        3642      7905                PLEASANTON ISD  yr1415    ATASCOSA
# 3643        3643      7906                    POTEET ISD  yr1415    ATASCOSA
# 3644        3644      8901                 BELLVILLE ISD  yr1415      AUSTIN
# 3645        3645      8902                     SEALY ISD  yr1415      AUSTIN
# 3646        3646      8903                    BRAZOS ISD  yr1415      AUSTIN
# 3647        3647      9901                  MULESHOE ISD  yr1415      BAILEY
# 3648        3648     10901                    MEDINA ISD  yr1415     BANDERA
# ...          ...       ...                           ...     ...         ...
# 4808        4808    246912                    THRALL ISD  yr1415  WILLIAMSON
# 4809        4809    246913                   LEANDER ISD  yr1415  WILLIAMSON
# 4810        4810    246914                  COUPLAND ISD  yr1415  WILLIAMSON
# 4811        4811    247901               FLORESVILLE ISD  yr1415      WILSON
# 4812        4812    247903                 LA VERNIA ISD  yr1415      WILSON
# 4813        4813    247904                      POTH ISD  yr1415      WILSON
# 4814        4814    247906                 STOCKDALE ISD  yr1415      WILSON
# 4815        4815    248901                    KERMIT ISD  yr1415     WINKLER
# 4816        4816    248902               WINK-LOVING ISD  yr1415     WINKLER
# 4817        4817    249901                    ALVORD ISD  yr1415        WISE
# 4818        4818    249902                      BOYD ISD  yr1415        WISE
# 4819        4819    249903                BRIDGEPORT ISD  yr1415        WISE
# 4820        4820    249904                     CHICO ISD  yr1415        WISE
# 4821        4821    249905                   DECATUR ISD  yr1415        WISE
# 4822        4822    249906                  PARADISE ISD  yr1415        WISE
# 4823        4823    249908                   SLIDELL ISD  yr1415        WISE
# 4824        4824    250902                   HAWKINS ISD  yr1415        WOOD
# 4825        4825    250903                   MINEOLA ISD  yr1415        WOOD
# 4826        4826    250904                   QUITMAN ISD  yr1415        WOOD
# 4827        4827    250905                    YANTIS ISD  yr1415        WOOD
# 4828        4828    250906               ALBA-GOLDEN ISD  yr1415        WOOD
# 4829        4829    250907                 WINNSBORO ISD  yr1415        WOOD
# 4830        4830    251901               DENVER CITY ISD  yr1415      YOAKUM
# 4831        4831    251902                    PLAINS ISD  yr1415      YOAKUM
# 4832        4832    252901                    GRAHAM ISD  yr1415       YOUNG
# 4833        4833    252902                 NEWCASTLE ISD  yr1415       YOUNG
# 4834        4834    252903                     OLNEY ISD  yr1415       YOUNG
# 4835        4835    253901             ZAPATA COUNTY ISD  yr1415      ZAPATA
# 4836        4836    254901              CRYSTAL CITY ISD  yr1415      ZAVALA
# 4837        4837    254902                  LA PRYOR ISD  yr1415      ZAVALA
#
#      distischarter rating_academic rating_financial eligible type  \
# 3619             N               M             Pass     True    H
# 3620             N               M             Pass     True    G
# 3621             N               M             Pass     True    H
# 3622             N               M             Pass     True    H
# 3623             N               M             Pass     True    E
# 3624             N               M             Pass     True    G
# 3625             N               M             Pass     True    H
# 3626             N               M             Pass     True    D
# 3627             Y               M             Pass    False    I
# 3628             N               M             Pass     True    G
# 3629             N               M             Pass     True    E
# 3630             N               M             Pass     True    G
# 3631             N               M             Pass     True    G
# 3632             N               M             Pass     True    H
# 3633             N               M             Pass     True    G
# 3634             N               M             Pass     True    E
# 3635             N               M             Pass     True    H
# 3636             N               M             Pass     True    D
# 3637             N               M             Pass     True    H
# 3638             N               M             Pass     True    H
# 3639             N               M             Pass     True    H
# 3640             N               M             Pass     True    F
# 3641             N               M             Pass     True    G
# 3642             N               M             Pass     True    E
# 3643             N               M             Pass     True    G
# 3644             N               M             Pass     True    E
# 3645             N               M             Pass     True    D
# 3646             N               M             Pass     True    H
# 3647             N               M             Fail    False    G
# 3648             N               M             Pass     True    H
# ...            ...             ...              ...      ...  ...
# 4808             N               M             Pass     True    H
# 4809             N               M             Pass     True    B
# 4810             N               M             Pass     True    H
# 4811             N               M             Pass     True    E
# 4812             N               M             Pass     True    E
# 4813             N               M             Pass     True    H
# 4814             N               M             Pass     True    H
# 4815             N               M             Pass     True    D
# 4816             N               M             Pass     True    F
# 4817             N               M             Pass     True    H
# 4818             N               M             Pass     True    G
# 4819             N               M             Pass     True    E
# 4820             N               M             Pass     True    H
# 4821             N               M             Pass     True    E
# 4822             N               M             Pass     True    G
# 4823             N               M             Pass     True    H
# 4824             N               M             Pass     True    H
# 4825             N               M             Pass     True    E
# 4826             N               M             Pass     True    E
# 4827             N               M             Pass     True    H
# 4828             N               M             Pass     True    H
# 4829             N               M             Pass     True    E
# 4830             N               M             Pass     True    G
# 4831             N               M             Pass     True    H
# 4832             N               M             Pass     True    G
# 4833             N               M             Pass     True    H
# 4834             N               M             Pass     True    H
# 4835             N               M             Pass     True    D
# 4836             N               I             Pass    False    G
# 4837             N               M             Pass     True    H
#
#              ...         charter  district_status  type_urban  type_suburban  \
# 3619         ...           False              doi           0              0
# 3620         ...           False              doi           0              0
# 3621         ...           False              doi           0              0
# 3622         ...           False              doi           0              0
# 3623         ...           False              doi           0              0
# 3624         ...           False              doi           0              0
# 3625         ...           False              doi           0              0
# 3626         ...           False              tps           0              1
# 3627         ...            True          charter           0              0
# 3628         ...           False              doi           0              0
# 3629         ...           False              doi           0              0
# 3630         ...           False              doi           0              0
# 3631         ...           False              tps           0              0
# 3632         ...           False              doi           0              0
# 3633         ...           False              tps           0              0
# 3634         ...           False              doi           0              0
# 3635         ...           False              doi           0              0
# 3636         ...           False              doi           0              1
# 3637         ...           False              doi           0              0
# 3638         ...           False              doi           0              0
# 3639         ...           False              tps           0              0
# 3640         ...           False              doi           0              0
# 3641         ...           False              doi           0              0
# 3642         ...           False              tps           0              0
# 3643         ...           False              tps           0              0
# 3644         ...           False              tps           0              0
# 3645         ...           False              tps           0              1
# 3646         ...           False              doi           0              0
# 3647         ...           False              doi           0              0
# 3648         ...           False              tps           0              0
# ...          ...             ...              ...         ...            ...
# 4808         ...           False              doi           0              0
# 4809         ...           False              doi           0              1
# 4810         ...           False              doi           0              0
# 4811         ...           False              doi           0              0
# 4812         ...           False              doi           0              0
# 4813         ...           False              doi           0              0
# 4814         ...           False              doi           0              0
# 4815         ...           False              tps           0              1
# 4816         ...           False              doi           0              0
# 4817         ...           False              doi           0              0
# 4818         ...           False              doi           0              0
# 4819         ...           False              doi           0              0
# 4820         ...           False              doi           0              0
# 4821         ...           False              doi           0              0
# 4822         ...           False              doi           0              0
# 4823         ...           False              doi           0              0
# 4824         ...           False              tps           0              0
# 4825         ...           False              doi           0              0
# 4826         ...           False              doi           0              0
# 4827         ...           False              tps           0              0
# 4828         ...           False              tps           0              0
# 4829         ...           False              doi           0              0
# 4830         ...           False              doi           0              0
# 4831         ...           False              tps           0              0
# 4832         ...           False              doi           0              0
# 4833         ...           False              doi           0              0
# 4834         ...           False              doi           0              0
# 4835         ...           False              doi           0              1
# 4836         ...           False              tps           0              0
# 4837         ...           False              tps           0              0
#
#       type_town  type_rural  teachers_nodegree  teachers_badegree  \
# 3619          0           1           0.000000           0.460037
# 3620          1           0           0.000000           0.510386
# 3621          0           1           0.000865           0.455882
# 3622          0           1           0.000000           0.558292
# 3623          1           0           0.016495           0.467010
# 3624          1           0           0.000000           0.502875
# 3625          0           1           0.011765           0.605042
# 3626          0           0           0.000000           0.421481
# 3627          1           0           0.020704           0.351967
# 3628          1           0           0.012782           0.385464
# 3629          1           0           0.006290           0.403952
# 3630          1           0           0.000000           0.414644
# 3631          1           0           0.000000           0.423635
# 3632          0           1           0.000000           0.475842
# 3633          1           0           0.000000           0.446239
# 3634          1           0           0.004085           0.372753
# 3635          0           1           0.000000           0.526316
# 3636          0           0           0.000000           0.481013
# 3637          0           1           0.000000           0.448120
# 3638          0           1           0.000000           0.473451
# 3639          0           1           0.000000           0.397849
# 3640          1           0           0.000000           0.408940
# 3641          1           0           0.000000           0.348456
# 3642          1           0           0.000000           0.432159
# 3643          1           0           0.003504           0.322004
# 3644          1           0           0.006483           0.445381
# 3645          0           0           0.002860           0.484415
# 3646          0           1           0.000000           0.430782
# 3647          1           0           0.000000           0.418165
# 3648          0           1           0.000000           0.404594
# ...         ...         ...                ...                ...
# 4808          0           1           0.000000           0.470035
# 4809          0           0           0.001381           0.394433
# 4810          0           1           0.046729           0.523364
# 4811          1           0           0.003365           0.319650
# 4812          1           0           0.000000           0.369458
# 4813          0           1           0.000000           0.471803
# 4814          0           1           0.000000           0.454161
# 4815          0           0           0.000000           0.362357
# 4816          1           0           0.000000           0.469220
# 4817          0           1           0.000000           0.431193
# 4818          1           0           0.000000           0.443030
# 4819          1           0           0.003328           0.411647
# 4820          0           1           0.000000           0.527215
# 4821          1           0           0.002385           0.386835
# 4822          1           0           0.000000           0.502366
# 4823          0           1           0.000000           0.390411
# 4824          0           1           0.000000           0.438474
# 4825          1           0           0.000000           0.433018
# 4826          1           0           0.023753           0.397862
# 4827          0           1           0.000000           0.527157
# 4828          0           1           0.007981           0.510774
# 4829          1           0           0.000000           0.431391
# 4830          1           0           0.000000           0.467350
# 4831          0           1           0.012048           0.487952
# 4832          1           0           0.000284           0.442395
# 4833          0           1           0.000000           0.394366
# 4834          0           1           0.000000           0.474106
# 4835          0           0           0.003770           0.374364
# 4836          1           0           0.003004           0.349054
# 4837          0           1           0.000000           0.372738
#
#      teachers_msdegree  teachers_phddegree
# 3619          0.041822            0.000000
# 3620          0.087240            0.000000
# 3621          0.035467            0.000000
# 3622          0.011494            0.000000
# 3623          0.069072            0.000000
# 3624          0.064131            0.004423
# 3625          0.016807            0.000000
# 3626          0.110582            0.001985
# 3627          0.144928            0.000000
# 3628          0.087469            0.000000
# 3629          0.065565            0.000000
# 3630          0.073220            0.000405
# 3631          0.087077            0.000000
# 3632          0.067350            0.000000
# 3633          0.067998            0.000000
# 3634          0.103758            0.006127
# 3635          0.033595            0.000000
# 3636          0.092827            0.000000
# 3637          0.090226            0.000000
# 3638          0.085546            0.000000
# 3639          0.086022            0.000000
# 3640          0.137423            0.000000
# 3641          0.114373            0.000000
# 3642          0.065614            0.000000
# 3643          0.100561            0.000000
# 3644          0.048298            0.004862
# 3645          0.080355            0.000000
# 3646          0.087948            0.000000
# 3647          0.084532            0.002248
# 3648          0.106007            0.000000
# ...                ...                 ...
# 4808          0.104583            0.000000
# 4809          0.144439            0.003660
# 4810          0.000000            0.000000
# 4811          0.097241            0.001682
# 4812          0.099015            0.000000
# 4813          0.064337            0.000000
# 4814          0.064175            0.000000
# 4815          0.067722            0.000000
# 4816          0.068399            0.000000
# 4817          0.097248            0.000000
# 4818          0.093333            0.000000
# 4819          0.109484            0.006656
# 4820          0.053362            0.000000
# 4821          0.104937            0.000000
# 4822          0.085869            0.000000
# 4823          0.159817            0.000000
# 4824          0.063084            0.000000
# 4825          0.168245            0.000000
# 4826          0.121140            0.000000
# 4827          0.079872            0.000000
# 4828          0.059058            0.000000
# 4829          0.076071            0.000000
# 4830          0.048229            0.000000
# 4831          0.062651            0.000000
# 4832          0.072361            0.000000
# 4833          0.169014            0.000000
# 4834          0.053975            0.000729
# 4835          0.061828            0.000000
# 4836          0.038750            0.000000
# 4837          0.132690            0.000000
#
# [1219 rows x 414 columns]

# %% [markdown]
# ## Schedules

# %%
df = analysis.many_x_one_y(data = data, x_list = regulations.schedules,
                         x_labels = regulations.labels, y = 'students_black')
tables.var_diff_to_excel(file = table_path + 'reg_blackXexemption.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 5)
df
# Out:
#                                       Characteristic  Control  Difference  \
# 0         25.0811 - Minimum First Day of Instruction     0.06        0.01
# 1              25.081 - Minimum Minutes of Operation     0.07       -0.01
# 2          25.0812 - Minimum Last Day of Instruction     0.07       -0.01
# 3  25.082 - Pledge of Allegiance and Minute of Si...     0.07       -0.01
#
#    Std. Error  P-value
# 0        0.01     0.64
# 1        0.01     0.38
# 2        0.01     0.54
# 3        0.01     0.36

# %% [markdown]
# ## Class Size

# %%
df = analysis.many_x_one_y(data = data, x_list = regulations.class_size,
                         x_labels = regulations.labels, y = 'students_black')
tables.var_diff_to_excel(file = table_path + 'reg_blackXexemption.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 5)
df
# Out:
#                            Characteristic  Control  Difference  Std. Error  \
# 0             25.112 - Class Size Maximum     0.07        0.01        0.01
# 1           25.113 - Notice of Class Size     0.07        0.00        0.01
# 2  25.111 - Maximum Student Teacher Ratio     0.07        0.00        0.01
#
#    P-value
# 0     0.35
# 1     0.65
# 2     0.69

# %% [markdown]
# ## Certification

# %%
df = analysis.many_x_one_y(data = data, x_list = regulations.certification,
                         x_labels = regulations.labels, y = 'students_black')
tables.var_diff_to_excel(file = table_path + 'reg_blackXexemption.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 5)
df
# Out:
#                                   Characteristic  Control  Difference  \
# 0        21.003 - Teacher Certification Required     0.06        0.01
# 1  21.053 - Presentation of Teacher Certificates     0.07       -0.00
# 2         21.057 - Notice of Uncertified Teacher     0.07       -0.01
#
#    Std. Error  P-value
# 0        0.01     0.25
# 1        0.01     0.80
# 2        0.01     0.23

# %% [markdown]
# ## Contracts

# %%
df = analysis.many_x_one_y(data = data, x_list = regulations.contracts,
                         x_labels = regulations.labels, y = 'students_black')
tables.var_diff_to_excel(file = table_path + 'reg_blackXexemption.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 5)
df
# Out:
#                                       Characteristic  Control  Difference  \
# 0      21.102 - Maximum Probationary Contract Length     0.07       -0.01
# 1  21.401 - Minimum Service Days Required for Tea...     0.08       -0.02
# 2                        21.352 - Teacher Evaluation     0.07       -0.00
# 3                  21.354 - Administrator Evaluation     0.07       -0.03
#
#    Std. Error  P-value
# 0        0.01     0.41
# 1        0.01     0.01
# 2        0.01     0.94
# 3        0.01     0.06

# %% [markdown]
# ## Student Behavior

# %%
df = analysis.many_x_one_y(data = data, x_list = regulations.behavior,
                         x_labels = regulations.labels, y = 'students_black')
tables.var_diff_to_excel(file = table_path + 'reg_blackXexemption.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 5)
df
# Out:
#                                       Characteristic  Control  Difference  \
# 0       25.092 - Minimum Attendance for Class Credit     0.06        0.02
# 1  37.0012 - Designation of Campus Behavior Coord...     0.06        0.02
# 2                                 25.036 - Transfers     0.07       -0.01
#
#    Std. Error  P-value
# 0        0.01     0.00
# 1        0.01     0.01
# 2        0.01     0.50
