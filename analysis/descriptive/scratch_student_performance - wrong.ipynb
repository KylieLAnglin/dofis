# %%
import pandas as pd
import os
import statsmodels.formula.api as sm

from library import regulations
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'),
                  sep=",")
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = data[data.year == 'yr1415']
data
# Out:
#       Unnamed: 0  district                      distname    year    cntyname  \
# 3682        3682      1902                    CAYUGA ISD  yr1415    ANDERSON
# 3683        3683      1903                   ELKHART ISD  yr1415    ANDERSON
# 3684        3684      1904                 FRANKSTON ISD  yr1415    ANDERSON
# 3685        3685      1906                    NECHES ISD  yr1415    ANDERSON
# 3686        3686      1907                 PALESTINE ISD  yr1415    ANDERSON
# 3687        3687      1908                  WESTWOOD ISD  yr1415    ANDERSON
# 3688        3688      1909                    SLOCUM ISD  yr1415    ANDERSON
# 3689        3689      2901                   ANDREWS ISD  yr1415     ANDREWS
# 3690        3690      3801  PINEYWOODS COMMUNITY ACADEMY  yr1415    ANGELINA
# 3691        3691      3902                    HUDSON ISD  yr1415    ANGELINA
# 3692        3692      3903                    LUFKIN ISD  yr1415    ANGELINA
# 3693        3693      3904                HUNTINGTON ISD  yr1415    ANGELINA
# 3694        3694      3905                    DIBOLL ISD  yr1415    ANGELINA
# 3695        3695      3906                   ZAVALLA ISD  yr1415    ANGELINA
# 3696        3696      3907                   CENTRAL ISD  yr1415    ANGELINA
# 3697        3697      4901            ARANSAS COUNTY ISD  yr1415     ARANSAS
# 3698        3698      5901               ARCHER CITY ISD  yr1415      ARCHER
# 3699        3699      5902                  HOLLIDAY ISD  yr1415      ARCHER
# 3700        3700      5904                WINDTHORST ISD  yr1415      ARCHER
# 3701        3701      6902                    CLAUDE ISD  yr1415   ARMSTRONG
# 3702        3702      7901                 CHARLOTTE ISD  yr1415    ATASCOSA
# 3703        3703      7902                JOURDANTON ISD  yr1415    ATASCOSA
# 3704        3704      7904                     LYTLE ISD  yr1415    ATASCOSA
# 3705        3705      7905                PLEASANTON ISD  yr1415    ATASCOSA
# 3706        3706      7906                    POTEET ISD  yr1415    ATASCOSA
# 3707        3707      8901                 BELLVILLE ISD  yr1415      AUSTIN
# 3708        3708      8902                     SEALY ISD  yr1415      AUSTIN
# 3709        3709      8903                    BRAZOS ISD  yr1415      AUSTIN
# 3710        3710      9901                  MULESHOE ISD  yr1415      BAILEY
# 3711        3711     10901                    MEDINA ISD  yr1415     BANDERA
# ...          ...       ...                           ...     ...         ...
# 4871        4871    246912                    THRALL ISD  yr1415  WILLIAMSON
# 4872        4872    246913                   LEANDER ISD  yr1415  WILLIAMSON
# 4873        4873    246914                  COUPLAND ISD  yr1415  WILLIAMSON
# 4874        4874    247901               FLORESVILLE ISD  yr1415      WILSON
# 4875        4875    247903                 LA VERNIA ISD  yr1415      WILSON
# 4876        4876    247904                      POTH ISD  yr1415      WILSON
# 4877        4877    247906                 STOCKDALE ISD  yr1415      WILSON
# 4878        4878    248901                    KERMIT ISD  yr1415     WINKLER
# 4879        4879    248902               WINK-LOVING ISD  yr1415     WINKLER
# 4880        4880    249901                    ALVORD ISD  yr1415        WISE
# 4881        4881    249902                      BOYD ISD  yr1415        WISE
# 4882        4882    249903                BRIDGEPORT ISD  yr1415        WISE
# 4883        4883    249904                     CHICO ISD  yr1415        WISE
# 4884        4884    249905                   DECATUR ISD  yr1415        WISE
# 4885        4885    249906                  PARADISE ISD  yr1415        WISE
# 4886        4886    249908                   SLIDELL ISD  yr1415        WISE
# 4887        4887    250902                   HAWKINS ISD  yr1415        WOOD
# 4888        4888    250903                   MINEOLA ISD  yr1415        WOOD
# 4889        4889    250904                   QUITMAN ISD  yr1415        WOOD
# 4890        4890    250905                    YANTIS ISD  yr1415        WOOD
# 4891        4891    250906               ALBA-GOLDEN ISD  yr1415        WOOD
# 4892        4892    250907                 WINNSBORO ISD  yr1415        WOOD
# 4893        4893    251901               DENVER CITY ISD  yr1415      YOAKUM
# 4894        4894    251902                    PLAINS ISD  yr1415      YOAKUM
# 4895        4895    252901                    GRAHAM ISD  yr1415       YOUNG
# 4896        4896    252902                 NEWCASTLE ISD  yr1415       YOUNG
# 4897        4897    252903                     OLNEY ISD  yr1415       YOUNG
# 4898        4898    253901             ZAPATA COUNTY ISD  yr1415      ZAPATA
# 4899        4899    254901              CRYSTAL CITY ISD  yr1415      ZAVALA
# 4900        4900    254902                  LA PRYOR ISD  yr1415      ZAVALA
#
#      distischarter rating_academic rating_financial  eligible type  \
# 3682             N               M             Pass       1.0    H
# 3683             N               M             Pass       1.0    G
# 3684             N               M             Pass       1.0    H
# 3685             N               M             Pass       1.0    H
# 3686             N               M             Pass       1.0    E
# 3687             N               M             Pass       1.0    G
# 3688             N               M             Pass       1.0    H
# 3689             N               M             Pass       1.0    D
# 3690             Y               M             Pass       0.0    I
# 3691             N               M             Pass       1.0    G
# 3692             N               M             Pass       1.0    E
# 3693             N               M             Pass       1.0    G
# 3694             N               M             Pass       1.0    G
# 3695             N               M             Pass       1.0    H
# 3696             N               M             Pass       1.0    G
# 3697             N               M             Pass       1.0    E
# 3698             N               M             Pass       1.0    H
# 3699             N               M             Pass       1.0    D
# 3700             N               M             Pass       1.0    H
# 3701             N               M             Pass       1.0    H
# 3702             N               M             Pass       1.0    H
# 3703             N               M             Pass       1.0    F
# 3704             N               M             Pass       1.0    G
# 3705             N               M             Pass       1.0    E
# 3706             N               M             Pass       1.0    G
# 3707             N               M             Pass       1.0    E
# 3708             N               M             Pass       1.0    D
# 3709             N               M             Pass       1.0    H
# 3710             N               M             Fail       0.0    G
# 3711             N               M             Pass       1.0    H
# ...            ...             ...              ...       ...  ...
# 4871             N               M             Pass       1.0    H
# 4872             N               M             Pass       1.0    B
# 4873             N               M             Pass       1.0    H
# 4874             N               M             Pass       1.0    E
# 4875             N               M             Pass       1.0    E
# 4876             N               M             Pass       1.0    H
# 4877             N               M             Pass       1.0    H
# 4878             N               M             Pass       1.0    D
# 4879             N               M             Pass       1.0    F
# 4880             N               M             Pass       1.0    H
# 4881             N               M             Pass       1.0    G
# 4882             N               M             Pass       1.0    E
# 4883             N               M             Pass       1.0    H
# 4884             N               M             Pass       1.0    E
# 4885             N               M             Pass       1.0    G
# 4886             N               M             Pass       1.0    H
# 4887             N               M             Pass       1.0    H
# 4888             N               M             Pass       1.0    E
# 4889             N               M             Pass       1.0    E
# 4878 -0.961637  0.185511 -1.157366 -1.312836  -1.069730
# 4879 -0.215359 -1.630074 -0.526524 -0.651445  -0.395414
# 4880  0.133962 -0.904854  0.332251  0.822955   0.444193
# 4881 -0.130675  0.180439  0.342523  0.082354   0.119642
# 4882 -0.337093  0.276797 -0.130158 -0.351453  -0.193995
# 4883 -0.130675 -1.386643 -0.046062  0.365514   0.027477
# 4884  0.784970  0.931016  0.289454  0.222635   0.343309
# 4885  1.134291  0.484727  0.345803  0.323943   0.413117
# 4886 -0.707585  0.226082  0.092531 -0.090110   0.044126
# 4887 -0.294751  0.413726 -0.926971 -0.611661  -0.597110
# 4888  0.197475 -0.428137  0.120398  0.157429   0.174330
# 4889 -0.014235 -0.245564  0.172568  0.580068   0.336835
# 4890  0.409185  0.185511 -0.527505  0.005986  -0.199299
# 4891 -0.363556 -0.549852 -0.036513  0.755140   0.227538
# 4892  1.166048  0.053652  0.428695  0.646127   0.595158
# 4893 -0.120090  0.753515  0.346364 -0.098182   0.192989
# 4894  0.599724  0.758586  0.643450 -0.013819   0.429254
# 4895  0.440941 -0.047777  0.085697 -0.158238   0.083358
# 4896  0.949045  0.966516  0.121297  0.312102   0.552896
# 4897  0.414477  1.184589  0.740656  0.626395   0.627059
# 4898 -1.220981 -1.853218 -0.901220 -1.172165  -1.167068
# 4899 -1.538546 -1.239571 -1.311768 -1.515809  -1.387890
# 4900 -0.421776 -1.036712 -1.480632 -1.192016  -1.020155
#
#       students_teacher_ratio
# 3682                5.362454
# 3683                7.222552
# 3684                6.946367
# 3685                6.075534
# 3686                6.911340
# 3687                7.054401
# 3688                6.537815
# 3689                7.953147
# 3690                8.395445
# 3691                7.057644
# 3692                6.711290
# 3693                7.099515
# 3694                6.668970
# 3695                6.032211
# 3696                6.693583
# 3697                6.629902
# 3698                5.397536
# 3699                7.603376
# 3700                6.887218
# 3701                5.265487
# 3702                5.516129
# 3703                7.765097
# 3704                6.557377
# 3705                7.225597
# 3706                6.103714
# 3707                6.998379
# 3708                7.986846
# 3709                6.807818
# 3710                6.398381
# 3711                4.734982
# ...                      ...
# 4871                7.685076
# 4872                8.312038
# 4873                6.635514
# 4874                6.620121
# 4875                7.834975
# 4876                6.536934
# 4877                5.867419
# 4878                6.380827
# 4879                5.567715
# 4880                6.348624
# 4881                6.987879
# 4882                6.921797
# 4883                6.446105
# 4884                7.152397
# 4885                7.620014
# 4886                5.684932
# 4887                5.732087
# 4888                7.158322
# 4889                6.520190
# 4890                5.575080
# 4891                6.807662
# 4892                6.971594
# 4893                7.486129
# 4894                5.469880
# 4895                7.077185
# 4896                5.915493
# 4897                5.288111
# 4898                6.931197
# 4899                6.040853
# 4900                5.826297
#
# [1219 rows x 411 columns]

# %% [markdown]
# # Student Performance

# %% [markdown]
# ## Schedules

# %%
df = analysis.many_y_one_x(data = data, x_list = regulations.schedules,
                         x_labels = regulations.labels, y = 'avescores')
tables.var_diff_to_excel(file = table_path + 'Student Performance.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Exemption Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 5)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e397b35b8e1c> in <module>()
#       1 df = analysis.many_y_one_x(data = data, x_list = regulations.schedules,
# ----> 2                          x_labels = regulations.labels, y = 'avescores')
#       3 tables.var_diff_to_excel(file = table_path + 'Student Performance.xlsx',
#       4                          df = df,
#       5                          control_col = 'Control',
#
# TypeError: many_y_one_x() got an unexpected keyword argument 'x_list'

# %% [markdown]
# ## Class Size

# %%
df = analysis.many_y_one_x(data = data, y_list = regulations.class_size,
                         y_labels = regulations.labels, x = 'avescores')
tables.var_diff_to_excel(file = table_path + 'Student Performance.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Exemption Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 14)
df
# Out:
#                                Regulation  Control  Exemption Difference  \
# 0             25.112 - Class Size Maximum     0.43                  0.03
# 1           25.113 - Notice of Class Size     0.36                  0.04
# 2  25.111 - Maximum Student Teacher Ratio     0.16                  0.01
#
#    Std. Error  P-value
# 0        0.03     0.26
# 1        0.02     0.08
# 2        0.02     0.49

# %% [markdown]
# ## Certification

# %%
df = analysis.many_y_one_x(data = data, y_list = regulations.certification,
                         y_labels = regulations.labels, x = 'avescores')
tables.var_diff_to_excel(file = table_path + 'Student Performance.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Exemption Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 21)
df
# Out:
#                                       Regulation  Control  \
# 0        21.003 - Teacher Certification Required     0.74
# 1  21.053 - Presentation of Teacher Certificates     0.29
# 2         21.057 - Notice of Uncertified Teacher     0.29
#
#    Exemption Difference  Std. Error  P-value
# 0                 -0.00        0.02     0.85
# 1                 -0.04        0.02     0.11
# 2                 -0.01        0.02     0.53

# %% [markdown]
# ## Contracts

# %%
df = analysis.many_y_one_x(data = data, y_list = regulations.contracts,
                         y_labels = regulations.labels, x = 'avescores')
tables.var_diff_to_excel(file = table_path + 'Student Performance.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Exemption Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 28)
df
# Out:
#                                           Regulation  Control  \
# 0      21.102 - Maximum Probationary Contract Length     0.39
# 1  21.401 - Minimum Service Days Required for Tea...     0.35
# 2                     21.352 - Appraisal of Teachers     0.19
# 3                       21.354 - Principal Appriasal     0.06
#
#    Exemption Difference  Std. Error  P-value
# 0                 -0.00        0.02     0.94
# 1                 -0.05        0.02     0.05
# 2                  0.04        0.02     0.07
# 3                  0.02        0.01     0.09

# %% [markdown]
# ## Student Behavior

# %%
df = analysis.many_y_one_x(data = data, y_list = regulations.behavior,
                         y_labels = regulations.labels, x = 'avescores')
tables.var_diff_to_excel(file = table_path + 'Student Performance.xlsx', 
                         df = df, 
                         control_col = 'Control', 
                         diff_col = 'Exemption Difference', 
                         se_col = 'Std. Error', pvalue_col = 'P-value',
                         start_col = 3, start_row = 37)
df
# Out:
#                                           Regulation  Control  \
# 0       25.092 - Minimum Attendance for Class Credit     0.27
# 1  37.0012 - Designation of Campus Behavior Coord...     0.23
# 2                                 25.036 - Transfers     0.19
#
#    Exemption Difference  Std. Error  P-value
# 0                 -0.04        0.02     0.06
# 1                 -0.01        0.02     0.62
# 2                 -0.01        0.02     0.68
