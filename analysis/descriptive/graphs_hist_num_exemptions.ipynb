# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm


import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

from library import regulations
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'),
                  sep=",")
data = data[data.year == 'yr1415']
data = data[data.doi == True]
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
stubnames = sorted(
    set([match[0] for match in data.columns.str.findall(
    r'reg.*').values if match != [] ])
    )

# %%
proportion = []
number = []
for reg in stubnames:
    proportion.append(data[reg].mean())
    number.append(data[reg].sum())

# %%
regs = pd.DataFrame(
    {'law': stubnames,
     'proportion': proportion,
     'number': number
    }).sort_values(by = ['proportion'], ascending = False)
regs['label'] = regs['law'].map(regulations.labels)
regs.head(50)
# Out:
#             law  proportion  number  \
# 120  reg25_0811    0.901911   708.0
# 38    reg21_003    0.738854   580.0
# 134   reg25_112    0.431847   339.0
# 119   reg25_081    0.412739   324.0
# 60    reg21_102    0.384713   302.0
# 135   reg25_113    0.363057   285.0
# 74    reg21_401    0.343949   270.0
# 55    reg21_057    0.289172   227.0
# 121  reg25_0812    0.287898   226.0
# 52    reg21_053    0.286624   225.0
# 129   reg25_092    0.268790   211.0
# 183  reg37_0012    0.224204   176.0
# 122   reg25_082    0.205096   161.0
# 69    reg21_352    0.200000   157.0
# 115   reg25_036    0.189809   149.0
# 131   reg25_111    0.160510   126.0
# 72   reg21_3541    0.121019    95.0
# 161  reg28_0216    0.121019    95.0
# 14    reg11_251    0.115924    91.0
# 44    reg21_044    0.096815    76.0
# 160  reg28_0214    0.090446    71.0
# 65    reg21_203    0.076433    60.0
# 53    reg21_055    0.076433    60.0
# 71    reg21_354    0.068790    54.0
# 37    reg21_002    0.067516    53.0
# 81    reg21_404    0.066242    52.0
# 15    reg11_252    0.066242    52.0
# 92    reg21_458    0.064968    51.0
# 16    reg11_253    0.063694    50.0
# 152   reg28_004    0.059873    47.0
# 89    reg21_451    0.059873    47.0
# 50    reg21_051    0.049682    39.0
# 136   reg25_114    0.049682    39.0
# 254   reg45_206    0.047134    37.0
# 253   reg45_205    0.045860    36.0
# 123   reg25_083    0.044586    35.0
# 70    reg21_353    0.043312    34.0
# 124   reg25_084    0.042038    33.0
# 39   reg21_0031    0.038217    30.0
# 188   reg37_008    0.038217    30.0
# 68    reg21_351    0.036943    29.0
# 207   reg39_054    0.034395    27.0
# 108   reg25_001    0.034395    27.0
# 187   reg37_007    0.033121    26.0
# 241   reg44_902    0.033121    26.0
# 75    reg21_402    0.028025    22.0
# 82    reg21_405    0.026752    21.0
# 17    reg11_255    0.025478    20.0
# 184   reg37_002    0.024204    19.0
# 173  reg29_0821    0.022930    18.0
#
#                                                  label
# 120         25.0811 - Minimum First Day of Instruction
# 38             21.003 - Teacher Certification Required
# 134                        25.112 - Class Size Maximum
# 119              25.081 - Minimum Minutes of Operation
# 60       21.102 - Maximum Probationary Contract Length
# 135                      25.113 - Notice of Class Size
# 74   21.401 - Minimum Service Days Required for Tea...
# 55              21.057 - Notice of Uncertified Teacher
# 121          25.0812 - Minimum Last Day of Instruction
# 52       21.053 - Presentation of Teacher Certificates
# 129       25.092 - Minimum Attendance for Class Credit
# 183  37.0012 - Designation of Campus Behavior Coord...
# 122  25.082 - Pledge of Allegiance and Minute of Si...
# 69                         21.352 - Teacher Evaluation
# 115                                 25.036 - Transfers
# 131             25.111 - Maximum Student Teacher Ratio
# 72                      21.3541 - Principal Evaluation
# 161  21.0216 - District Grading Policy (includes fa...
# 14                                                 NaN
# 44                                                 NaN
# 160                        21.0214 - Finality of Grade
# 65                  21.203 - Annual Teacher Evaluation
# 53                 21.055 - Local Permit with Approval
# 71                   21.354 - Administrator Evaluation
# 37               21.002 - Teacher Employment Contracts
# 81              21.404 - Planning and Preparation Time
# 15                                                 NaN
# 92                            21.458 - Teacher Mentors
# 16                                                 NaN
# 152                                                NaN
# 89      21.451 - Professional Development Requirements
# 50             21.051 - Teacher Field Based Experience
# 136               25.114 - P.E. Student Teacher Ratios
# 254                                   45.206 - Bidding
# 253                 45.205 - Provider Term of Contract
# 123                                                NaN
# 70     25.353 - Teacher Appraisal Limited to Classroom
# 124  25.084 - Year-Round Attendance (includes false...
# 39   21.0031 - Failure to Obtain Certification Cont...
# 188        36.008 - Disciplinary Alternative Education
# 68                                                 NaN
# 207                                                NaN
# 108                                                NaN
# 187            37.007 - Expulsion for Serious Offenses
# 241                                                NaN
# 75                             21.402 - Minimum Salary
# 82                            21.504 - Duty-Free Lunch
# 17   11.255 - Drop-out Prevention Review (includes ...
# 184            37.002 - Student Removal from Classroom
# 173           29.0821 - Optional Flexible Year Program

# %% [markdown]
# # Number of Exemptions

# %%
false_laws = ['11_255', '11_251', '21.044', '11.253', '25.084', '21.351', '39.054','11.255', '28.0821']
#regs_sm = regs.head(50)
#regs_sm = regs_sm[~regs_sm.law.isin(false_laws)]
stubnames = sorted(
    set([match[0] for match in data.columns.str.findall(
    r'reg.*').values if match != [] ])
    )
for false in false_laws:
    if false in stubnames:
        stubnames.remove(false)

# %%
data['num_regs'] = data[stubnames].sum(axis = 1)
data['num_regs'][data.num_regs < 54].mean()
num_regs = data[data.num_regs < 54]['num_regs']
num_regs.mean()
num_regs.std()
# Out:
# 4.876199414886655

# %%
# This is  the colormap I'd like to use.
cm = plt.cm.get_cmap('plasma')

# Plot histogram.
n, bins, patches = plt.hist(num_regs, 10, normed=1, color='green')
bin_centers = 0.5 * (bins[:-1] + bins[1:])

# scale values to interval [0,1]
col = bin_centers - min(bin_centers)
col /= max(col)

for c, p in zip(col, patches):
    plt.setp(p, 'facecolor', cm(c))
    
plt.xlabel('Number of Exemptions')
plt.ylabel('Number of Districts')
plt.title(r'$\mathrm{Histogram\ of\ Number\ of\ Exemptions:}\ \mu=8,\ \sigma=5$')
#plt.axis([40, 160, 0, 0.03])
plt.grid(False)
plt.savefig(table_path + 'hist_num_exemptions.png', dpi = 600)


plt.show()
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
