# %%
import pandas as pd
import os
import fnmatch
import numpy as np
import random

# %%
datapath = '/Users/kylieleblancKylie/domino/dofis/data/'
#data = pd.read_csv(os.path.join(datapath, 'clean', 'teachers_final.csv'))
data = pd.read_csv(os.path.join(datapath, 'clean', 'teachers', 'teachers_yr1617.csv'))
print(len(data))
data.head()
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,41,42,43,44,45,57,58,59,60,61,73,74,75,76,77,89,90,91,92,93,105,106,107,108,109,121,122,123,124,125,137,138,139,140,141,153,154,155,156,157,169,170,171,172,173,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 358384
#   teacher_id teacher_first teacher_last  district        distname     campus  \
# 0  *30*00034       MCKENNA       BAXTER     61902  LEWISVILLE ISD   61902059
# 1  *30*0F443         PEDRO       BOITEL    101903       ALIEF ISD  101903143
# 2  *30*0LP36      VERONICA       KERETI     15910  NORTH EAST ISD   15910048
# 3  *30*1*Q47       KENNETH     GRIFFITH    126903    CLEBURNE ISD  126903001
# 4  *30*11241        ROBERT     ANCHONDO     71905      YSLETA ISD   71905050
#
# ...

# %%
test = len(data)*data.fte_teacher.mean()
test

# %%
data['fte_teacher'] = data['fte_teacher'].apply(pd.to_numeric, errors='coerce')

# %%
data['fte_teacher'].mean()
# Out:
# 0.9632926979579411

# %%
leander = data[data.district == 246913]
leander
# Out:
#        teacher_id teacher_first        teacher_last  district     distname  \
# 634     *32Q3FV39       RACHAEL             MARCELL    246913  LEANDER ISD
# 674     *33*0VP49          JOHN              CONNER    246913  LEANDER ISD
# 734     *3314*Q47         SUSAN               OLSEN    246913  LEANDER ISD
# 1582    *35*3V135        PHILIP                KING    246913  LEANDER ISD
# 1724    *35*5V137       EDUARDO               MEJIA    246913  LEANDER ISD
# 1736    *35*6*231         KEVIN              CARTER    246913  LEANDER ISD
# 1943    *35*V**45          DANA               RAITT    246913  LEANDER ISD
# 3011    *3514Q*32      KATHLEEN               ARTUZ    246913  LEANDER ISD
# 3443    *3520VP36         EMILY            MCMULLEN    246913  LEANDER ISD
# 3547    *3522PV35      LILLIANA            KENDRICK    246913  LEANDER ISD
# 3675    *3524PV38      MICHELLE           TANNEHILL    246913  LEANDER ISD
# ...

# %%
len(leander[leander.sub_area1 != 'NOT APPLICABLE'])
# Out:
# 1503

# %%
len(leander)
# Out:
# 2597
