# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import re
import numpy as np
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'))
data = data[data.year == 2018]
data.head()
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0  year   campus        campname campischarter  district  \
# 51734       51734  2018  1902001      CAYUGA H S             N      1902
# 51735       51735  2018  1902041   CAYUGA MIDDLE             N      1902
# 51736       51736  2018  1902103       CAYUGA EL             N      1902
# 51737       51737  2018  1903001     ELKHART H S             N      1903
# 51738       51738  2018  1903041  ELKHART MIDDLE             N      1903
#
#           distname distischarter rating_academic rating_financial  ...  \
# 51734   CAYUGA ISD             N               B             Pass  ...
# 51735   CAYUGA ISD             N               B             Pass  ...
# 51736   CAYUGA ISD             N               B             Pass  ...
# 51737  ELKHART ISD             N               B             Pass  ...
# 51738  ELKHART ISD             N               B             Pass  ...
#
#       charter district_status type_urban type_suburban  type_town  type_rural  \
# 51734   False             doi          0             0          0           1
# 51735   False             doi          0             0          0           1
# 51736   False             doi          0             0          0           1
# 51737   False             doi          0             0          1           0
# 51738   False             doi          0             0          1           0
#
#        teachers_nodegree  teachers_badegree  teachers_msdegree  \
# 51734                0.0           0.907514           0.092486
# 51735                0.0           0.855072           0.137681
# 51736                0.0           1.000000           0.000000
# 51737                0.0           0.702703           0.297297
# 51738                0.0           0.905579           0.090129
#
#        teachers_phddegree
# 51734                 0.0
# 51735                 0.0
# 51736                 0.0
# 51737                 0.0
# 51738                 0.0
#
# [5 rows x 304 columns]

# %%
# School Characteristics

# %%
print('There are', data.campus.nunique(), 'schools in Texas.')
print('Of these,', data[data.campischarter == 'Y'].campus.nunique(), 'are charters.')
print('Of traditional public schools only', 
      data[data.campischarter == 'N'][data.eligible == 0].schools_num.sum(axis = 0), 
      'are ineligible for DOI status.')
print(len(data[data.doi == True].sum(axis = 0)), 'districts are districts of innovation.')
# Out:
# There are 8755 schools in Texas.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ee65bec2f826> in <module>()
#       1 print('There are', data.campus.nunique(), 'schools in Texas.')
# ----> 2 print('Of these,', data[data.distischarter == 'Y'].schools_num.sum(axis = 0), 'are charters.')
#       3 print('Of traditional public schools only',
#       4       data[data.distischarter == 'N'][data.eligible == 0].schools_num.sum(axis = 0),
#       5       'are ineligible for DOI status.')
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'schools_num'
