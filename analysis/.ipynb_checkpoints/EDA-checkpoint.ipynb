# %%
import pandas as pd
import os
# %matplotlib inline
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'

# %%
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'),
                  sep=",")

# %%
tea_vars = [
 'district', 'distname','year','cntyname',
 'distischarter','doi','rating',
 'type','type_description','type_urban','type_suburban','type_town',
 'students_num','students_frpl','students_black','students_hisp','students_white',
 'teachers_num','teachers_new_num',
 'teacher_turnover_num','teachers_turnover_denom','teachers_turnover_ratio',
 'teachers_exp_ave','teachers_tenure_ave',
 'teachers_nodegree','teachers_badegree','teachers_msdegree','teachers_phddegree',
 'r_3rd_avescore','m_3rd_avescore','r_4th_avescore','m_4th_avescore',
 'r_5th_avescore','m_5th_avescore','r_6th_avescore','m_6th_avescore',
 'r_7th_avescore','m_7th_avescore','r_8th_avescore','m_8th_avescore',
 'alg_avescore','bio_avescore','eng1_avescore','eng2_avescore','us_avescore']

# %% [markdown]
# ## 3rd Grade

# %%
year = data.groupby(['year']).mean()['m_3rd_avescore'].index
m_score = data.groupby(['year']).mean()['m_3rd_avescore'].values
r_score = data.groupby(['year']).mean()['r_3rd_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Average 3rd Grade STAAR')
ax.grid()
ax.legend()

ax.set_ylim(1200, 1800)

#fig.savefig("test.png")
plt.show()

# %%
year = data.groupby(['year']).mean()['m_3rd_std'].index
m_score = data.groupby(['year']).mean()['m_3rd_std'].values
r_score = data.groupby(['year']).mean()['r_3rd_std'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Standardized 3rd Grade STAAR')
ax.grid()
ax.legend()

ax.set_ylim(-1, 1)

#fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## 4th Grade

# %%
year = data.groupby(['year']).mean()['m_4th_avescore'].index
m_score = data.groupby(['year']).mean()['m_4th_avescore'].values
r_score = data.groupby(['year']).mean()['r_4th_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Average 4th Grade STAAR')
ax.grid()
ax.legend()

ax.set_ylim(1200, 1800)

#fig.savefig("test.png")
plt.show()

# %%
year = data.groupby(['year']).mean()['m_4th_std'].index
m_score = data.groupby(['year']).mean()['m_4th_std'].values
r_score = data.groupby(['year']).mean()['r_4th_std'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Standardized 4th Grade STAAR')
ax.grid()
ax.legend()

ax.set_ylim(-1, 1)

#fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## Fifth Grade

# %%
year = data.groupby(['year']).mean()['m_5th_avescore'].index
m_score = data.groupby(['year']).mean()['m_5th_avescore'].values
r_score = data.groupby(['year']).mean()['r_5th_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Average 5th Grade STAAR')
ax.grid()

ax.legend()

ax.set_ylim(1200, 1800)

plt.show()

# %%
year = data.groupby(['year']).mean()['m_5th_std'].index
m_score = data.groupby(['year']).mean()['m_5th_std'].values
r_score = data.groupby(['year']).mean()['r_5th_std'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Standardized 5th Grade STAAR')
ax.grid()

ax.legend()

ax.set_ylim(-1, 1)

plt.show()

# %% [markdown]
# ## 6th

# %%
year = data.groupby(['year']).mean()['m_6th_avescore'].index
m_score = data.groupby(['year']).mean()['m_6th_avescore'].values
r_score = data.groupby(['year']).mean()['r_6th_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Average 6th Grade STAAR')
ax.grid()

ax.legend()

ax.set_ylim(1200, 1800)

plt.show()

# %%
year = data.groupby(['year']).mean()['m_6th_std'].index
m_score = data.groupby(['year']).mean()['m_6th_std'].values
r_score = data.groupby(['year']).mean()['r_6th_std'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Standardized 6th Grade STAAR')
ax.grid()

ax.legend()

ax.set_ylim(-1,1)

plt.show()

# %% [markdown]
# ## 7th

# %%
year = data.groupby(['year']).mean()['m_7th_avescore'].index
m_score = data.groupby(['year']).mean()['m_7th_avescore'].values
r_score = data.groupby(['year']).mean()['r_7th_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Average 7th Grade STAAR')
ax.grid()
ax.legend()

ax.set_ylim(1200, 1800)

fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## 8th

# %%
year = data.groupby(['year']).mean()['m_8th_avescore'].index
m_score = data.groupby(['year']).mean()['m_8th_avescore'].values
r_score = data.groupby(['year']).mean()['r_8th_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score, label = "Math")
ax.plot(year, r_score, label = "Reading")

ax.set(xlabel='Year', ylabel='Score',
       title='Average 8th Grade Math')
ax.grid()

ax.legend()

ax.set_ylim(1200, 1800)

fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## Algebra

# %%
year = data.groupby(['year']).mean()['alg_avescore'].index
m_score = data.groupby(['year']).mean()['alg_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score)


ax.set(xlabel='Year', ylabel='Score',
       title='Average Algebra')
ax.grid()

ax.set_ylim(3200, 4200)

fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## English 1 and 2

# %%
year = data.groupby(['year']).mean()['eng1_avescore'].index
e1_score = data.groupby(['year']).mean()['eng1_avescore'].values
e2_score = data.groupby(['year']).mean()['eng2_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, e1_score, label = "English I")
ax.plot(year, e2_score, label = "English II")

ax.set(xlabel='Year', ylabel='Score',
       title='Average English 1 and 2')
ax.grid()
ax.legend()
ax.set_ylim(3200, 4200)
#fig.savefig("test.png")
plt.show()

# %% [markdown]
# # # Biology

# %%
year = data.groupby(['year']).mean()['bio_avescore'].index
m_score = data.groupby(['year']).mean()['bio_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score)


ax.set(xlabel='Year', ylabel='Score',
       title='Average Biology')
ax.grid()

ax.set_ylim(3200, 4200)

fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## US History

# %%
year = data.groupby(['year']).mean()['us_avescore'].index
m_score = data.groupby(['year']).mean()['us_avescore'].values

fig, ax = plt.subplots()
ax.plot(year, m_score)


ax.set(xlabel='Year', ylabel='Score',
       title='Average US History')
ax.grid()

ax.set_ylim(3400, 4400)

fig.savefig("test.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
a = data.groupby(['year','doi']).mean()['m_3rd_avescore'].unstack()
a.plot(ax=ax)
ax.set(xlabel='Year', ylabel='Score',
       title='Average 3rd Grade Math')
ax.grid()
plt.xticks(np.arange(len(data['year'].unique())), a.index)
plt.show()

# %%
yr1415 = data[data.year == 'yr1415']
subjects = ['r_3rd', 'm_3rd', 'r_4th', 'm_4th', 'r_5th', 'm_5th',
            'r_6th', 'm_6th', 'r_7th', 'm_7th', 'r_8th', 'm_8th',
            'alg', 'bio', 'eng1', 'eng2', 'us']
means = []
sds = []
for var in subjects:
    sub = var + '_avescore'
    mean = yr1415[sub].mean()
    means.append(mean)
    sd = yr1415[sub].std()
    sds.append(sd)
print(means)
print(sds)
# Out:
# [1422.3097497842969, 1432.8997407087295, 1503.2203975799482, 1515.381158167675, 1550.5288048151333, 1581.2641996557659, 1585.8315881326353, 1603.9546643417611, 1640.2813321647677, 1632.942832014072, 1674.7252843394576, 1644.5279007971656, 3910.0322003577817, 4043.6294896030245, 3937.915750915751, 3936.6895273401296, 4042.4207089552237]
# [46.037228682029166, 53.981849842233615, 50.74100392949069, 55.89211144863735, 48.75679735513131, 54.84229909269244, 46.41604616864496, 52.097268090904514, 43.09897516157625, 48.460010412980274, 44.401919099145154, 52.58442528840774, 216.27726170560504, 196.51124305505508, 202.30697932968957, 188.93781552927646, 197.18170053393382]

# %%
for sub, mean, sd in zip(subjects, means, sds):
    old_var = sub + "_avescore"
    new_var = sub + "_std"
    data[new_var] = (data[old_var] - mean)/sd
data['r_3rd_std']
# Out:
# 0      -0.332552
# 1       0.014993
# 2       0.753526
# 3       2.773630
# 4      -0.397716
# 5      -0.484602
# 6      -0.875590
# 7      -0.332552
# 8      -1.418629
# 9       0.601475
# 10     -0.680096
# 11     -0.289108
# 12     -0.267387
# 13      0.319095
# 14     -0.071893
# 15     -0.397716
# 16      0.058436
# 17      0.601475
# 18      1.209679
# 19      0.253930
# 20     -1.505515
# 21     -0.115336
# 22     -0.919033
# 23      0.080158
# 24     -0.093614
# 25      0.666640
# 26     -0.310830
# 27      0.731804
# 28     -0.658375
# 29      0.753526
#           ...
# 8484    0.775248
# 8485    1.557223
# 8486    0.319095
# 8487    0.232209
# 8488    0.253930
# 8489    1.948211
# 8490    1.340008
# 8491   -1.396907
# 8492   -0.375995
# 8493    1.578945
# 8494    0.731804
# 8495   -0.006728
# 8496   -0.701818
# 8497    0.579754
# 8498    0.731804
# 8499   -0.636653
# 8500    0.340817
# 8501   -0.202222
# 8502    1.513780
# 8503    1.405173
# 8504    0.253930
# ...

# %%
data = standardize_scores(data=data, std_year = 'yr1415')
data['r_3rd_std']
# Out:
# 0      -0.332552
# 1       0.014993
# 2       0.753526
# 3       2.773630
# 4      -0.397716
# 5      -0.484602
# 6      -0.875590
# 7      -0.332552
# 8      -1.418629
# 9       0.601475
# 10     -0.680096
# 11     -0.289108
# 12     -0.267387
# 13      0.319095
# 14     -0.071893
# 15     -0.397716
# 16      0.058436
# 17      0.601475
# 18      1.209679
# 19      0.253930
# 20     -1.505515
# 21     -0.115336
# 22     -0.919033
# 23      0.080158
# 24     -0.093614
# 25      0.666640
# 26     -0.310830
# 27      0.731804
# 28     -0.658375
# 29      0.753526
#           ...
# 8484    0.775248
# 8485    1.557223
# 8486    0.319095
# 8487    0.232209
# 8488    0.253930
# 8489    1.948211
# 8490    1.340008
# 8491   -1.396907
# 8492   -0.375995
# 8493    1.578945
# 8494    0.731804
# 8495   -0.006728
# 8496   -0.701818
# 8497    0.579754
# 8498    0.731804
# 8499   -0.636653
# 8500    0.340817
# 8501   -0.202222
# 8502    1.513780
# 8503    1.405173
# 8504    0.253930
# ...
