# %%
import sys
sys.path.append("../")

import pandas as pd
import os

from library import regulations
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data_district.csv'),
                  sep=",")
data.sample(5)
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Unnamed: 0  year  district                            distname  \
# 7613        7613  2018     61802      NORTH TEXAS COLLEGIATE ACADEMY
# 3264        3264  2014    161807         HARMONY SCIENCE ACAD (WACO)
# 4773        4773  2015    227806  UNIVERSITY OF TEXAS UNIVERSITY CHA
# 4662        4662  2015    201903                       LANEVILLE ISD
# 1663        1663  2013     87901                GLASSCOCK COUNTY ISD
#
#      distischarter rating_academic rating_financial type  \
# 7613             Y               C             Pass    I
# 3264             Y               M              NaN    I
# 4773             Y               A             Pass    I
# ...

# %%
data = data[data.year == 2016]
data = data[data.doi == True]
data.sample(5)
# Out:
#       Unnamed: 0  year  district               distname distischarter  \
# 5743        5743  2016    169911           SAINT JO ISD             N
# 5449        5449  2016    102903             WASKOM ISD             N
# 6002        6002  2016    228905      APPLE SPRINGS ISD             N
# 6035        6035  2016    236901        NEW WAVERLY ISD             N
# 5618        5618  2016    138902  KNOX CITY-O’BRIEN ISD             N
#
#      rating_academic rating_financial type         type_description  cntyname  \
# 5743               M             Pass    H                    RURAL  MONTAGUE
# 5449               M             Pass    G  NON-METROPOLITAN STABLE  HARRISON
# 6002               M             Pass    H                    RURAL   TRINITY
# 6035               M             Pass    G  NON-METROPOLITAN STABLE    WALKER
# 5618               M             Pass    H                    RURAL      KNOX
#
# ...

# %%
data.geography.value_counts()
# Out:
# Rural       361
# Town        222
# Suburban    200
# Urban        39
# Name: geography, dtype: int64

# %% [markdown]
# # Geography

# %%
columns = ['Count', 'Percent Urban', 'Percent Suburban', 'Percent Town', 'Percent Rural', 'F-test p-value']

# %%
schedules_df = analysis.create_count_proportion_df(data, list_of_regs = regulations.schedules, 
                                                dict_of_reg_labels = regulations.labels)
tables.df_to_excel(file = table_path + 'desc_exemptionsXgeography.xlsx', df = schedules_df,
                  df_columns = columns, start_row = 5, start_col = 3)
schedules_df
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)
#                                           Regulation  Count  Percent Urban  \
# 0         25.0811 - Minimum First Day of Instruction    798           0.95
# 1              25.081 - Minimum Minutes of Operation    356           0.49
# 2          25.0812 - Minimum Last Day of Instruction    231           0.26
# 3  25.082 - Pledge of Allegiance and Minute of Si...    208           0.26
#
#    Percent Suburban  Percent Town  Percent Rural  F-test p-value
# 0              0.96          0.98           0.98            0.30
# 1              0.40          0.39           0.47            0.17
# 2              0.24          0.26           0.32            0.26
# ...

# %%
class_size_df = analysis.create_count_proportion_df(data, list_of_regs = regulations.class_size,
                                                 dict_of_reg_labels = regulations.labels)
tables.df_to_excel(file = table_path + 'desc_exemptionsXgeography.xlsx', df = class_size_df,
                  df_columns = columns, start_row = 10, start_col = 3)
class_size_df
# Out:
#                                Regulation  Count  Percent Urban  \
# 0             25.112 - Class Size Maximum    363           0.38
# 1           25.113 - Notice of Class Size    299           0.36
# 2  25.111 - Maximum Student Teacher Ratio    127           0.21
#
#    Percent Suburban  Percent Town  Percent Rural  F-test p-value
# 0              0.42          0.45           0.45            0.81
# 1              0.35          0.39           0.36            0.86
# 2              0.16          0.14           0.15            0.76

# %%
certification_df = analysis.create_count_proportion_df(data, 
                                                 list_of_regs = regulations.certification, 
                                                 dict_of_reg_labels = regulations.labels)
tables.df_to_excel(file = table_path + 'desc_exemptionsXgeography.xlsx', df = certification_df,
                  df_columns = columns, start_row = 14, start_col = 3)
certification_df
# Out:
#                                       Regulation  Count  Percent Urban  \
# 0        21.003 - Teacher Certification Required    714           0.74
# 1  21.053 - Presentation of Teacher Certificates    240           0.31
# 2         21.057 - Notice of Uncertified Teacher    271           0.28
#
#    Percent Suburban  Percent Town  Percent Rural  F-test p-value
# 0              0.82          0.88           0.91            0.00
# 1              0.24          0.32           0.30            0.40
# 2              0.26          0.36           0.35            0.12

# %%
contracts_df = analysis.create_count_proportion_df(data, 
                                                 list_of_regs = regulations.contracts, 
                                                 dict_of_reg_labels = regulations.labels)
tables.df_to_excel(file = table_path + 'desc_exemptionsXgeography.xlsx', df = contracts_df,
                  df_columns = columns, start_row = 18, start_col = 3)
contracts_df
# Out:
#                                           Regulation  Count  Percent Urban  \
# 0      21.102 - Maximum Probationary Contract Length    419           0.18
# 1  21.401 - Minimum Service Days Required for Tea...    290           0.03
# 2                        21.352 - Teacher Evaluation    166           0.21
# 3                  21.354 - Administrator Evaluation     46           0.10
#
#    Percent Suburban  Percent Town  Percent Rural  F-test p-value
# 0              0.41          0.58           0.56            0.00
# 1              0.12          0.28           0.56            0.00
# 2              0.22          0.20           0.19            0.88
# 3              0.06          0.04           0.06            0.44

# %%
behavior_df = analysis.create_count_proportion_df(data, 
                                                 list_of_regs = regulations.behavior, 
                                                 dict_of_reg_labels = regulations.labels)
tables.df_to_excel(file = table_path + 'desc_exemptionsXgeography.xlsx', df = behavior_df,
                  df_columns = columns, start_row = 23, start_col = 3)
behavior_df
# Out:
#                                           Regulation  Count  Percent Urban  \
# 0       25.092 - Minimum Attendance for Class Credit    214           0.51
# 1  37.0012 - Designation of Campus Behavior Coord...    178           0.36
# 2                                 25.036 - Transfers    178           0.05
#
#    Percent Suburban  Percent Town  Percent Rural  F-test p-value
# 0              0.34          0.26           0.19             0.0
# 1              0.28          0.27           0.13             0.0
# 2              0.06          0.23           0.31             0.0
