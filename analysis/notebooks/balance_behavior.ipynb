# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm

from library import regulations
from library import characteristics
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data_district.csv'),
                  sep=",", low_memory = False)
data.head()
# Out:
#    Unnamed: 0  year  district       distname distischarter rating_academic  \
# 0           0  2012      1902     CAYUGA ISD             N             NaN
# 1           1  2012      1903    ELKHART ISD             N             NaN
# 2           2  2012      1904  FRANKSTON ISD             N             NaN
# 3           3  2012      1906     NECHES ISD             N             NaN
# 4           4  2012      1907  PALESTINE ISD             N             NaN
#
#   rating_financial type         type_description  cntyname  ...  \
# 0              NaN    H                    RURAL  ANDERSON  ...
# 1              NaN    G  NON-METROPOLITAN STABLE  ANDERSON  ...
# 2              NaN    H                    RURAL  ANDERSON  ...
# 3              NaN    H                    RURAL  ANDERSON  ...
# 4              NaN    E         INDEPENDENT TOWN  ANDERSON  ...
#
#    district_status  type_urban  type_suburban  type_town  type_rural  \
# 0              doi           0              0          0           1
# 1              doi           0              0          1           0
# 2              doi           0              0          0           1
# 3              doi           0              0          0           1
# 4              doi           0              0          1           0
#
#    eligible  teachers_nodegree  teachers_badegree  teachers_msdegree  \
# 0         1           0.000000           0.880443           0.119557
# 1         1           0.000000           0.827979           0.171917
# 2         1           0.000000           0.826226           0.173774
# 3         1           0.000000           0.969697           0.030303
# 4         1           0.004019           0.808958           0.182775
#
#    teachers_phddegree
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.004261
#
# [5 rows x 321 columns]

# %% [markdown]
# Just keep doi districts from 2015-16

# %%
data = data[data.year == 2016]
data = data[data.doi == True]
data
# Out:
#       Unnamed: 0  year  district           distname distischarter  \
# 4901        4901  2016      1902         CAYUGA ISD             N
# 4902        4902  2016      1903        ELKHART ISD             N
# 4903        4903  2016      1904      FRANKSTON ISD             N
# 4904        4904  2016      1906         NECHES ISD             N
# 4905        4905  2016      1907      PALESTINE ISD             N
# ...          ...   ...       ...                ...           ...
# 6102        6102  2016    252901         GRAHAM ISD             N
# 6103        6103  2016    252902      NEWCASTLE ISD             N
# 6104        6104  2016    252903          OLNEY ISD             N
# 6105        6105  2016    253901  ZAPATA COUNTY ISD             N
# 6107        6107  2016    254902       LA PRYOR ISD             N
#
#      rating_academic rating_financial type             type_description  \
# 4901               M             Pass    H                        RURAL
# 4902               M             Pass    G      NON-METROPOLITAN STABLE
# 4903               M             Pass    H                        RURAL
# 4904               M             Pass    H                        RURAL
# 4905               M             Pass    E             INDEPENDENT TOWN
# ...              ...              ...  ...                          ...
# 6102               M             Pass    G      NON-METROPOLITAN STABLE
# 6103               M             Pass    H                        RURAL
# 6104               M             Pass    H                        RURAL
# 6105               M             Pass    D  OTHER CENTRAL CITY SUBURBAN
# 6107               M             Pass    H                        RURAL
#
#       cntyname  ...  district_status  type_urban  type_suburban  type_town  \
# 4901  ANDERSON  ...              doi           0              0          0
# 4902  ANDERSON  ...              doi           0              0          1
# 4903  ANDERSON  ...              doi           0              0          0
# 4904  ANDERSON  ...              doi           0              0          0
# 4905  ANDERSON  ...              doi           0              0          1
# ...        ...  ...              ...         ...            ...        ...
# 6102     YOUNG  ...              doi           0              0          1
# 6103     YOUNG  ...              doi           0              0          0
# 6104     YOUNG  ...              doi           0              0          0
# 6105    ZAPATA  ...              doi           0              1          0
# 6107    ZAVALA  ...              doi           0              0          0
#
#       type_rural  eligible  teachers_nodegree  teachers_badegree  \
# 4901           1         1           0.000000           0.908088
# 4902           0         1           0.000000           0.850449
# 4903           1         1           0.001721           0.877797
# 4904           1         1           0.000000           1.000000
# 4905           0         1           0.025157           0.868664
# ...          ...       ...                ...                ...
# 6102           0         1           0.000000           0.840647
# 6103           1         1           0.000000           0.684211
# 6104           1         1           0.000000           0.849521
# 6105           0         1           0.026432           0.849780
# 6107           1         1           0.055310           0.723451
#
#       teachers_msdegree  teachers_phddegree
# 4901           0.091912            0.000000
# 4902           0.149551            0.000000
# 4903           0.120482            0.000000
# 4904           0.000000            0.000000
# 4905           0.106178            0.000000
# ...                 ...                 ...
# 6102           0.159353            0.000000
# 6103           0.315789            0.000000
# 6104           0.150479            0.001368
# 6105           0.123789            0.000000
# 6107           0.221239            0.000000
#
# [822 rows x 321 columns]

# %% [markdown]
# ## 25.092

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_092')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_092')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_092')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_behavior.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 2, start_row = row)
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):

# %%
data.teachers_turnover_ratio
# Out:
# 4901    21.3
# 4902    14.9
# 4903    22.5
# 4904    13.6
# 4905    21.9
#         ...
# 6102    14.4
# 6103    10.0
# 6104    25.1
# 6105    11.1
# 6107    30.9
# Name: teachers_turnover_ratio, Length: 822, dtype: float64

# %% [markdown]
# ## 37.0012

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg37_0012')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg37_0012')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg37_0012')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_behavior.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 3, start_row = row)
district
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#   Characteristic  Control  Difference  Std. Error  P-value
# 0          Urban     0.04        0.04        0.02     0.03
# 1       Suburban     0.23        0.08        0.04     0.02
# 2           Town     0.25        0.09        0.04     0.01
# 3          Rural     0.49       -0.22        0.04     0.00

# %% [markdown]
# ## 25.036

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_036')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_036')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_036')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_behavior.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 4, start_row = row)
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
