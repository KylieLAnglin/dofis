# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm
import statsmodels.formula.api as smf

from library import regulations
from library import characteristics
from library import analysis
from library import tables

from openpyxl import load_workbook

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'),
                  sep=",")
data = data[data.year == 'yr1516']
data = data[data.doi == 1]
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
x_list = ['type_urban', 'type_suburban', 'type_town',  
           'teachers_tenure_ave', 'teachers_turnover_ratio', 'students_teacher_ratio',
           'students_hisp', 'students_black', 'students_frpl', 'avescores']

# %% [markdown]
# # Schedules

# %%
tables.model_to_excel(data, y = 'reg25_0811', x_list = x_list, 
                      file = table_path + 'PS_schedules.xlsx', start_row = 4, start_col = 2)
tables.model_to_excel(data, y = 'reg25_081', x_list = x_list, 
                      file = table_path + 'PS_schedules.xlsx', start_row = 4, start_col = 3)
tables.model_to_excel(data, y = 'reg25_0812', x_list = x_list, 
                      file = table_path + 'PS_schedules.xlsx', start_row = 4, start_col = 4)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.317697
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.670156
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.594185
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.500743
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              reg25_082   No. Observations:                  784
# Model:                          Logit   Df Residuals:                      774
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 19 Oct 2018   Pseudo R-squ.:                 0.01378
# Time:                        21:33:40   Log-Likelihood:                -392.58
# ...

# %% [markdown]
# # Certification and Class Sizes

# %%
tables.model_to_excel(data, y = 'reg21_003', x_list = x_list, 
                      file = table_path + 'PS_certification.xlsx', start_row = 4, start_col = 2)
tables.model_to_excel(data, y = 'reg25_112', x_list = x_list, 
                      file = table_path + 'PS_certification.xlsx', start_row = 4, start_col = 4)
tables.model_to_excel(data, y = 'reg25_111', x_list = x_list, 
                      file = table_path + 'PS_certification.xlsx', start_row = 4, start_col = 5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.566437
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592138
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.676611
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.439188
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              reg25_111   No. Observations:                  784
# Model:                          Logit   Df Residuals:                      774
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 19 Oct 2018   Pseudo R-squ.:               -0.001025
# Time:                        21:33:41   Log-Likelihood:                -344.32
# ...

# %% [markdown]
# # Contracts

# %%
tables.model_to_excel(data, y = 'reg21_102', x_list = x_list, 
                      file = table_path + 'PS_contracts.xlsx', start_row = 4, start_col = 2)
tables.model_to_excel(data, y = 'reg21_401', x_list = x_list, 
                      file = table_path + 'PS_contracts.xlsx', start_row = 4, start_col = 3)
tables.model_to_excel(data, y = 'reg21_352', x_list = x_list, 
                     file = table_path + 'PS_contracts.xlsx', start_row = 4, start_col = 4)
tables.model_to_excel(data, y = 'reg21_354', x_list = x_list, 
                      file = table_path + 'PS_contracts.xlsx', start_row = 4, start_col = 5)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.647782
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569178
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500382
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.244046
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              reg21_354   No. Observations:                  784
# Model:                          Logit   Df Residuals:                      774
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 19 Oct 2018   Pseudo R-squ.:                 0.02664
# Time:                        21:33:41   Log-Likelihood:                -191.33
# ...

# %% [markdown]
# # Behavior

# %%
tables.model_to_excel(data, y = 'reg25_092', x_list = x_list, 
                      file = table_path + 'PS_behavior.xlsx', start_row = 4, start_col = 2)
tables.model_to_excel(data, y = 'reg37_0012', x_list = x_list, 
                      file = table_path + 'PS_behavior.xlsx', start_row = 4, start_col = 3)
tables.model_to_excel(data, y = 'reg25_036', x_list = x_list, 
                      file = table_path + 'PS_behavior.xlsx', start_row = 4, start_col = 4)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.552209
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.515320
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450688
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              reg25_036   No. Observations:                  784
# Model:                          Logit   Df Residuals:                      774
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 19 Oct 2018   Pseudo R-squ.:                 0.07323
# Time:                        21:33:41   Log-Likelihood:                -353.34
# converged:                       True   LL-Null:                       -381.26
#                                         LLR p-value:                 8.438e-09
# ...
