# %%
import os
# %matplotlib inline
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from patsy import dmatrices
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'cits_match.csv'),
                  sep=",", low_memory=False)

# %%
# CITS dataset
year_centered + treatyear + yearpost + treatpostyear + treatpostyear2

# %%
data[data.year == 2018][['distname', 'year', 'doi_year', 'treat', 'year_centered', 'treatyear', 'yearpost','treatpostyear', 'treatpostyear2']]
# Out:
#                 distname  year  doi_year  treat  year_centered  treatyear  \
# 6             CAYUGA ISD  2018    2017.0      1            1.0        1.0
# 13           ELKHART ISD  2018    2018.0      1            0.0        0.0
# 20         FRANKSTON ISD  2018    2018.0      1            0.0        0.0
# 27            NECHES ISD  2018    2017.0      1            1.0        1.0
# 34         PALESTINE ISD  2018    2016.0      1            2.0        2.0
# 41          WESTWOOD ISD  2018    2017.0      1            1.0        1.0
# 48            SLOCUM ISD  2018    2016.0      1            2.0        2.0
# 55           ANDREWS ISD  2018       NaN      0            2.0        0.0
# 62            HUDSON ISD  2018    2017.0      1            1.0        1.0
# 69            LUFKIN ISD  2018    2017.0      1            1.0        1.0
# 76        HUNTINGTON ISD  2018    2017.0      1            1.0        1.0
# 83            DIBOLL ISD  2018       NaN      0            2.0        0.0
# 90           CENTRAL ISD  2018       NaN      0            2.0        0.0
# 97    ARANSAS COUNTY ISD  2018    2017.0      1            1.0        1.0
# 104      ARCHER CITY ISD  2018    2018.0      1            0.0        0.0
# 111         HOLLIDAY ISD  2018    2017.0      1            1.0        1.0
# 118       WINDTHORST ISD  2018    2017.0      1            1.0        1.0
# 125        CHARLOTTE ISD  2018       NaN      0            2.0        0.0
# 132       JOURDANTON ISD  2018    2017.0      1            1.0        1.0
# 139       PLEASANTON ISD  2018       NaN      0            2.0        0.0
# 146        BELLVILLE ISD  2018       NaN      0            2.0        0.0
# 153            SEALY ISD  2018       NaN      0            2.0        0.0
# 160           BRAZOS ISD  2018    2017.0      1            1.0        1.0
# 167           MEDINA ISD  2018       NaN      0            2.0        0.0
# 174          BANDERA ISD  2018       NaN      0            2.0        0.0
# 181          BASTROP ISD  2018    2017.0      1            1.0        1.0
# 188            ELGIN ISD  2018    2017.0      1            1.0        1.0
# 195       SMITHVILLE ISD  2018    2018.0      1            0.0        0.0
# 202           MCDADE ISD  2018       NaN      0            2.0        0.0
# 209          SEYMOUR ISD  2018    2017.0      1            1.0        1.0
# ...                  ...   ...       ...    ...            ...        ...
# 6110           HUTTO ISD  2018    2017.0      1            1.0        1.0
# 6117         JARRELL ISD  2018    2016.0      1            2.0        2.0
# 6124          TAYLOR ISD  2018    2017.0      1            1.0        1.0
# 6131          THRALL ISD  2018    2017.0      1            1.0        1.0
# 6138         LEANDER ISD  2018    2018.0      1            0.0        0.0
# 6145        COUPLAND ISD  2018    2017.0      1            1.0        1.0
# 6152     FLORESVILLE ISD  2018    2017.0      1            1.0        1.0
# 6159            POTH ISD  2018    2017.0      1            1.0        1.0
# 6166       STOCKDALE ISD  2018    2017.0      1            1.0        1.0
# 6173          KERMIT ISD  2018       NaN      0            2.0        0.0
# 6180          ALVORD ISD  2018    2017.0      1            1.0        1.0
# 6187            BOYD ISD  2018    2017.0      1            1.0        1.0
# 6194      BRIDGEPORT ISD  2018    2017.0      1            1.0        1.0
# 6201           CHICO ISD  2018    2017.0      1            1.0        1.0
# 6208         DECATUR ISD  2018    2017.0      1            1.0        1.0
# 6215        PARADISE ISD  2018    2017.0      1            1.0        1.0
# 6222         SLIDELL ISD  2018    2016.0      1            2.0        2.0
# 6229         HAWKINS ISD  2018       NaN      0            2.0        0.0
# 6236         MINEOLA ISD  2018    2016.0      1            2.0        2.0
# 6243         QUITMAN ISD  2018    2018.0      1            0.0        0.0
# 6250          YANTIS ISD  2018       NaN      0            2.0        0.0
# 6257     ALBA-GOLDEN ISD  2018       NaN      0            2.0        0.0
# 6264       WINNSBORO ISD  2018    2018.0      1            0.0        0.0
# 6271     DENVER CITY ISD  2018    2017.0      1            1.0        1.0
# 6278          PLAINS ISD  2018       NaN      0            2.0        0.0
# 6285          GRAHAM ISD  2018    2017.0      1            1.0        1.0
# 6292       NEWCASTLE ISD  2018    2017.0      1            1.0        1.0
# 6299           OLNEY ISD  2018    2018.0      1            0.0        0.0
# 6306   ZAPATA COUNTY ISD  2018    2017.0      1            1.0        1.0
# 6313        LA PRYOR ISD  2018       NaN      0            2.0        0.0
#
#       yearpost  treatpostyear  treatpostyear2
# 6          1.0            1.0               0
# 13         0.0            0.0               0
# 20         0.0            0.0               0
# 27         1.0            1.0               0
# 34         2.0            2.0               1
# 41         1.0            1.0               0
# 48         2.0            2.0               1
# 55         2.0            0.0               0
# 62         1.0            1.0               0
# 69         1.0            1.0               0
# 76         1.0            1.0               0
# 83         2.0            0.0               0
# 90         2.0            0.0               0
# 97         1.0            1.0               0
# 104        0.0            0.0               0
# 111        1.0            1.0               0
# 118        1.0            1.0               0
# 125        2.0            0.0               0
# 132        1.0            1.0               0
# 139        2.0            0.0               0
# 146        2.0            0.0               0
# 153        2.0            0.0               0
# 160        1.0            1.0               0
# 167        2.0            0.0               0
# 174        2.0            0.0               0
# 181        1.0            1.0               0
# 188        1.0            1.0               0
# 195        0.0            0.0               0
# 202        2.0            0.0               0
# 209        1.0            1.0               0
# ...        ...            ...             ...
# 6110       1.0            1.0               0
# 6117       2.0            2.0               1
# 6124       1.0            1.0               0
# 6131       1.0            1.0               0
# 6138       0.0            0.0               0
# 6145       1.0            1.0               0
# 6152       1.0            1.0               0
# 6159       1.0            1.0               0
# 6166       1.0            1.0               0
# 6173       2.0            0.0               0
# 6180       1.0            1.0               0
# 6187       1.0            1.0               0
# 6194       1.0            1.0               0
# 6201       1.0            1.0               0
# 6208       1.0            1.0               0
# 6215       1.0            1.0               0
# 6222       2.0            2.0               1
# 6229       2.0            0.0               0
# 6236       2.0            2.0               1
# 6243       0.0            0.0               0
# 6250       2.0            0.0               0
# 6257       2.0            0.0               0
# 6264       0.0            0.0               0
# 6271       1.0            1.0               0
# 6278       2.0            0.0               0
# 6285       1.0            1.0               0
# 6292       1.0            1.0               0
# 6299       0.0            0.0               0
# 6306       1.0            1.0               0
# 6313       2.0            0.0               0
#
# [902 rows x 9 columns]

# %% [markdown]
# # No Matching

# %%
y, X = dmatrices('avescores ~  treat + doi_year_centered + treatyear + yearpost + treatpostyear + treatpostyear2',
                 data=data, return_type='dataframe', NA_action = "drop")
cluster = data[pd.notnull(data.avescores)].distname
mod = smf.OLS(y, X)    # Describe model
res = mod.fit(cov_type = 'cluster',  cov_kwds={'groups': pd.DataFrame(cluster)})       # Fit model
print(res.summary())   # Summarize model
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     190.8
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):          1.57e-127
# Time:                        14:53:39   Log-Likelihood:                -5398.1
# No. Observations:                5280   AIC:                         1.081e+04
# Df Residuals:                    5274   BIC:                         1.085e+04
# Df Model:                           5
# Covariance Type:              cluster
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.1524      0.050      3.041      0.002       0.054       0.251
# treat                 0.2165      0.101      2.149      0.032       0.019       0.414
# doi_year_centered     0.1038      0.007     15.154      0.000       0.090       0.117
# treatyear            -0.0170      0.011     -1.551      0.121      -0.038       0.004
# yearpost             -0.0185      0.013     -1.379      0.168      -0.045       0.008
# treatpostyear         0.0202      0.013      1.597      0.110      -0.005       0.045
# treatpostyear2        0.0202      0.013      1.597      0.110      -0.005       0.045
# ==============================================================================
# Omnibus:                      445.667   Durbin-Watson:                   0.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              600.341
# Skew:                           0.711   Prob(JB):                    4.34e-131
# Kurtosis:                       3.841   Cond. No.                     6.72e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
# [2] The smallest eigenvalue is 1.56e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/model.py:1532: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   'rank is %d' % (J, J_), ValueWarning)

# %% [markdown]
# # Matching

# %%
y, X = dmatrices('avescores ~  treat + doi_year_centered + treatyear + yearpost + treatpostyear + treatpostyear2',
                 data=data, return_type='dataframe', NA_action = "drop")
cluster = data[pd.notnull(data.avescores)].distname
psweights = data[pd.notnull(data.avescores)].psweight
mod = smf.WLS(y, X, weights = psweights)    # Describe model
res = mod.fit(cov_type = 'cluster',  cov_kwds={'groups': pd.DataFrame(cluster)})       # Fit model
print(res.summary())   # Summarize model
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.062
# Model:                            WLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     83.77
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           4.17e-82
# Time:                        08:10:28   Log-Likelihood:                -7256.3
# No. Observations:                6302   AIC:                         1.453e+04
# Df Residuals:                    6295   BIC:                         1.457e+04
# Df Model:                           6
# Covariance Type:              cluster
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.2941      0.056      5.259      0.000       0.184       0.404
# treat                 0.0727      0.094      0.772      0.440      -0.112       0.257
# doi_year_centered     0.1018      0.009     11.422      0.000       0.084       0.119
# treatyear            -0.0148      0.012     -1.205      0.228      -0.039       0.009
# yearpost             -0.0295      0.015     -1.906      0.057      -0.060       0.001
# treatpostyear         0.1111      0.043      2.594      0.009       0.027       0.195
# treatpostyear2       -0.1041      0.022     -4.674      0.000      -0.148      -0.060
# ==============================================================================
# Omnibus:                     1727.714   Durbin-Watson:                   0.347
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12634.898
# Skew:                           1.114   Prob(JB):                         0.00
# Kurtosis:                       9.569   Cond. No.                         24.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)

# %% [markdown]
# # Weights and pretest

# %%
y, X = dmatrices('avescores ~  treat + doi_year_centered + treatyear + yearpost + treatpostyear + treatpostyear2 + scores15',
                 data=data, return_type='dataframe', NA_action = "drop")
cluster = data[pd.notnull(data.avescores)].distname
psweights = data[pd.notnull(data.avescores)].psweight
mod = smf.WLS(y, X, weights = psweights)    # Describe model
res = mod.fit(cov_type = 'cluster',  cov_kwds={'groups': pd.DataFrame(cluster)})       # Fit model
print(res.summary())   # Summarize model
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.840
# Model:                            WLS   Adj. R-squared:                  0.840
# Method:                 Least Squares   F-statistic:                     784.5
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):               0.00
# Time:                        08:14:34   Log-Likelihood:                -1687.8
# No. Observations:                6302   AIC:                             3392.
# Df Residuals:                    6294   BIC:                             3446.
# Df Model:                           7
# Covariance Type:              cluster
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.1248      0.014      8.876      0.000       0.097       0.152
# treat                 0.0962      0.025      3.808      0.000       0.047       0.146
# doi_year_centered     0.1010      0.009     11.400      0.000       0.084       0.118
# treatyear            -0.0141      0.011     -1.260      0.208      -0.036       0.008
# yearpost             -0.0301      0.016     -1.941      0.052      -0.060       0.000
# treatpostyear         0.0855      0.029      2.929      0.003       0.028       0.143
# treatpostyear2       -0.0908      0.018     -5.156      0.000      -0.125      -0.056
# scores15              0.9302      0.016     58.772      0.000       0.899       0.961
# ==============================================================================
# Omnibus:                     1829.595   Durbin-Watson:                   1.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           258475.369
# Skew:                           0.024   Prob(JB):                         0.00
# Kurtosis:                      34.374   Cond. No.                         24.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust tocluster correlation (cluster)
