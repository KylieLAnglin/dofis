# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm
import numpy as np
from patsy import dmatrices
from openpyxl import load_workbook
import engarde.decorators as ed


from library import regulations
from library import characteristics
from library import analysis
from library import tables
from library import test

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/impact/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'cits.csv'),
                  sep=",", low_memory= False)
@ed.verify(test.alleligible)
def load():
    return data
data = load()
data.head()
data = data[data.year == 2016]
data['doi_16'] = np.where(data.doi_year == 2016, 1, 0)
data['doi_17'] = np.where(data.doi_year == 2017, 1, 0)
data['doi_18'] = np.where(data.doi_year == 2018, 1, 0)
data['tpsd'] = np.where(data.doi == False, 1, 0)
data.head()
# Out:
#       Unnamed: 0  district       distname  year  cntyname distischarter  \
# 3712        4909      1902     CAYUGA ISD  2016  ANDERSON             N
# 3713        4910      1903    ELKHART ISD  2016  ANDERSON             N
# 3714        4911      1904  FRANKSTON ISD  2016  ANDERSON             N
# 3715        4912      1906     NECHES ISD  2016  ANDERSON             N
# 3716        4913      1907  PALESTINE ISD  2016  ANDERSON             N
#
#      rating_academic rating_financial eligible type  ...  treatyear  \
# 3712               M             Pass     True    H  ...       -1.0
# 3713               M             Pass     True    G  ...       -2.0
# 3714               M             Pass     True    H  ...       -2.0
# 3715               M             Pass     True    H  ...       -1.0
# 3716               M             Pass     True    E  ...        0.0
#
#       treatpost  treatpostyear  yearpost1  treatpostyear1  treatpostyear2  \
# 3712        0.0           -0.0          0               0               0
# 3713        0.0           -0.0          0               0               0
# 3714        0.0           -0.0          0               0               0
# 3715        0.0           -0.0          0               0               0
# 3716        1.0            0.0          0               0               0
#
#       doi_16  doi_17  doi_18  tpsd
# 3712       0       1       0     0
# 3713       0       0       1     0
# 3714       0       0       1     0
# 3715       0       1       0     0
# 3716       1       0       0     0
#
# [5 rows x 131 columns]

# %%
y, X = dmatrices('students_num ~ 0 + tpsd + doi_16 + doi_17 + doi_18', data=data, return_type='dataframe', NA_action = "drop")
X.head()
# Out:
#       tpsd  doi_16  doi_17  doi_18
# 3365   0.0     0.0     1.0     0.0
# 3366   0.0     0.0     0.0     1.0
# 3367   0.0     0.0     0.0     1.0
# 3368   0.0     0.0     1.0     0.0
# 3369   0.0     1.0     0.0     0.0

# %%
rules = [(data.tpsd == 1), (data.doi_16 == 1), (data.doi_17 == 1), (data.doi_18 == 1) ]
coef_1 = []
coef_2 = []
coef_3 = []
coef_4 = []
cols  = [coef_1, coef_2, coef_3, coef_4]
char = 'students_num'
for rule, col in zip(rules, cols):
    col.append(float((data[rule][[char]].mean().round(2))))
coef_1
# Out:
# [6295.91]

# %%
def stars(pvalue):
    if pvalue >.05:
        stars = ''
    if pvalue <= .05:
        stars = '*'
    if pvalue <= .01:
        stars = '**'
    if pvalue <= .001:
        stars = '***'
    return(stars)
test = stars(.05)
test
# Out:
# '*'

# %%
def make_stat_df(data, y_list, y_labels):
    characteristics = []
    coef_1 = []
    coef_2 = []
    coef_3 = []
    coef_4 = []
    p_ftest = []
    for var in y_list:
        formula = var + ' ~ ' + '0 + tpsd + doi_16 + doi_17 + doi_18'
        y, X = dmatrices(formula, data=data, return_type='dataframe', NA_action = "drop") 
        mod = sm.OLS(y, X)    # Describe model
        res = mod.fit()       # Fit model
        print(res.fvalue)
        print(y_labels[var])
        print(res.summary())   # Summarize model
        p_ftest.append(stars(res.f_pvalue))
        p_ftest.append('')
        rules = [(data.tpsd == 1), (data.doi_16 == 1), (data.doi_17 == 1), (data.doi_18 == 1) ]
        cols  = [coef_1, coef_2, coef_3, coef_4]
        for rule, col in zip(rules, cols):
            col.append(float((data[rule][[var]].mean().round(2))))
            col.append('[' + str(float((data[rule][[var]].std().round(2)))) + ']')
        characteristics.append(y_labels[var])
        characteristics.append('')


    df = pd.DataFrame(
        {'Characteristic': characteristics,
         'TPSD': coef_1,
         'DOI_2016': coef_2,
         'DOI_2017': coef_3,
         'DOI_2018': coef_4,
         'P_ftest': p_ftest
         })
    return df
geo = make_stat_df(data = data, 
                   y_list = characteristics.geography,
                   y_labels = characteristics.labels)
geo
# Out:
# 14.940378240545344
# Urban
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     14.94
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           8.42e-12
# Time:                        08:35:21   Log-Likelihood:                 49.106
# No. Observations:                 842   AIC:                            -90.21
# Df Residuals:                     838   BIC:                            -71.27
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.0660      0.016      4.048      0.000       0.034       0.098
# doi_16         0.1346      0.032      4.243      0.000       0.072       0.197
# doi_17         0.0401      0.010      3.913      0.000       0.020       0.060
# doi_18         0.0753      0.024      3.172      0.002       0.029       0.122
# ==============================================================================
# Omnibus:                      667.375   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7713.438
# Skew:                           3.807   Prob(JB):                         0.00
# Kurtosis:                      15.723   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 71.57773299952396
# Suburban
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.255
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     71.58
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           3.55e-52
# Time:                        08:35:21   Log-Likelihood:                -494.32
# No. Observations:                 842   AIC:                             996.6
# Df Residuals:                     838   BIC:                             1016.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.2792      0.031      8.982      0.000       0.218       0.340
# doi_16         0.3269      0.061      5.404      0.000       0.208       0.446
# doi_17         0.2385      0.020     12.210      0.000       0.200       0.277
# doi_18         0.2366      0.045      5.229      0.000       0.148       0.325
# ==============================================================================
# Omnibus:                      165.990   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              195.554
# Skew:                           1.126   Prob(JB):                     3.43e-43
# Kurtosis:                       2.289   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 80.18849773523849
# Town
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     80.19
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           1.24e-57
# Time:                        08:35:22   Log-Likelihood:                -511.98
# No. Observations:                 842   AIC:                             1032.
# Df Residuals:                     838   BIC:                             1051.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.2335      0.032      7.356      0.000       0.171       0.296
# doi_16         0.2115      0.062      3.424      0.001       0.090       0.333
# doi_17         0.2886      0.020     14.469      0.000       0.249       0.328
# doi_18         0.3118      0.046      6.750      0.000       0.221       0.403
# ==============================================================================
# Omnibus:                      246.675   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.145
# Skew:                           1.009   Prob(JB):                     9.28e-39
# Kurtosis:                       2.043   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 151.3139260223725
# Rural
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     151.3
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           2.10e-97
# Time:                        08:35:22   Log-Likelihood:                -597.50
# No. Observations:                 842   AIC:                             1203.
# Df Residuals:                     838   BIC:                             1222.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.4213      0.035     11.991      0.000       0.352       0.490
# doi_16         0.3269      0.068      4.780      0.000       0.193       0.461
# doi_17         0.4329      0.022     19.607      0.000       0.390       0.476
# doi_18         0.3763      0.051      7.359      0.000       0.276       0.477
# ==============================================================================
# Omnibus:                       15.026   Durbin-Watson:                   1.623
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):              138.791
# Skew:                           0.333   Prob(JB):                     7.28e-31
# Kurtosis:                       1.126   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   Characteristic    TPSD DOI_2016 DOI_2017 DOI_2018 P_ftest
# 0          Urban    0.07     0.13     0.04     0.08     ***
# 1                 [0.25]   [0.34]    [0.2]   [0.27]
# 2       Suburban    0.28     0.33     0.24     0.24     ***
# 3                 [0.45]   [0.47]   [0.43]   [0.43]
# 4           Town    0.23     0.21     0.29     0.31     ***
# 5                 [0.42]   [0.41]   [0.45]   [0.47]
# 6          Rural    0.42     0.33     0.43     0.38     ***
# 7                  [0.5]   [0.47]    [0.5]   [0.49]

# %%
teacher = make_stat_df(data = data, 
                   y_list = characteristics.teacher,
                   y_labels = characteristics.labels)
teacher
# Out:
# 3159.049146441374
# Ave. Experience Teaching
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.938
# Model:                             OLS   Adj. R-squared:                  0.938
# Method:                  Least Squares   F-statistic:                     3159.
# Date:                 Sun, 17 Mar 2019   Prob (F-statistic):               0.00
# Time:                         08:35:22   Log-Likelihood:                -1723.9
# No. Observations:                  842   AIC:                             3456.
# Df Residuals:                      838   BIC:                             3475.
# Df Model:                            4
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           7.3635      0.134     54.998      0.000       7.101       7.626
# doi_16         7.2942      0.261     27.991      0.000       6.783       7.806
# doi_17         7.2597      0.084     86.299      0.000       7.095       7.425
# doi_18         7.2398      0.195     37.154      0.000       6.857       7.622
# ==============================================================================
# Omnibus:                       47.848   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.572
# Skew:                           0.406   Prob(JB):                     4.32e-19
# Kurtosis:                       4.323   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 952.7846399809383
# Teacher Turnover Ratio
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     teachers_turnover_ratio   R-squared:                       0.820
# Model:                                 OLS   Adj. R-squared:                  0.819
# Method:                      Least Squares   F-statistic:                     952.8
# Date:                     Sun, 17 Mar 2019   Prob (F-statistic):          5.59e-310
# Time:                             08:35:22   Log-Likelihood:                 876.89
# No. Observations:                      842   AIC:                            -1746.
# Df Residuals:                          838   BIC:                            -1727.
# Df Model:                                4
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.1876      0.006     30.755      0.000       0.176       0.200
# doi_16         0.1722      0.012     14.506      0.000       0.149       0.196
# doi_17         0.1807      0.004     47.164      0.000       0.173       0.188
# doi_18         0.1842      0.009     20.747      0.000       0.167       0.202
# ==============================================================================
# Omnibus:                      226.444   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              962.756
# Skew:                           1.190   Prob(JB):                    8.71e-210
# Kurtosis:                       7.666   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 6623.596133743035
# Student-Teacher Ratio
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.969
# Model:                                OLS   Adj. R-squared:                  0.969
# Method:                     Least Squares   F-statistic:                     6624.
# Date:                    Sun, 17 Mar 2019   Prob (F-statistic):               0.00
# Time:                            08:35:22   Log-Likelihood:                -1338.6
# No. Observations:                     842   AIC:                             2685.
# Df Residuals:                         838   BIC:                             2704.
# Df Model:                               4
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           6.4915      0.085     76.616      0.000       6.325       6.658
# doi_16         6.9525      0.165     42.159      0.000       6.629       7.276
# doi_17         6.6850      0.053    125.573      0.000       6.580       6.789
# doi_18         6.8419      0.123     55.483      0.000       6.600       7.084
# ==============================================================================
# Omnibus:                       48.403   Durbin-Watson:                   1.394
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.504
# Skew:                           0.305   Prob(JB):                     5.03e-26
# Kurtosis:                       4.717   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#              Characteristic    TPSD DOI_2016 DOI_2017 DOI_2018 P_ftest
# 0  Ave. Experience Teaching    7.36     7.29     7.26     7.24     ***
# 1                            [2.08]   [1.59]   [1.81]   [1.78]
# 2    Teacher Turnover Ratio    0.19     0.17     0.18     0.18     ***
# 3                             [0.1]   [0.06]   [0.08]   [0.08]
# 4     Student-Teacher Ratio    6.49     6.95     6.68     6.84     ***
# 5                            [1.21]   [1.14]   [1.17]   [1.04]

# %%
student = make_stat_df(data = data, 
                   y_list = characteristics.student,
                   y_labels = characteristics.labels)
student
# Out:
# 487.36191534011135
# Percent Hispanic
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.699
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     487.4
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):          5.83e-217
# Time:                        08:35:22   Log-Likelihood:                -56.200
# No. Observations:                 842   AIC:                             120.4
# Df Residuals:                     838   BIC:                             139.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.5033      0.018     27.246      0.000       0.467       0.540
# doi_16         0.4451      0.036     12.377      0.000       0.374       0.516
# doi_17         0.3411      0.012     29.386      0.000       0.318       0.364
# doi_18         0.3710      0.027     13.798      0.000       0.318       0.424
# ==============================================================================
# Omnibus:                       62.936   Durbin-Watson:                   1.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.790
# Skew:                           0.550   Prob(JB):                     1.27e-12
# Kurtosis:                       2.408   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 836.9302648717675
# Percent White
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     836.9
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):          6.98e-291
# Time:                        08:35:22   Log-Likelihood:                -53.948
# No. Observations:                 842   AIC:                             115.9
# Df Residuals:                     838   BIC:                             134.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.4225      0.018     22.934      0.000       0.386       0.459
# doi_16         0.4362      0.036     12.163      0.000       0.366       0.507
# doi_17         0.5540      0.012     47.852      0.000       0.531       0.577
# doi_18         0.5254      0.027     19.595      0.000       0.473       0.578
# ==============================================================================
# Omnibus:                      133.705   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.813
# Skew:                          -0.229   Prob(JB):                     6.15e-09
# Kurtosis:                       2.068   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 102.79697222621797
# Percent Black
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     102.8
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           3.13e-71
# Time:                        08:35:23   Log-Likelihood:                 855.55
# No. Observations:                 842   AIC:                            -1703.
# Df Residuals:                     838   BIC:                            -1684.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.0470      0.006      7.514      0.000       0.035       0.059
# doi_16         0.0656      0.012      5.388      0.000       0.042       0.090
# doi_17         0.0650      0.004     16.534      0.000       0.057       0.073
# doi_18         0.0659      0.009      7.234      0.000       0.048       0.084
# ==============================================================================
# Omnibus:                      519.643   Durbin-Watson:                   1.439
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5108.363
# Skew:                           2.713   Prob(JB):                         0.00
# Kurtosis:                      13.778   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1962.059072158288
# Percent Econ. Disadvantaged
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     1962.
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):               0.00
# Time:                        08:35:23   Log-Likelihood:                 233.40
# No. Observations:                 842   AIC:                            -458.8
# Df Residuals:                     838   BIC:                            -439.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.6131      0.013     46.813      0.000       0.587       0.639
# doi_16         0.5617      0.025     22.033      0.000       0.512       0.612
# doi_17         0.5418      0.008     65.842      0.000       0.526       0.558
# doi_18         0.5512      0.019     28.916      0.000       0.514       0.589
# ==============================================================================
# Omnibus:                       19.913   Durbin-Watson:                   1.626
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.727
# Skew:                          -0.380   Prob(JB):                     3.16e-05
# Kurtosis:                       3.112   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 64.66672341880579
# Average STAAR Performance (Std.)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     64.67
# Date:                Sun, 17 Mar 2019   Prob (F-statistic):           1.13e-47
# Time:                        08:35:23   Log-Likelihood:                -876.17
# No. Observations:                 841   AIC:                             1760.
# Df Residuals:                     837   BIC:                             1779.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# tpsd           0.2054      0.049      4.184      0.000       0.109       0.302
# doi_16         0.4640      0.095      4.867      0.000       0.277       0.651
# doi_17         0.4237      0.031     13.768      0.000       0.363       0.484
# doi_18         0.3767      0.071      5.284      0.000       0.237       0.517
# ==============================================================================
# Omnibus:                       58.878   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.421
# Skew:                           0.608   Prob(JB):                     4.19e-17
# Kurtosis:                       3.822   Cond. No.                         3.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                      Characteristic    TPSD DOI_2016 DOI_2017 DOI_2018 P_ftest
# 0                  Percent Hispanic     0.5     0.45     0.34     0.37     ***
# 1                                    [0.32]   [0.25]   [0.23]   [0.25]
# 2                     Percent White    0.42     0.44     0.55     0.53     ***
# 3                                     [0.3]   [0.24]   [0.24]   [0.26]
# 4                     Percent Black    0.05     0.07     0.06     0.07     ***
# 5                                    [0.08]   [0.08]   [0.09]   [0.08]
# 6       Percent Econ. Disadvantaged    0.61     0.56     0.54     0.55     ***
# 7                                     [0.2]   [0.21]   [0.17]   [0.17]
# 8  Average STAAR Performance (Std.)    0.21     0.46     0.42     0.38     ***
# 9                                    [0.69]   [0.89]   [0.67]   [0.63]

# %% [markdown]
# # To Table

# %%
rows = [6, 15, 22]
dfs = [geo, teacher, student]
file = table_path + 'characteristic_by_adoption_year.xlsx'
wb = load_workbook(file)
ws = wb.active
str_n = 'N = ' + str(len(data[data.tpsd == 1]))
ws.cell(row=4, column=2).value = str_n
str_n = 'N = ' + str(len(data[data.doi_16 == 1]))
ws.cell(row=4, column=3).value = str_n
str_n = 'N = ' + str(len(data[data.doi_17 == 1]))
ws.cell(row=4, column=4).value = str_n
str_n = 'N = ' + str(len(data[data.doi_18 == 1]))
ws.cell(row=4, column=5).value = str_n

for df, row in zip(dfs, rows):
    row_n = row
    for ob in df.TPSD:
        ws.cell(row=row_n, column=2).value = ob
        row_n = row_n + 1
    row_n = row
    for ob in df.DOI_2016:
        ws.cell(row=row_n, column=3).value = ob
        row_n = row_n + 1   
    row_n = row
    for ob in df.DOI_2017:
        ws.cell(row=row_n, column=4).value = ob
        row_n = row_n + 1 
    row_n = row
    for ob in df.DOI_2018:
        ws.cell(row=row_n, column=5).value = ob
        row_n = row_n + 1 
    row_n = row
    for ob in df.P_ftest:
        ws.cell(row=row_n, column=6).value = ob
        row_n = row_n + 1 
wb.save(file)
