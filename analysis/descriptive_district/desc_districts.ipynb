# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import re
import numpy as np
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'))
data = data[data.year == 2018]
data
# Out:
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (7,8,280,331) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Unnamed: 0  district                      distname  year    cntyname  \
# 7311        7311      1902                    CAYUGA ISD  2018    ANDERSON
# 7312        7312      1903                   ELKHART ISD  2018    ANDERSON
# 7313        7313      1904                 FRANKSTON ISD  2018    ANDERSON
# 7314        7314      1906                    NECHES ISD  2018    ANDERSON
# 7315        7315      1907                 PALESTINE ISD  2018    ANDERSON
# 7316        7316      1908                  WESTWOOD ISD  2018    ANDERSON
# 7317        7317      1909                    SLOCUM ISD  2018    ANDERSON
# 7318        7318      2901                   ANDREWS ISD  2018     ANDREWS
# 7319        7319      3801  PINEYWOODS COMMUNITY ACADEMY  2018    ANGELINA
# 7320        7320      3902                    HUDSON ISD  2018    ANGELINA
# 7321        7321      3903                    LUFKIN ISD  2018    ANGELINA
# 7322        7322      3904                HUNTINGTON ISD  2018    ANGELINA
# 7323        7323      3905                    DIBOLL ISD  2018    ANGELINA
# 7324        7324      3906                   ZAVALLA ISD  2018    ANGELINA
# 7325        7325      3907                   CENTRAL ISD  2018    ANGELINA
# 7326        7326      4901            ARANSAS COUNTY ISD  2018     ARANSAS
# 7327        7327      5901               ARCHER CITY ISD  2018      ARCHER
# 7328        7328      5902                  HOLLIDAY ISD  2018      ARCHER
# 7329        7329      5904                WINDTHORST ISD  2018      ARCHER
# 7330        7330      6902                    CLAUDE ISD  2018   ARMSTRONG
# 7331        7331      7901                 CHARLOTTE ISD  2018    ATASCOSA
# 7332        7332      7902                JOURDANTON ISD  2018    ATASCOSA
# 7333        7333      7904                     LYTLE ISD  2018    ATASCOSA
# 7334        7334      7905                PLEASANTON ISD  2018    ATASCOSA
# 7335        7335      7906                    POTEET ISD  2018    ATASCOSA
# 7336        7336      8901                 BELLVILLE ISD  2018      AUSTIN
# 7337        7337      8902                     SEALY ISD  2018      AUSTIN
# 7338        7338      8903                    BRAZOS ISD  2018      AUSTIN
# 7339        7339      9901                  MULESHOE ISD  2018      BAILEY
# 7340        7340     10901                    MEDINA ISD  2018     BANDERA
# ...          ...       ...                           ...   ...         ...
# 8483        8483    246914                  COUPLAND ISD  2018  WILLIAMSON
# 8484        8484    247901               FLORESVILLE ISD  2018      WILSON
# 8485        8485    247903                 LA VERNIA ISD  2018      WILSON
# 8486        8486    247904                      POTH ISD  2018      WILSON
# 8487        8487    247906                 STOCKDALE ISD  2018      WILSON
# 8488        8488    248901                    KERMIT ISD  2018     WINKLER
# 8489        8489    248902               WINK-LOVING ISD  2018     WINKLER
# 8490        8490    249901                    ALVORD ISD  2018        WISE
# 8491        8491    249902                      BOYD ISD  2018        WISE
# 8492        8492    249903                BRIDGEPORT ISD  2018        WISE
# 8493        8493    249904                     CHICO ISD  2018        WISE
# 8494        8494    249905                   DECATUR ISD  2018        WISE
# 8495        8495    249906                  PARADISE ISD  2018        WISE
# 8496        8496    249908                   SLIDELL ISD  2018        WISE
# 8497        8497    250902                   HAWKINS ISD  2018        WOOD
# 8498        8498    250903                   MINEOLA ISD  2018        WOOD
# 8499        8499    250904                   QUITMAN ISD  2018        WOOD
# 8500        8500    250905                    YANTIS ISD  2018        WOOD
# 8501        8501    250906               ALBA-GOLDEN ISD  2018        WOOD
# 8502        8502    250907                 WINNSBORO ISD  2018        WOOD
# 8503        8503    251901               DENVER CITY ISD  2018      YOAKUM
# 8504        8504    251902                    PLAINS ISD  2018      YOAKUM
# 8505        8505    252901                    GRAHAM ISD  2018       YOUNG
# 8506        8506    252902                 NEWCASTLE ISD  2018       YOUNG
# 8507        8507    252903                     OLNEY ISD  2018       YOUNG
# 8508        8508    253901             ZAPATA COUNTY ISD  2018      ZAPATA
# 8509        8509    254901              CRYSTAL CITY ISD  2018      ZAVALA
# 8510        8510    254902                  LA PRYOR ISD  2018      ZAVALA
# 8524        8524     15950                           NaN  2018         NaN
# 8525        8525    181950                           NaN  2018         NaN
#
#      distischarter              rating_academic rating_financial eligible  \
# 7311             N                            B             Pass    False
# 7312             N                            B             Pass    False
# 7313             N                            B             Pass    False
# 7314             N                            B             Pass    False
# 7315             N                            B             Pass    False
# 7316             N                            C             Pass    False
# 7317             N                            B             Pass    False
# 7318             N                            C             Pass    False
# 7319             Y                            A             Pass    False
# 7320             N                            A             Pass     True
# 7321             N                            B             Pass    False
# 7322             N                            B             Pass    False
# 7323             N                            B             Pass    False
# 7324             N                            D             Pass    False
# 7325             N                            B             Pass    False
# 7326             N  Not Rated: Harvey Provision             Pass    False
# 7327             N                            A             Pass     True
# 7328             N                            B             Pass    False
# 7329             N                            A             Pass     True
# 7330             N                            A             Pass     True
# 7331             N                            C             Pass    False
# 7332             N                            B             Pass    False
# 7333             N                            C             Pass    False
# 7334             N                            C             Pass    False
# 7335             N                            C             Pass    False
# 7336             N                            B             Pass    False
# 7337             N                            C             Pass    False
# 7338             N                            C             Pass    False
# 7339             N                            C             Pass    False
# 7340             N                 Met Standard             Pass    False
# ...            ...                          ...              ...      ...
# 8483             N                 Met Standard             Pass    False
# 8484             N                            B             Pass    False
# 8485             N                            B             Pass    False
# 8486             N                            A             Pass     True
# 8487             N                            B             Pass    False
# 8488             N                            D             Pass    False
# 8489             N                            F             Pass    False
# 8490             N                            A             Pass     True
# 8491             N                            C             Pass    False
# 8492             N                            C             Pass    False
# 8493             N                            C             Pass    False
# 8494             N                            B             Pass    False
# 8495             N                            B             Pass    False
# 8496             N                 Met Standard             Pass    False
# 8497             N                            B             Pass    False
# 8498             N                            B             Pass    False
# 8499             N                            B             Pass    False
# 8500             N                            D             Pass    False
# 8501             N                            B             Pass    False
# 8502             N                            B             Pass    False
# 8503             N                            B             Pass    False
# 8504             N                            C             Pass    False
# 8505             N                            C             Pass    False
# 8506             N                 Met Standard             Pass    False
# 8507             N                            A             Pass     True
# 8508             N                            B             Pass    False
# 8509             N                            C             Pass    False
# 8510             N                            C             Pass    False
# 8524           NaN                          NaN              NaN      NaN
# 8525           NaN                          NaN              NaN      NaN
#
#      type  ... type_urban  type_suburban  type_town  type_rural   index  \
# 7311    H  ...          0              0          0           1   186.0
# 7312    G  ...          0              0          1           0   355.0
# 7313    H  ...          0              0          0           1   400.0
# 7314    H  ...          0              0          0           1   805.0
# 7315    E  ...          0              0          1           0   859.0
# 7316    G  ...          0              0          1           0  1249.0
# 7317    H  ...          0              0          0           1  1064.0
# 7318    D  ...          0              1          0           0    38.0
# 7319    I  ...          0              0          1           0   890.0
# 7320    G  ...          0              0          1           0   542.0
# 7321    E  ...          0              0          1           0   705.0
# 7322    G  ...          0              0          1           0   548.0
# 7323    G  ...          0              0          1           0   309.0
# 7324    H  ...          0              0          0           1  1288.0
# 7325    G  ...          0              0          1           0   196.0
# 7326    E  ...          0              0          1           0    46.0
# 7327    H  ...          0              0          0           1    48.0
# 7328    D  ...          0              1          0           0   527.0
# 7329    H  ...          0              0          0           1  1267.0
# 7330    H  ...          0              0          0           1   221.0
# 7331    H  ...          0              0          0           1   203.0
# 7332    G  ...          0              0          1           0   587.0
# 7333    G  ...          0              0          1           0   710.0
# 7334    E  ...          0              0          1           0   897.0
# 7335    G  ...          0              0          1           0   908.0
# 7336    E  ...          0              0          1           0    89.0
# 7337    D  ...          0              1          0           0  1039.0
# 7338    H  ...          0              0          0           1   127.0
# 7339    G  ...          0              0          1           0   795.0
# 7340    H  ...          0              0          0           1   748.0
# ...   ...  ...        ...            ...        ...         ...     ...
# 8483    H  ...          0              0          0           1   259.0
# 8484    E  ...          0              0          1           0   383.0
# 8485    E  ...          0              0          1           0   641.0
# 8486    H  ...          0              0          0           1   909.0
# 8487    H  ...          0              0          0           1  1105.0
# 8488    D  ...          0              1          0           0   608.0
# 8489    H  ...          0              0          0           1  1270.0
# 8490    H  ...          0              0          0           1    30.0
# 8491    G  ...          0              0          1           0   123.0
# 8492    G  ...          0              0          1           0   135.0
# 8493    H  ...          0              0          0           1   206.0
# 8494    E  ...          0              0          1           0   295.0
# 8495    G  ...          0              0          1           0   866.0
# 8496    H  ...          0              0          0           1  1063.0
# 8497    H  ...          0              0          0           1   502.0
# 8498    E  ...          0              0          1           0   775.0
# 8499    G  ...          0              0          1           0   930.0
# 8500    H  ...          0              0          0           1  1282.0
# 8501    G  ...          0              0          1           0    17.0
# 8502    E  ...          0              0          1           0  1271.0
# 8503    G  ...          0              0          1           0   302.0
# 8504    H  ...          0              0          0           1   893.0
# 8505    G  ...          0              0          1           0   449.0
# 8506    H  ...          0              0          0           1   818.0
# 8507    H  ...          0              0          0           1   847.0
# 8508    D  ...          0              1          0           0  1287.0
# 8509    G  ...          0              0          1           0   274.0
# 8510    H  ...          0              0          0           1   639.0
# 8524  NaN  ...          0              0          0           0     NaN
# 8525  NaN  ...          0              0          0           0     NaN
#
#       always_eligible  teachers_nodegree  teachers_badegree  \
# 7311            False           0.000000           0.929719
# 7312            False           0.000000           0.823356
# 7313            False           0.001692           0.812183
# 7314            False           0.000000           0.994100
# 7315            False           0.093493           0.824233
# 7316            False           0.095547           0.805668
# 7317            False           0.000000           0.804878
# 7318            False           0.000000           0.758277
# 7319            False           0.031104           0.653188
# 7320             True           0.010262           0.774756
# 7321            False           0.026423           0.766938
# 7322            False           0.000000           0.867386
# 7323            False           0.014937           0.864824
# 7324            False           0.003012           0.849398
# 7325            False           0.000000           0.864177
# 7326            False           0.009182           0.756887
# 7327             True           0.000000           0.934783
# 7328            False           0.000000           0.820442
# 7329             True           0.000000           0.887955
# 7330             True           0.028818           0.717579
# 7331            False           0.034483           0.735632
# 7332            False           0.000000           0.729639
# 7333            False           0.000000           0.759227
# 7334            False           0.000000           0.839490
# 7335            False           0.008780           0.808604
# 7336            False           0.006549           0.863130
# 7337            False           0.009935           0.829111
# 7338            False           0.000000           0.819376
# 7339            False           0.000000           0.798482
# 7340            False           0.000000           0.906149
# ...               ...                ...                ...
# 8483            False           0.071429           0.785714
# 8484            False           0.016293           0.810998
# 8485            False           0.000000           0.736398
# 8486             True           0.015456           0.843895
# 8487            False           0.000000           0.898512
# 8488            False           0.000000           0.860412
# 8489            False           0.000000           0.827068
# 8490             True           0.000000           0.753022
# 8491            False           0.000000           0.827740
# 8492            False           0.006824           0.795285
# 8493            False           0.000000           0.872247
# 8494            False           0.007637           0.745585
# 8495            False           0.000000           0.817582
# 8496            False           0.000000           0.692661
# 8497            False           0.000000           0.828526
# 8498            False           0.000000           0.728972
# 8499            False           0.011038           0.800221
# 8500            False           0.000000           0.689655
# 8501            False           0.000000           0.802910
# 8502            False           0.000000           0.863014
# 8503            False           0.000000           0.795803
# 8504            False           0.000000           0.949749
# 8505            False           0.000000           0.845836
# 8506            False           0.000000           0.783784
# 8507             True           0.000000           0.784000
# 8508            False           0.009183           0.881543
# 8509            False           0.013846           0.862308
# 8510            False           0.000000           0.873563
# 8524              NaN                NaN                NaN
# 8525              NaN                NaN                NaN
#
#       teachers_msdegree  teachers_phddegree
# 7311           0.070281            0.000000
# 7312           0.176644            0.000000
# 7313           0.186125            0.000000
# 7314           0.002950            0.000000
# 7315           0.082274            0.000000
# 7316           0.098785            0.000000
# 7317           0.195122            0.000000
# 7318           0.241324            0.000000
# 7319           0.300156            0.015552
# 7320           0.210364            0.005131
# 7321           0.206640            0.000000
# 7322           0.132614            0.000000
# 7323           0.120239            0.000000
# 7324           0.144578            0.000000
# 7325           0.135823            0.000000
# 7326           0.224749            0.008745
# 7327           0.065217            0.000000
# 7328           0.179558            0.000000
# 7329           0.112045            0.000000
# 7330           0.256484            0.000000
# 7331           0.229885            0.000000
# 7332           0.270361            0.000000
# 7333           0.231986            0.008787
# 7334           0.160510            0.000000
# 7335           0.182616            0.000000
# 7336           0.127701            0.002620
# 7337           0.160954            0.000000
# 7338           0.180624            0.000000
# 7339           0.197302            0.004216
# 7340           0.064725            0.029126
# ...                 ...                 ...
# 8483           0.142857            0.000000
# 8484           0.164562            0.008147
# 8485           0.258912            0.004690
# 8486           0.142195            0.000000
# 8487           0.100135            0.000000
# 8488           0.139588            0.000000
# 8489           0.172932            0.000000
# 8490           0.246978            0.000000
# 8491           0.172260            0.000000
# 8492           0.197891            0.000000
# 8493           0.129956            0.000000
# 8494           0.247255            0.000000
# 8495           0.182418            0.000000
# 8496           0.307339            0.000000
# 8497           0.173077            0.000000
# 8498           0.271807            0.000000
# 8499           0.188742            0.000000
# 8500           0.310345            0.000000
# 8501           0.197090            0.000000
# 8502           0.136986            0.000000
# 8503           0.205004            0.000000
# 8504           0.050251            0.000000
# 8505           0.154164            0.000000
# 8506           0.216216            0.000000
# 8507           0.212000            0.004000
# 8508           0.109275            0.000000
# 8509           0.115385            0.007692
# 8510           0.126437            0.000000
# 8524                NaN                 NaN
# 8525                NaN                 NaN
#
# [1202 rows x 336 columns]

# %% [markdown]
# # School Characteristics

# %%
data.schools_num.sum(axis = 0)
# Out:
# 8759.0

# %%
print('There are', data.schools_num.sum(axis = 0), 'schools in Texas.')
print('Of these,', data[data.distischarter == 'Y'].schools_num.sum(axis = 0), 'are charters.')
print('Of traditional public schools only', 
      data[data.distischarter == 'N'][data.eligible == 0].schools_num.sum(axis = 0), 
      'are ineligible for DOI status.')
print(len(data[data.doi == True].sum(axis = 0)), 'districts are districts of innovation.')
# Out:
# There are 8759.0 schools in Texas.
# Of these, 705.0 are charters.
# Of traditional public schools only 6848.0 are ineligible for DOI status.
# 335 districts are districts of innovation.
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
len(data[(data.doi_year.notnull())])
# Out:
# 784

# %%
data[(data.doi_year.isnull()) & (data.doi == True)]
# Out:
#       Unnamed: 0  district                    distname  year      cntyname  \
# 7318        7318      2901                 ANDREWS ISD  2018       ANDREWS
# 7329        7329      5904              WINDTHORST ISD  2018        ARCHER
# 7362        7362     14909                  TEMPLE ISD  2018          BELL
# 7388        7388     15905        EDGEWOOD ISD (15905)  2018         BEXAR
# 7394        7394     15911            EAST CENTRAL ISD  2018         BEXAR
# 7399        7399     15916                  JUDSON ISD  2018         BEXAR
# 7519        7519     43914           WYLIE ISD (43914)  2018        COLLIN
# 7538        7538     49903     VALLEY VIEW ISD (49903)  2018         COOKE
# 7601        7601     57914                MESQUITE ISD  2018        DALLAS
# 7607        7607     58906                  LAMESA ISD  2018        DAWSON
# 7646        7646     67908             RISING STAR ISD  2018      EASTLAND
# 7705        7705     76903                    ROBY ISD  2018        FISHER
# 7718        7718     81906                     DEW ISD  2018     FREESTONE
# 7834        7834    101910             GALENA PARK ISD  2018        HARRIS
# 7856        7856    104903                    RULE ISD  2018       HASKELL
# 7857        7857    104907             PAINT CREEK ISD  2018       HASKELL
# 7889        7889    108912                 LA JOYA ISD  2018       HIDALGO
# 7895        7895    109902                   BYNUM ISD  2018          HILL
# 7898        7898    109905        HUBBARD ISD (109905)  2018          HILL
# 7909        7909    110906                   SMYER ISD  2018       HOCKLEY
# 7923        7923    113902               GRAPELAND ISD  2018       HOUSTON
# 7996        7996    129902                  FORNEY ISD  2018       KAUFMAN
# 8010        8010    133904                  INGRAM ISD  2018          KERR
# 8059        8059    148901                  BOOKER ISD  2018      LIPSCOMB
# 8061        8061    148903                 HIGGINS ISD  2018      LIPSCOMB
# 8083        8083    156902                 STANTON ISD  2018        MARTIN
# 8099        8099    161903         MIDWAY ISD (161903)  2018      MCLENNAN
# 8111        8111    161921                CONNALLY ISD  2018      MCLENNAN
# 8127        8127    166902                   GAUSE ISD  2018         MILAM
# 8154        8154    172902  DAINGERFIELD-LONE STAR ISD  2018        MORRIS
# 8179        8179    177903               BLACKWELL ISD  2018         NOLAN
# 8251        8251    194904             CLARKSVILLE ISD  2018     RED RIVER
# 8270        8270    201902               HENDERSON ISD  2018          RUSK
# 8285        8285    205902        GREGORY-PORTLAND ISD  2018  SAN PATRICIO
# 8328        8328    219903                   TULIA ISD  2018       SWISHER
# 8375        8375    226906                    WALL ISD  2018     TOM GREEN
# 8402        8402    228904    CENTERVILLE ISD (228904)  2018       TRINITY
# 8426        8426    234903       EDGEWOOD ISD (234903)  2018     VAN ZANDT
# 8429        8429    234906                     VAN ISD  2018     VAN ZANDT
# 8489        8489    248902             WINK-LOVING ISD  2018       WINKLER
#
#      distischarter              rating_academic rating_financial eligible  \
# 7318             N                            C             Pass    False
# 7329             N                            A             Pass     True
# 7362             N                            C             Pass    False
# 7388             N                            D             Pass    False
# 7394             N                            C             Pass    False
# 7399             N                            C             Pass    False
# 7519             N                            A             Pass     True
# 7538             N                            C             Pass    False
# 7601             N                            C             Pass    False
# 7607             N                            C             Pass    False
# 7646             N                            A             Pass     True
# 7705             N                            A             Pass     True
# 7718             N                 Met Standard             Pass    False
# 7834             N  Not Rated: Harvey Provision             Pass    False
# 7856             N                 Met Standard             Pass    False
# 7857             N                 Met Standard             Pass    False
# 7889             N                            B             Pass    False
# 7895             N                 Met Standard             Pass    False
# 7898             N                            C             Pass    False
# 7909             N                            C             Pass    False
# 7923             N                            D             Pass    False
# 7996             N                            B             Pass    False
# 8010             N                            C             Pass    False
# 8059             N                            A             Pass     True
# 8061             N                 Met Standard             Pass    False
# 8083             N                            C             Pass    False
# 8099             N                            A             Pass     True
# 8111             N                            C             Pass    False
# 8127             N                 Met Standard             Pass    False
# 8154             N                            D             Pass    False
# 8179             N                 Met Standard             Pass    False
# 8251             N                            C             Pass    False
# 8270             N                            B             Pass    False
# 8285             N  Not Rated: Harvey Provision             Pass    False
# 8328             N                            D             Pass    False
# 8375             N                            A             Pass     True
# 8402             N                 Met Standard             Pass    False
# 8426             N                            B             Pass    False
# 8429             N                            B             Pass    False
# 8489             N                            F             Pass    False
#
#      type  ... type_urban  type_suburban  type_town  type_rural   index  \
# 7318    D  ...          0              1          0           0    38.0
# 7329    H  ...          0              0          0           1  1267.0
# 7362    D  ...          0              1          0           0  1125.0
# 7388    B  ...          0              1          0           0   342.0
# 7394    B  ...          0              1          0           0   332.0
# 7399    B  ...          0              1          0           0   591.0
# 7519    D  ...          0              1          0           0  1281.0
# 7538    H  ...          0              0          0           1  1201.0
# 7601    B  ...          0              1          0           0   757.0
# 7607    G  ...          0              0          1           0   649.0
# 7646    H  ...          0              0          0           1   967.0
# 7705    H  ...          0              0          0           1   974.0
# 7718    H  ...          0              0          0           1   307.0
# 7834    B  ...          0              1          0           0   412.0
# 7856    H  ...          0              0          0           1   992.0
# 7857    H  ...          0              0          0           1   856.0
# 7889    C  ...          1              0          0           0   636.0
# 7895    H  ...          0              0          0           1   164.0
# 7898    H  ...          0              0          0           1   539.0
# 7909    H  ...          0              0          0           1  1066.0
# 7923    H  ...          0              0          0           1   458.0
# 7996    B  ...          0              1          0           0   389.0
# 8010    G  ...          0              0          1           0   559.0
# 8059    H  ...          0              0          0           1   117.0
# 8061    H  ...          0              0          0           1   517.0
# 8083    D  ...          0              1          0           0  1097.0
# 8099    D  ...          0              1          0           0   767.0
# 8111    D  ...          0              1          0           0   247.0
# 8127    H  ...          0              0          0           1   423.0
# 8154    G  ...          0              0          1           0   282.0
# 8179    H  ...          0              0          0           1   102.0
# 8251    H  ...          0              0          0           1   220.0
# 8270    E  ...          0              0          1           0   509.0
# 8285    D  ...          0              1          0           0   463.0
# 8328    G  ...          0              0          1           0  1175.0
# 8375    D  ...          0              1          0           0  1221.0
# 8402    H  ...          0              0          0           1   194.0
# 8426    G  ...          0              0          1           0   343.0
# 8429    D  ...          0              1          0           0  1203.0
# 8489    H  ...          0              0          0           1  1270.0
#
#       always_eligible  teachers_nodegree  teachers_badegree  \
# 7318            False           0.000000           0.758277
# 7329             True           0.000000           0.887955
# 7362            False           0.024000           0.689362
# 7388            False           0.003512           0.709574
# 7394            False           0.000000           0.725773
# 7399            False           0.034318           0.641710
# 7519             True           0.004970           0.716529
# 7538            False           0.015929           0.828319
# 7601            False           0.005186           0.517439
# 7607            False           0.007283           0.932993
# 7646             True           0.000000           0.795181
# 7705             True           0.000000           0.966102
# 7718            False           0.000000           0.933333
# 7834            False           0.012985           0.716810
# 7856            False           0.000000           0.986842
# 7857            False           0.000000           0.923977
# 7889            False           0.015613           0.810908
# 7895            False           0.000000           0.604520
# 7898            False           0.003436           0.824742
# 7909            False           0.000000           0.834667
# 7923            False           0.002288           0.929062
# 7996            False           0.006425           0.738221
# 8010            False           0.000000           0.799489
# 8059             True           0.002591           0.930052
# 8061            False           0.000000           0.792683
# 8083            False           0.039216           0.824837
# 8099             True           0.004048           0.755313
# 8111            False           0.000000           0.816210
# 8127            False           0.000000           0.875776
# 8154            False           0.022676           0.789116
# 8179            False           0.000000           0.900943
# 8251            False           0.000000           0.624060
# 8270            False           0.012273           0.784173
# 8285            False           0.000000           0.750954
# 8328            False           0.020408           0.792857
# 8375             True           0.000000           0.773703
# 8402            False           0.000000           0.764706
# 8426            False           0.020779           0.810390
# 8429            False           0.000000           0.822178
# 8489            False           0.000000           0.827068
#
#       teachers_msdegree  teachers_phddegree
# 7318           0.241324            0.000000
# 7329           0.112045            0.000000
# 7362           0.278128            0.008511
# 7388           0.281112            0.005650
# 7394           0.269374            0.004854
# 7399           0.319564            0.004408
# 7519           0.273531            0.004970
# 7538           0.155752            0.000000
# 7601           0.469732            0.007682
# 7607           0.052440            0.007283
# 7646           0.204819            0.000000
# 7705           0.033898            0.000000
# 7718           0.066667            0.000000
# 7834           0.256723            0.013482
# 7856           0.013158            0.000000
# 7857           0.076023            0.000000
# 7889           0.171897            0.001582
# 7895           0.395480            0.000000
# 7898           0.171821            0.000000
# 7909           0.165333            0.000000
# 7923           0.068650            0.000000
# 7996           0.252059            0.003295
# 8010           0.187739            0.012771
# 8059           0.046632            0.020725
# 8061           0.207317            0.000000
# 8083           0.135948            0.000000
# 8099           0.234568            0.006072
# 8111           0.181507            0.002283
# 8127           0.062112            0.062112
# 8154           0.188209            0.000000
# 8179           0.099057            0.000000
# 8251           0.375940            0.000000
# 8270           0.199323            0.004232
# 8285           0.245865            0.003181
# 8328           0.186735            0.000000
# 8375           0.226297            0.000000
# 8402           0.235294            0.000000
# 8426           0.168831            0.000000
# 8429           0.177822            0.000000
# 8489           0.172932            0.000000
#
# [40 rows x 336 columns]

# %%
len(data[(data.doi_year.notnull())])

# %% [markdown]
# # District Characteristics

# %%
print('There are', len(data), 'districts in Texas.')
print('Of these,', len(data[data.distischarter == 'Y']), 'are charters.')
print('Of traditional public schools only', len(data[data.distischarter == 'N'][data.eligible == 0]), 'are ineligible for DOI status.')
print(len(data[data.doi == True]), 'districts are districts of innovation.')
# Out:
# There are 1202 districts in Texas.
# Of these, 177 are charters.
# Of traditional public schools only 902 are ineligible for DOI status.
# 824 districts are districts of innovation.
# /Users/kylieleblancKylie/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %%
data['type_description'].value_counts()
# Out:
# RURAL                            461
# CHARTER SCHOOL DISTRICTS         180
# NON-METROPOLITAN STABLE          174
# OTHER CENTRAL CITY SUBURBAN      164
# MAJOR SUBURBAN                    79
# INDEPENDENT TOWN                  68
# OTHER CENTRAL CITY                38
# NON-METROPOLITAN FAST GROWING     28
# MAJOR URBAN                       11
# Name: type_description, dtype: int64

# %%
data.groupby(['geography'])['students_num'].mean()
# Out:
# geography
# Rural         428.488323
# Suburban     9411.817844
# Town         2070.489286
# Urban       11095.628415
# Name: students_num, dtype: float64

# %%
data.groupby(['doi', 'distischarter', 'eligible'])['district'].count()
# Out:
# doi    distischarter  eligible
# False  N              False        24
#                       True        214
#        Y              False       180
# True   N              False         9
#                       True        776
# Name: district, dtype: int64

# %%
countXgeo = pd.DataFrame(data.groupby(['geography'])['district'].count())
countXgeo['proportion'] = countXgeo['district']/countXgeo['district'].sum()
countXgeo
# Out:
#            district  proportion
# geography
# Rural           471    0.391521
# Suburban        269    0.223608
# Town            280    0.232751
# Urban           183    0.152120

# %%
countXtype = pd.DataFrame(data.groupby(['type_description'])['district'].count())
countXtype['proportion'] = countXtype['district']/countXtype['district'].sum()
countXtype
# Out:
#                                district  proportion
# type_description
# CHARTER SCHOOL DISTRICTS            180    0.149626
# INDEPENDENT TOWN                     68    0.056525
# MAJOR SUBURBAN                       79    0.065669
# MAJOR URBAN                          11    0.009144
# NON-METROPOLITAN FAST GROWING        28    0.023275
# NON-METROPOLITAN STABLE             174    0.144638
# OTHER CENTRAL CITY                   38    0.031588
# OTHER CENTRAL CITY SUBURBAN         164    0.136326
# RURAL                               461    0.383209

# %%
data[data.distname == "LEANDER ISD"].type_description
# Out:
# 8422    MAJOR SUBURBAN
# Name: type_description, dtype: object
