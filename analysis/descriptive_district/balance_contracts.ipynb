# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm

from library import regulations
from library import characteristics
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data_district.csv'),
                  sep=",")
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Just keep doi districts from 2014-15

# %%
data = data[data.year == 2016]
data = data[data.doi == True]

# %% [markdown]
# ## 21.102

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_102')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_102')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_102')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_contracts.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 2, start_row = row)
# Out:
# type_urban ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     18.22
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           2.20e-05
# Time:                        11:47:01   Log-Likelihood:                 115.44
# No. Observations:                 822   AIC:                            -226.9
# Df Residuals:                     820   BIC:                            -217.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0794      0.010      7.572      0.000       0.059       0.100
# reg21_102     -0.0627      0.015     -4.269      0.000      -0.092      -0.034
# ==============================================================================
# Omnibus:                      702.219   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10426.756
# Skew:                           4.114   Prob(JB):                         0.00
# Kurtosis:                      18.387   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     10.63
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):            0.00116
# Time:                        11:47:01   Log-Likelihood:                -465.57
# No. Observations:                 822   AIC:                             935.1
# Df Residuals:                     820   BIC:                             944.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2928      0.021     13.771      0.000       0.251       0.335
# reg21_102     -0.0971      0.030     -3.260      0.001      -0.156      -0.039
# ==============================================================================
# Omnibus:                      145.807   Durbin-Watson:                   1.294
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              199.046
# Skew:                           1.173   Prob(JB):                     6.00e-44
# Kurtosis:                       2.446   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.461
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0197
# Time:                        11:47:01   Log-Likelihood:                -496.23
# No. Observations:                 822   AIC:                             996.5
# Df Residuals:                     820   BIC:                             1006.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2333      0.022     10.568      0.000       0.190       0.277
# reg21_102      0.0722      0.031      2.337      0.020       0.012       0.133
# ==============================================================================
# Omnibus:                      217.145   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.701
# Skew:                           1.025   Prob(JB):                     3.15e-38
# Kurtosis:                       2.085   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     6.429
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0114
# Time:                        11:47:01   Log-Likelihood:                -587.26
# No. Observations:                 822   AIC:                             1179.
# Df Residuals:                     820   BIC:                             1188.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3945      0.025     16.002      0.000       0.346       0.443
# reg21_102      0.0876      0.035      2.535      0.011       0.020       0.155
# ==============================================================================
# Omnibus:                        7.956   Durbin-Watson:                   1.644
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):              132.923
# Skew:                           0.242   Prob(JB):                     1.37e-29
# Kurtosis:                       1.090   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg21_102
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.000
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                    0.1188
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):              0.730
# Time:                         11:47:01   Log-Likelihood:                -1673.3
# No. Observations:                  821   AIC:                             3351.
# Df Residuals:                      819   BIC:                             3360.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.2027      0.093     77.659      0.000       7.021       7.385
# reg21_102     -0.0447      0.130     -0.345      0.730      -0.300       0.210
# ==============================================================================
# Omnibus:                       19.695   Durbin-Watson:                   1.761
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.838
# Skew:                           0.116   Prob(JB):                     1.00e-08
# Kurtosis:                       4.012   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg21_102
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.005
# Model:                                   OLS   Adj. R-squared:                  0.004
# Method:                        Least Squares   F-statistic:                     3.931
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):             0.0477
# Time:                               11:47:01   Log-Likelihood:                -2921.1
# No. Observations:                        821   AIC:                             5846.
# Df Residuals:                            819   BIC:                             5856.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.0127      0.424     42.483      0.000      17.180      18.845
# reg21_102      1.1768      0.594      1.983      0.048       0.012       2.342
# ==============================================================================
# Omnibus:                      157.901   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.581
# Skew:                           1.005   Prob(JB):                     2.08e-86
# Kurtosis:                       5.738   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg21_102
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.009
# Model:                                OLS   Adj. R-squared:                  0.008
# Method:                     Least Squares   F-statistic:                     7.222
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):            0.00735
# Time:                            11:47:01   Log-Likelihood:                -1879.6
# No. Observations:                     821   AIC:                             3763.
# Df Residuals:                         819   BIC:                             3773.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.9620      0.119    108.700      0.000      12.728      13.196
# reg21_102     -0.4486      0.167     -2.687      0.007      -0.776      -0.121
# ==============================================================================
# Omnibus:                        6.478   Durbin-Watson:                   1.289
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                6.528
# Skew:                          -0.218   Prob(JB):                       0.0382
# Kurtosis:                       2.976   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     16.99
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           4.15e-05
# Time:                        11:47:01   Log-Likelihood:                -8.5677
# No. Observations:                 822   AIC:                             21.14
# Df Residuals:                     820   BIC:                             30.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3950      0.012     32.391      0.000       0.371       0.419
# reg21_102     -0.0704      0.017     -4.122      0.000      -0.104      -0.037
# ==============================================================================
# Omnibus:                       67.786   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.861
# Skew:                           0.761   Prob(JB):                     1.68e-18
# Kurtosis:                       2.726   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     20.19
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           8.03e-06
# Time:                        11:47:02   Log-Likelihood:                -23.437
# No. Observations:                 822   AIC:                             50.87
# Df Residuals:                     820   BIC:                             60.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4940      0.012     39.784      0.000       0.470       0.518
# reg21_102      0.0781      0.017      4.493      0.000       0.044       0.112
# ==============================================================================
# Omnibus:                      121.002   Durbin-Watson:                   1.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.561
# Skew:                          -0.363   Prob(JB):                     1.28e-10
# Kurtosis:                       2.104   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5668
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.452
# Time:                        11:47:02   Log-Likelihood:                 698.65
# No. Observations:                 822   AIC:                            -1393.
# Df Residuals:                     820   BIC:                            -1384.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0709      0.005     13.750      0.000       0.061       0.081
# reg21_102     -0.0054      0.007     -0.753      0.452      -0.020       0.009
# ==============================================================================
# Omnibus:                      572.103   Durbin-Watson:                   1.512
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7124.252
# Skew:                           3.092   Prob(JB):                         0.00
# Kurtosis:                      16.029   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1398
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.709
# Time:                        11:47:02   Log-Likelihood:                 222.21
# No. Observations:                 822   AIC:                            -440.4
# Df Residuals:                     820   BIC:                            -431.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5568      0.009     60.463      0.000       0.539       0.575
# reg21_102     -0.0048      0.013     -0.374      0.709      -0.030       0.020
# ==============================================================================
# Omnibus:                       11.653   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.987
# Skew:                          -0.289   Prob(JB):                      0.00249
# Kurtosis:                       2.874   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg21_102
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8859
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.347
# Time:                        11:47:02   Log-Likelihood:                -894.81
# No. Observations:                 822   AIC:                             1794.
# Df Residuals:                     820   BIC:                             1803.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3460      0.036      9.654      0.000       0.276       0.416
# reg21_102     -0.0473      0.050     -0.941      0.347      -0.146       0.051
# ==============================================================================
# Omnibus:                       45.177   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.758
# Skew:                           0.554   Prob(JB):                     3.50e-12
# Kurtosis:                       3.559   Cond. No.                         2.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 21.401

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_401')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_401')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_401')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_contracts.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 3, start_row = row)
# Out:
# type_urban ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     19.60
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           1.08e-05
# Time:                        11:47:02   Log-Likelihood:                 116.12
# No. Observations:                 822   AIC:                            -228.2
# Df Residuals:                     820   BIC:                            -218.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0714      0.009      7.832      0.000       0.054       0.089
# reg21_401     -0.0680      0.015     -4.428      0.000      -0.098      -0.038
# ==============================================================================
# Omnibus:                      699.826   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10281.305
# Skew:                           4.098   Prob(JB):                         0.00
# Kurtosis:                      18.265   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     67.75
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           7.27e-16
# Time:                        11:47:02   Log-Likelihood:                -438.24
# No. Observations:                 822   AIC:                             880.5
# Df Residuals:                     820   BIC:                             889.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3308      0.018     18.481      0.000       0.296       0.366
# reg21_401     -0.2481      0.030     -8.231      0.000      -0.307      -0.189
# ==============================================================================
# Omnibus:                      129.171   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.939
# Skew:                           1.010   Prob(JB):                     6.16e-34
# Kurtosis:                       2.379   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     6.378
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0117
# Time:                        11:47:02   Log-Likelihood:                -495.77
# No. Observations:                 822   AIC:                             995.5
# Df Residuals:                     820   BIC:                             1005.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2989      0.019     15.567      0.000       0.261       0.337
# reg21_401     -0.0816      0.032     -2.525      0.012      -0.145      -0.018
# ==============================================================================
# Omnibus:                      217.060   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.018
# Skew:                           1.023   Prob(JB):                     4.43e-38
# Kurtosis:                       2.084   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     140.9
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           4.26e-30
# Time:                        11:47:02   Log-Likelihood:                -525.31
# No. Observations:                 822   AIC:                             1055.
# Df Residuals:                     820   BIC:                             1064.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2989      0.020     15.018      0.000       0.260       0.338
# reg21_401      0.3977      0.034     11.869      0.000       0.332       0.463
# ==============================================================================
# Omnibus:                      846.785   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.269
# Skew:                           0.262   Prob(JB):                     3.01e-14
# Kurtosis:                       1.758   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg21_401
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.004
# Model:                             OLS   Adj. R-squared:                  0.003
# Method:                  Least Squares   F-statistic:                     3.271
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):             0.0709
# Time:                         11:47:02   Log-Likelihood:                -1671.7
# No. Observations:                  821   AIC:                             3347.
# Df Residuals:                      819   BIC:                             3357.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.2665      0.081     90.217      0.000       7.108       7.425
# reg21_401     -0.2451      0.136     -1.809      0.071      -0.511       0.021
# ==============================================================================
# Omnibus:                       21.165   Durbin-Watson:                   1.755
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.102
# Skew:                           0.145   Prob(JB):                     3.23e-09
# Kurtosis:                       4.029   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg21_401
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.012
# Model:                                   OLS   Adj. R-squared:                  0.011
# Method:                        Least Squares   F-statistic:                     9.902
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):            0.00171
# Time:                               11:47:02   Log-Likelihood:                -2918.1
# No. Observations:                        821   AIC:                             5840.
# Df Residuals:                            819   BIC:                             5850.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.9258      0.368     48.766      0.000      17.204      18.647
# reg21_401      1.9463      0.618      3.147      0.002       0.732       3.160
# ==============================================================================
# Omnibus:                      142.726   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              350.166
# Skew:                           0.920   Prob(JB):                     9.17e-77
# Kurtosis:                       5.617   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg21_401
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.122
# Model:                                OLS   Adj. R-squared:                  0.121
# Method:                     Least Squares   F-statistic:                     114.3
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):           4.55e-25
# Time:                            11:47:02   Log-Likelihood:                -1829.5
# No. Observations:                     821   AIC:                             3663.
# Df Residuals:                         819   BIC:                             3673.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.3534      0.098    136.790      0.000      13.162      13.545
# reg21_401     -1.7563      0.164    -10.692      0.000      -2.079      -1.434
# ==============================================================================
# Omnibus:                       20.737   Durbin-Watson:                   1.364
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.308
# Skew:                          -0.331   Prob(JB):                     8.68e-06
# Kurtosis:                       3.494   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.734
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0986
# Time:                        11:47:02   Log-Likelihood:                -15.627
# No. Observations:                 822   AIC:                             35.25
# Df Residuals:                     820   BIC:                             44.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3696      0.011     34.528      0.000       0.349       0.391
# reg21_401     -0.0298      0.018     -1.654      0.099      -0.065       0.006
# ==============================================================================
# Omnibus:                       70.811   Durbin-Watson:                   1.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.020
# Skew:                           0.788   Prob(JB):                     1.27e-19
# Kurtosis:                       2.755   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     14.23
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           0.000173
# Time:                        11:47:02   Log-Likelihood:                -26.361
# No. Observations:                 822   AIC:                             56.72
# Df Residuals:                     820   BIC:                             66.15
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5095      0.011     46.980      0.000       0.488       0.531
# reg21_401      0.0689      0.018      3.772      0.000       0.033       0.105
# ==============================================================================
# Omnibus:                      130.663   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.888
# Skew:                          -0.376   Prob(JB):                     3.99e-11
# Kurtosis:                       2.088   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     13.29
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           0.000283
# Time:                        11:47:02   Log-Likelihood:                 704.98
# No. Observations:                 822   AIC:                            -1406.
# Df Residuals:                     820   BIC:                            -1397.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0778      0.004     17.463      0.000       0.069       0.087
# reg21_401     -0.0273      0.008     -3.646      0.000      -0.042      -0.013
# ==============================================================================
# Omnibus:                      568.955   Durbin-Watson:                   1.525
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7015.579
# Skew:                           3.072   Prob(JB):                         0.00
# Kurtosis:                      15.926   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.6439
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.423
# Time:                        11:47:02   Log-Likelihood:                 222.46
# No. Observations:                 822   AIC:                            -440.9
# Df Residuals:                     820   BIC:                            -431.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5506      0.008     68.708      0.000       0.535       0.566
# reg21_401      0.0108      0.013      0.802      0.423      -0.016       0.037
# ==============================================================================
# Omnibus:                       10.814   Durbin-Watson:                   1.703
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.092
# Skew:                          -0.277   Prob(JB):                      0.00390
# Kurtosis:                       2.867   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg21_401
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.934
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.165
# Time:                        11:47:02   Log-Likelihood:                -894.29
# No. Observations:                 822   AIC:                             1793.
# Df Residuals:                     820   BIC:                             1802.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3477      0.031     11.152      0.000       0.286       0.409
# reg21_401     -0.0730      0.052     -1.391      0.165      -0.176       0.030
# ==============================================================================
# Omnibus:                       45.775   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.652
# Skew:                           0.557   Prob(JB):                     2.24e-12
# Kurtosis:                       3.570   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 21.352

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_352')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_352')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_352')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_contracts.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 4, start_row = row)
# Out:
# type_urban ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.002566
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.960
# Time:                        11:47:02   Log-Likelihood:                 106.41
# No. Observations:                 822   AIC:                            -208.8
# Df Residuals:                     820   BIC:                            -199.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0473      0.008      5.686      0.000       0.031       0.064
# reg21_352      0.0009      0.018      0.051      0.960      -0.035       0.037
# ==============================================================================
# Omnibus:                      721.444   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11390.675
# Skew:                           4.258   Prob(JB):                         0.00
# Kurtosis:                      19.127   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5336
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.465
# Time:                        11:47:02   Log-Likelihood:                -470.60
# No. Observations:                 822   AIC:                             945.2
# Df Residuals:                     820   BIC:                             954.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2378      0.017     14.182      0.000       0.205       0.271
# reg21_352      0.0273      0.037      0.730      0.465      -0.046       0.100
# ==============================================================================
# Omnibus:                      150.673   Durbin-Watson:                   1.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.787
# Skew:                           1.195   Prob(JB):                     1.25e-45
# Kurtosis:                       2.432   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.001077
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.974
# Time:                        11:47:02   Log-Likelihood:                -498.95
# No. Observations:                 822   AIC:                             1002.
# Df Residuals:                     820   BIC:                             1011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2698      0.017     15.546      0.000       0.236       0.304
# reg21_352      0.0013      0.039      0.033      0.974      -0.075       0.077
# ==============================================================================
# Omnibus:                      225.537   Durbin-Watson:                   1.827
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.410
# Skew:                           1.036   Prob(JB):                     4.93e-39
# Kurtosis:                       2.073   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4659
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.495
# Time:                        11:47:02   Log-Likelihood:                -590.24
# No. Observations:                 822   AIC:                             1184.
# Df Residuals:                     820   BIC:                             1194.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4451      0.019     22.951      0.000       0.407       0.483
# reg21_352     -0.0295      0.043     -0.683      0.495      -0.114       0.055
# ==============================================================================
# Omnibus:                        8.130   Durbin-Watson:                   1.632
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):              136.818
# Skew:                           0.245   Prob(JB):                     1.95e-30
# Kurtosis:                       1.062   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg21_352
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.001
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                    0.4873
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):              0.485
# Time:                         11:47:02   Log-Likelihood:                -1673.1
# No. Observations:                  821   AIC:                             3350.
# Df Residuals:                      819   BIC:                             3360.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.1571      0.073     98.523      0.000       7.015       7.300
# reg21_352      0.1128      0.162      0.698      0.485      -0.204       0.430
# ==============================================================================
# Omnibus:                       19.226   Durbin-Watson:                   1.755
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.363
# Skew:                           0.118   Prob(JB):                     2.09e-08
# Kurtosis:                       3.989   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg21_352
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.000
# Model:                                   OLS   Adj. R-squared:                 -0.001
# Method:                        Least Squares   F-statistic:                  0.002301
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):              0.962
# Time:                               11:47:02   Log-Likelihood:                -2923.0
# No. Observations:                        821   AIC:                             5850.
# Df Residuals:                            819   BIC:                             5859.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.6205      0.333     55.924      0.000      17.967      19.274
# reg21_352     -0.0355      0.740     -0.048      0.962      -1.489       1.418
# ==============================================================================
# Omnibus:                      153.075   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              367.695
# Skew:                           0.990   Prob(JB):                     1.43e-80
# Kurtosis:                       5.612   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg21_352
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.003
# Model:                                OLS   Adj. R-squared:                  0.002
# Method:                     Least Squares   F-statistic:                     2.729
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):             0.0989
# Time:                            11:47:02   Log-Likelihood:                -1881.8
# No. Observations:                     821   AIC:                             3768.
# Df Residuals:                         819   BIC:                             3777.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.6635      0.094    135.187      0.000      12.480      12.847
# reg21_352      0.3442      0.208      1.652      0.099      -0.065       0.753
# ==============================================================================
# Omnibus:                        5.576   Durbin-Watson:                   1.273
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.593
# Skew:                          -0.202   Prob(JB):                       0.0610
# Kurtosis:                       2.985   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3634
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.547
# Time:                        11:47:03   Log-Likelihood:                -16.813
# No. Observations:                 822   AIC:                             37.63
# Df Residuals:                     820   BIC:                             47.05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3617      0.010     37.468      0.000       0.343       0.381
# reg21_352     -0.0130      0.021     -0.603      0.547      -0.055       0.029
# ==============================================================================
# Omnibus:                       71.807   Durbin-Watson:                   1.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.817
# Skew:                           0.797   Prob(JB):                     5.17e-20
# Kurtosis:                       2.770   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.04002
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.841
# Time:                        11:47:03   Log-Likelihood:                -33.412
# No. Observations:                 822   AIC:                             70.82
# Df Residuals:                     820   BIC:                             80.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5329      0.010     54.099      0.000       0.514       0.552
# reg21_352      0.0044      0.022      0.200      0.841      -0.039       0.047
# ==============================================================================
# Omnibus:                      126.538   Durbin-Watson:                   1.404
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.899
# Skew:                          -0.402   Prob(JB):                     1.46e-11
# Kurtosis:                       2.100   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1805
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.671
# Time:                        11:47:03   Log-Likelihood:                 698.46
# No. Observations:                 822   AIC:                            -1393.
# Df Residuals:                     820   BIC:                            -1383.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0674      0.004     16.662      0.000       0.059       0.075
# reg21_352      0.0038      0.009      0.425      0.671      -0.014       0.021
# ==============================================================================
# Omnibus:                      570.863   Durbin-Watson:                   1.509
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7065.420
# Skew:                           3.085   Prob(JB):                         0.00
# Kurtosis:                      15.970   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.153
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.143
# Time:                        11:47:03   Log-Likelihood:                 223.22
# No. Observations:                 822   AIC:                            -442.4
# Df Residuals:                     820   BIC:                            -433.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5591      0.007     77.555      0.000       0.545       0.573
# reg21_352     -0.0235      0.016     -1.467      0.143      -0.055       0.008
# ==============================================================================
# Omnibus:                       10.137   Durbin-Watson:                   1.687
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.377
# Skew:                          -0.267   Prob(JB):                      0.00558
# Kurtosis:                       2.864   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg21_352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.722
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0301
# Time:                        11:47:03   Log-Likelihood:                -892.89
# No. Observations:                 822   AIC:                             1790.
# Df Residuals:                     820   BIC:                             1799.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2946      0.028     10.509      0.000       0.240       0.350
# reg21_352      0.1355      0.062      2.173      0.030       0.013       0.258
# ==============================================================================
# Omnibus:                       44.341   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.661
# Skew:                           0.548   Prob(JB):                     6.05e-12
# Kurtosis:                       3.555   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 21.354

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_354')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_354')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_354')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_contracts.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 4, start_row = row)
# Out:
# type_urban ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.683
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.195
# Time:                        11:47:03   Log-Likelihood:                 107.25
# No. Observations:                 822   AIC:                            -210.5
# Df Residuals:                     820   BIC:                            -201.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0451      0.008      5.909      0.000       0.030       0.060
# reg21_354      0.0419      0.032      1.297      0.195      -0.021       0.105
# ==============================================================================
# Omnibus:                      719.845   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11313.048
# Skew:                           4.245   Prob(JB):                         0.00
# Kurtosis:                      19.069   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.08142
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.775
# Time:                        11:47:03   Log-Likelihood:                -470.82
# No. Observations:                 822   AIC:                             945.6
# Df Residuals:                     820   BIC:                             955.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2423      0.015     15.710      0.000       0.212       0.273
# reg21_354      0.0186      0.065      0.285      0.775      -0.109       0.147
# ==============================================================================
# Omnibus:                      150.905   Durbin-Watson:                   1.268
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.128
# Skew:                           1.196   Prob(JB):                     1.05e-45
# Kurtosis:                       2.432   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.368
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.243
# Time:                        11:47:03   Log-Likelihood:                -498.27
# No. Observations:                 822   AIC:                             1001.
# Df Residuals:                     820   BIC:                             1010.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2745      0.016     17.215      0.000       0.243       0.306
# reg21_354     -0.0788      0.067     -1.170      0.243      -0.211       0.053
# ==============================================================================
# Omnibus:                      224.299   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.443
# Skew:                           1.033   Prob(JB):                     8.00e-39
# Kurtosis:                       2.074   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.05941
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.807
# Time:                        11:47:03   Log-Likelihood:                -590.44
# No. Observations:                 822   AIC:                             1185.
# Df Residuals:                     820   BIC:                             1194.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4381      0.018     24.564      0.000       0.403       0.473
# reg21_354      0.0184      0.075      0.244      0.807      -0.130       0.166
# ==============================================================================
# Omnibus:                        8.144   Durbin-Watson:                   1.630
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):              137.084
# Skew:                           0.245   Prob(JB):                     1.71e-30
# Kurtosis:                       1.060   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg21_354
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.001
# Model:                             OLS   Adj. R-squared:                 -0.000
# Method:                  Least Squares   F-statistic:                    0.5918
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):              0.442
# Time:                         11:47:03   Log-Likelihood:                -1673.0
# No. Observations:                  821   AIC:                             3350.
# Df Residuals:                      819   BIC:                             3359.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.1677      0.067    107.335      0.000       7.037       7.299
# reg21_354      0.2170      0.282      0.769      0.442      -0.337       0.771
# ==============================================================================
# Omnibus:                       19.476   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.062
# Skew:                           0.118   Prob(JB):                     1.48e-08
# Kurtosis:                       3.999   Cond. No.                         4.36
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg21_354
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.001
# Model:                                   OLS   Adj. R-squared:                 -0.000
# Method:                        Least Squares   F-statistic:                    0.6545
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):              0.419
# Time:                               11:47:03   Log-Likelihood:                -2922.7
# No. Observations:                        821   AIC:                             5849.
# Df Residuals:                            819   BIC:                             5859.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.6719      0.306     61.023      0.000      18.071      19.272
# reg21_354     -1.0458      1.293     -0.809      0.419      -3.583       1.492
# ==============================================================================
# Omnibus:                      155.435   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              377.621
# Skew:                           1.001   Prob(JB):                     1.00e-82
# Kurtosis:                       5.652   Cond. No.                         4.36
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg21_354
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.001
# Model:                                OLS   Adj. R-squared:                 -0.001
# Method:                     Least Squares   F-statistic:                    0.5217
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):              0.470
# Time:                            11:47:03   Log-Likelihood:                -1882.9
# No. Observations:                     821   AIC:                             3770.
# Df Residuals:                         819   BIC:                             3779.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.7478      0.086    147.830      0.000      12.579      12.917
# reg21_354     -0.2631      0.364     -0.722      0.470      -0.978       0.452
# ==============================================================================
# Omnibus:                        4.261   Durbin-Watson:                   1.272
# Prob(Omnibus):                  0.119   Jarque-Bera (JB):                4.321
# Skew:                          -0.174   Prob(JB):                        0.115
# Kurtosis:                       2.932   Cond. No.                         4.36
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3725
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.542
# Time:                        11:47:03   Log-Likelihood:                -16.808
# No. Observations:                 822   AIC:                             37.62
# Df Residuals:                     820   BIC:                             47.04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3578      0.009     40.312      0.000       0.340       0.375
# reg21_354      0.0229      0.038      0.610      0.542      -0.051       0.097
# ==============================================================================
# Omnibus:                       71.773   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.714
# Skew:                           0.796   Prob(JB):                     5.45e-20
# Kurtosis:                       2.767   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.006225
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.937
# Time:                        11:47:03   Log-Likelihood:                -33.429
# No. Observations:                 822   AIC:                             70.86
# Df Residuals:                     820   BIC:                             80.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5337      0.009     58.918      0.000       0.516       0.551
# reg21_354      0.0030      0.038      0.079      0.937      -0.072       0.078
# ==============================================================================
# Omnibus:                      127.063   Durbin-Watson:                   1.405
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.876
# Skew:                          -0.401   Prob(JB):                     1.48e-11
# Kurtosis:                       2.099   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.951
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.163
# Time:                        11:47:03   Log-Likelihood:                 699.34
# No. Observations:                 822   AIC:                            -1395.
# Df Residuals:                     820   BIC:                            -1385.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0694      0.004     18.680      0.000       0.062       0.077
# reg21_354     -0.0219      0.016     -1.397      0.163      -0.053       0.009
# ==============================================================================
# Omnibus:                      570.042   Durbin-Watson:                   1.503
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7048.478
# Skew:                           3.079   Prob(JB):                         0.00
# Kurtosis:                      15.956   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg21_354
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.493
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.115
# Time:                        11:47:03   Log-Likelihood:                 223.39
# No. Observations:                 822   AIC:                            -442.8
# Df Residuals:                     820   BIC:                            -433.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5569      0.007     84.025      0.000       0.544       0.570
# reg21_354     -0.0442      0.028     -1.579      0.115      -0.099       0.011
# ==============================================================================
# Omnibus:                       11.077   Durbin-Watson:                   1.682
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.384
# Skew:                          -0.282   Prob(JB):                      0.00337
# Kurtosis:                       2.883   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg21_354
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.299
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.130
# Time:                        11:47:03   Log-Likelihood:                -894.10
# No. Observations:                 822   AIC:                             1792.
# Df Residuals:                     820   BIC:                             1802.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3127      0.026     12.115      0.000       0.262       0.363
# reg21_354      0.1654      0.109      1.516      0.130      -0.049       0.380
# ==============================================================================
# Omnibus:                       47.782   Durbin-Watson:                   1.764
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.789
# Skew:                           0.566   Prob(JB):                     4.66e-13
# Kurtosis:                       3.613   Cond. No.                         4.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
