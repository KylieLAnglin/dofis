# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm

from library import regulations
from library import characteristics
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data_district.csv'),
                  sep=",")
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Just keep doi districts from 2014-15

# %%
data = data[data.year == 2016]
data = data[data.doi == True]

# %% [markdown]
# ## 21.003

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_003')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_003')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg21_003')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_hiring.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 2, start_row = row)
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)
# type_urban ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     5.632
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0179
# Time:                        11:47:54   Log-Likelihood:                 109.23
# No. Observations:                 822   AIC:                            -214.5
# Df Residuals:                     820   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0926      0.020      4.536      0.000       0.053       0.133
# reg21_003     -0.0520      0.022     -2.373      0.018      -0.095      -0.009
# ==============================================================================
# Omnibus:                      716.059   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11130.650
# Skew:                           4.216   Prob(JB):                         0.00
# Kurtosis:                      18.934   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     6.695
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):            0.00984
# Time:                        11:47:54   Log-Likelihood:                -467.52
# No. Observations:                 822   AIC:                             939.0
# Df Residuals:                     820   BIC:                             948.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3426      0.041      8.321      0.000       0.262       0.423
# reg21_003     -0.1143      0.044     -2.587      0.010      -0.201      -0.028
# ==============================================================================
# Omnibus:                      147.075   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              202.678
# Skew:                           1.185   Prob(JB):                     9.75e-45
# Kurtosis:                       2.451   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2536
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.615
# Time:                        11:47:54   Log-Likelihood:                -498.83
# No. Observations:                 822   AIC:                             1002.
# Df Residuals:                     820   BIC:                             1011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2500      0.043      5.845      0.000       0.166       0.334
# reg21_003      0.0231      0.046      0.504      0.615      -0.067       0.113
# ==============================================================================
# Omnibus:                      225.173   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.236
# Skew:                           1.035   Prob(JB):                     5.38e-39
# Kurtosis:                       2.073   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     7.863
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):            0.00517
# Time:                        11:47:54   Log-Likelihood:                -586.55
# No. Observations:                 822   AIC:                             1177.
# Df Residuals:                     820   BIC:                             1187.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3148      0.048      6.616      0.000       0.221       0.408
# reg21_003      0.1432      0.051      2.804      0.005       0.043       0.243
# ==============================================================================
# Omnibus:                        7.658   Durbin-Watson:                   1.634
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):              132.290
# Skew:                           0.237   Prob(JB):                     1.88e-29
# Kurtosis:                       1.093   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg21_003
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.002
# Model:                             OLS   Adj. R-squared:                  0.001
# Method:                  Least Squares   F-statistic:                     1.491
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):              0.222
# Time:                         11:47:55   Log-Likelihood:                -1672.6
# No. Observations:                  821   AIC:                             3349.
# Df Residuals:                      819   BIC:                             3359.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.3833      0.179     41.296      0.000       7.032       7.734
# reg21_003     -0.2342      0.192     -1.221      0.222      -0.611       0.142
# ==============================================================================
# Omnibus:                       19.583   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.681
# Skew:                           0.113   Prob(JB):                     1.08e-08
# Kurtosis:                       4.011   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg21_003
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.001
# Model:                                   OLS   Adj. R-squared:                 -0.000
# Method:                        Least Squares   F-statistic:                    0.9275
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):              0.336
# Time:                               11:47:55   Log-Likelihood:                -2922.6
# No. Observations:                        821   AIC:                             5849.
# Df Residuals:                            819   BIC:                             5859.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.8778      0.820     21.815      0.000      16.269      19.486
# reg21_003      0.8469      0.879      0.963      0.336      -0.879       2.573
# ==============================================================================
# Omnibus:                      152.984   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              365.558
# Skew:                           0.992   Prob(JB):                     4.17e-80
# Kurtosis:                       5.598   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg21_003
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.012
# Model:                                OLS   Adj. R-squared:                  0.011
# Method:                     Least Squares   F-statistic:                     9.893
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):            0.00172
# Time:                            11:47:55   Log-Likelihood:                -1878.3
# No. Observations:                     821   AIC:                             3761.
# Df Residuals:                         819   BIC:                             3770.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.4063      0.230     58.367      0.000      12.955      13.857
# reg21_003     -0.7752      0.246     -3.145      0.002      -1.259      -0.291
# ==============================================================================
# Omnibus:                        4.848   Durbin-Watson:                   1.276
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                4.741
# Skew:                          -0.184   Prob(JB):                       0.0934
# Kurtosis:                       3.060   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.134
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):             0.0770
# Time:                        11:47:55   Log-Likelihood:                -15.427
# No. Observations:                 822   AIC:                             34.85
# Df Residuals:                     820   BIC:                             44.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3983      0.024     16.768      0.000       0.352       0.445
# reg21_003     -0.0451      0.025     -1.770      0.077      -0.095       0.005
# ==============================================================================
# Omnibus:                       69.532   Durbin-Watson:                   1.260
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.035
# Skew:                           0.770   Prob(JB):                     5.65e-19
# Kurtosis:                       2.708   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.483
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.115
# Time:                        11:47:55   Log-Likelihood:                -32.189
# No. Observations:                 822   AIC:                             68.38
# Df Residuals:                     820   BIC:                             77.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4982      0.024     20.552      0.000       0.451       0.546
# reg21_003      0.0410      0.026      1.576      0.115      -0.010       0.092
# ==============================================================================
# Omnibus:                      138.194   Durbin-Watson:                   1.408
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.378
# Skew:                          -0.383   Prob(JB):                     1.90e-11
# Kurtosis:                       2.075   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.08020
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.777
# Time:                        11:47:55   Log-Likelihood:                 698.41
# No. Observations:                 822   AIC:                            -1393.
# Df Residuals:                     820   BIC:                            -1383.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0655      0.010      6.574      0.000       0.046       0.085
# reg21_003      0.0030      0.011      0.283      0.777      -0.018       0.024
# ==============================================================================
# Omnibus:                      572.064   Durbin-Watson:                   1.509
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7123.144
# Skew:                           3.092   Prob(JB):                         0.00
# Kurtosis:                      16.028   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1102
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.740
# Time:                        11:47:55   Log-Likelihood:                 222.19
# No. Observations:                 822   AIC:                            -440.4
# Df Residuals:                     820   BIC:                            -431.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5599      0.018     31.471      0.000       0.525       0.595
# reg21_003     -0.0063      0.019     -0.332      0.740      -0.044       0.031
# ==============================================================================
# Omnibus:                       11.364   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.674
# Skew:                          -0.284   Prob(JB):                      0.00292
# Kurtosis:                       2.868   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg21_003
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.6599
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.417
# Time:                        11:47:55   Log-Likelihood:                -894.92
# No. Observations:                 822   AIC:                             1794.
# Df Residuals:                     820   BIC:                             1803.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3744      0.069      5.406      0.000       0.238       0.510
# reg21_003     -0.0604      0.074     -0.812      0.417      -0.206       0.085
# ==============================================================================
# Omnibus:                       48.075   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.265
# Skew:                           0.567   Prob(JB):                     3.67e-13
# Kurtosis:                       3.620   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 25.112

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_112')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_112')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_112')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_hiring.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 3, start_row = row)
# Out:
# type_urban ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5383
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.463
# Time:                        11:47:55   Log-Likelihood:                 106.68
# No. Observations:                 822   AIC:                            -209.4
# Df Residuals:                     820   BIC:                            -199.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0523      0.010      5.265      0.000       0.033       0.072
# reg25_112     -0.0110      0.015     -0.734      0.463      -0.040       0.018
# ==============================================================================
# Omnibus:                      720.894   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11362.398
# Skew:                           4.253   Prob(JB):                         0.00
# Kurtosis:                      19.105   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2950
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.587
# Time:                        11:47:55   Log-Likelihood:                -470.72
# No. Observations:                 822   AIC:                             945.4
# Df Residuals:                     820   BIC:                             954.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2505      0.020     12.497      0.000       0.211       0.290
# reg25_112     -0.0164      0.030     -0.543      0.587      -0.076       0.043
# ==============================================================================
# Omnibus:                      150.803   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.961
# Skew:                           1.196   Prob(JB):                     1.15e-45
# Kurtosis:                       2.432   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2193
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.640
# Time:                        11:47:55   Log-Likelihood:                -498.85
# No. Observations:                 822   AIC:                             1002.
# Df Residuals:                     820   BIC:                             1011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2636      0.021     12.707      0.000       0.223       0.304
# reg25_112      0.0146      0.031      0.468      0.640      -0.047       0.076
# ==============================================================================
# Omnibus:                      225.184   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.262
# Skew:                           1.035   Prob(JB):                     5.31e-39
# Kurtosis:                       2.073   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1331
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.715
# Time:                        11:47:55   Log-Likelihood:                -590.41
# No. Observations:                 822   AIC:                             1185.
# Df Residuals:                     820   BIC:                             1194.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4336      0.023     18.695      0.000       0.388       0.479
# reg25_112      0.0127      0.035      0.365      0.715      -0.056       0.081
# ==============================================================================
# Omnibus:                        8.142   Durbin-Watson:                   1.629
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):              137.036
# Skew:                           0.245   Prob(JB):                     1.75e-30
# Kurtosis:                       1.061   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg25_112
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.000
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                   0.02550
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):              0.873
# Time:                         11:47:55   Log-Likelihood:                -1673.3
# No. Observations:                  821   AIC:                             3351.
# Df Residuals:                      819   BIC:                             3360.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.1891      0.087     82.820      0.000       7.019       7.359
# reg25_112     -0.0209      0.131     -0.160      0.873      -0.277       0.236
# ==============================================================================
# Omnibus:                       19.547   Durbin-Watson:                   1.760
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.442
# Skew:                           0.115   Prob(JB):                     1.22e-08
# Kurtosis:                       4.006   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg25_112
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.000
# Model:                                   OLS   Adj. R-squared:                 -0.001
# Method:                        Least Squares   F-statistic:                    0.3166
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):              0.574
# Time:                               11:47:55   Log-Likelihood:                -2922.9
# No. Observations:                        821   AIC:                             5850.
# Df Residuals:                            819   BIC:                             5859.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.4647      0.398     46.432      0.000      17.684      19.245
# reg25_112      0.3370      0.599      0.563      0.574      -0.839       1.512
# ==============================================================================
# Omnibus:                      152.504   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              363.421
# Skew:                           0.990   Prob(JB):                     1.21e-79
# Kurtosis:                       5.589   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg25_112
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.010
# Model:                                OLS   Adj. R-squared:                  0.009
# Method:                     Least Squares   F-statistic:                     8.598
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):            0.00346
# Time:                            11:47:55   Log-Likelihood:                -1878.9
# No. Observations:                     821   AIC:                             3762.
# Df Residuals:                         819   BIC:                             3771.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.5160      0.112    112.247      0.000      12.297      12.735
# reg25_112      0.4924      0.168      2.932      0.003       0.163       0.822
# ==============================================================================
# Omnibus:                        2.731   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.255   Jarque-Bera (JB):                2.761
# Skew:                          -0.140   Prob(JB):                        0.251
# Kurtosis:                       2.951   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg25_112
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.431
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.232
# Time:                        11:47:55   Log-Likelihood:                -16.278
# No. Observations:                 822   AIC:                             36.56
# Df Residuals:                     820   BIC:                             45.98
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3683      0.012     31.930      0.000       0.346       0.391
# reg25_112     -0.0208      0.017     -1.196      0.232      -0.055       0.013
# ==============================================================================
# Omnibus:                       71.930   Durbin-Watson:                   1.252
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.808
# Skew:                           0.796   Prob(JB):                     5.20e-20
# Kurtosis:                       2.759   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5981
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.440
# Time:                        11:47:55   Log-Likelihood:                -33.132
# No. Observations:                 822   AIC:                             70.26
# Df Residuals:                     820   BIC:                             79.69
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5278      0.012     44.830      0.000       0.505       0.551
# reg25_112      0.0137      0.018      0.773      0.440      -0.021       0.048
# ==============================================================================
# Omnibus:                      129.679   Durbin-Watson:                   1.400
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.324
# Skew:                          -0.403   Prob(JB):                     1.18e-11
# Kurtosis:                       2.094   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.177
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.278
# Time:                        11:47:55   Log-Likelihood:                 698.96
# No. Observations:                 822   AIC:                            -1394.
# Df Residuals:                     820   BIC:                            -1384.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0647      0.005     13.385      0.000       0.055       0.074
# reg25_112      0.0079      0.007      1.085      0.278      -0.006       0.022
# ==============================================================================
# Omnibus:                      573.230   Durbin-Watson:                   1.515
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7199.049
# Skew:                           3.097   Prob(JB):                         0.00
# Kurtosis:                      16.108   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.494
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.222
# Time:                        11:47:55   Log-Likelihood:                 222.89
# No. Observations:                 822   AIC:                            -441.8
# Df Residuals:                     820   BIC:                            -432.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5614      0.009     65.108      0.000       0.544       0.578
# reg25_112     -0.0159      0.013     -1.222      0.222      -0.041       0.010
# ==============================================================================
# Omnibus:                       10.969   Durbin-Watson:                   1.692
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.270
# Skew:                          -0.281   Prob(JB):                      0.00357
# Kurtosis:                       2.883   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg25_112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.002917
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.957
# Time:                        11:47:55   Log-Likelihood:                -895.25
# No. Observations:                 822   AIC:                             1795.
# Df Residuals:                     820   BIC:                             1804.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3231      0.034      9.616      0.000       0.257       0.389
# reg25_112     -0.0027      0.051     -0.054      0.957      -0.102       0.097
# ==============================================================================
# Omnibus:                       47.750   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.576
# Skew:                           0.568   Prob(JB):                     5.18e-13
# Kurtosis:                       3.601   Cond. No.                         2.50
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 25.111

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_111')
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_111')
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'reg25_111')
dfs = [district, teacher, student]
rows = [5, 14, 21]
for df, row in zip(dfs,rows):
    tables.just_diff_to_excel(file = table_path + 'balance_hiring.xlsx', 
                             df = df, 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 4, start_row = row)
# Out:
# type_urban ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_urban   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8022
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.371
# Time:                        11:47:55   Log-Likelihood:                 106.81
# No. Observations:                 822   AIC:                            -209.6
# Df Residuals:                     820   BIC:                            -200.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0446      0.008      5.527      0.000       0.029       0.060
# reg25_111      0.0184      0.021      0.896      0.371      -0.022       0.059
# ==============================================================================
# Omnibus:                      720.645   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11350.417
# Skew:                           4.251   Prob(JB):                         0.00
# Kurtosis:                      19.097   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_suburban ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          type_suburban   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2225
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.637
# Time:                        11:47:55   Log-Likelihood:                -470.75
# No. Observations:                 822   AIC:                             945.5
# Df Residuals:                     820   BIC:                             954.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2403      0.016     14.747      0.000       0.208       0.272
# reg25_111      0.0196      0.041      0.472      0.637      -0.062       0.101
# ==============================================================================
# Omnibus:                      150.833   Durbin-Watson:                   1.271
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.021
# Skew:                           1.196   Prob(JB):                     1.11e-45
# Kurtosis:                       2.432   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_town ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              type_town   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2492
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.618
# Time:                        11:47:55   Log-Likelihood:                -498.83
# No. Observations:                 822   AIC:                             1002.
# Df Residuals:                     820   BIC:                             1011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2734      0.017     16.215      0.000       0.240       0.306
# reg25_111     -0.0214      0.043     -0.499      0.618      -0.106       0.063
# ==============================================================================
# Omnibus:                      225.174   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.240
# Skew:                           1.035   Prob(JB):                     5.37e-39
# Kurtosis:                       2.073   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# type_rural ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             type_rural   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1188
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.730
# Time:                        11:47:55   Log-Likelihood:                -590.41
# No. Observations:                 822   AIC:                             1185.
# Df Residuals:                     820   BIC:                             1194.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4417      0.019     23.438      0.000       0.405       0.479
# reg25_111     -0.0165      0.048     -0.345      0.730      -0.111       0.078
# ==============================================================================
# Omnibus:                        8.142   Durbin-Watson:                   1.632
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):              137.046
# Skew:                           0.245   Prob(JB):                     1.74e-30
# Kurtosis:                       1.061   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_tenure_ave ~ + 1 + reg25_111
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.000
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                   0.08000
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):              0.777
# Time:                         11:47:55   Log-Likelihood:                -1673.3
# No. Observations:                  821   AIC:                             3351.
# Df Residuals:                      819   BIC:                             3360.
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.1721      0.071    101.674      0.000       7.034       7.311
# reg25_111      0.0509      0.180      0.283      0.777      -0.303       0.404
# ==============================================================================
# Omnibus:                       19.577   Durbin-Watson:                   1.761
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.474
# Skew:                           0.116   Prob(JB):                     1.20e-08
# Kurtosis:                       4.006   Cond. No.                         2.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# teachers_turnover_ratio_d ~ + 1 + reg25_111
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     teachers_turnover_ratio_d   R-squared:                       0.001
# Model:                                   OLS   Adj. R-squared:                 -0.000
# Method:                        Least Squares   F-statistic:                    0.6638
# Date:                       Sun, 16 Feb 2020   Prob (F-statistic):              0.415
# Time:                               11:47:55   Log-Likelihood:                -2922.7
# No. Observations:                        821   AIC:                             5849.
# Df Residuals:                            819   BIC:                             5859.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.7164      0.323     57.926      0.000      18.082      19.351
# reg25_111     -0.6720      0.825     -0.815      0.415      -2.291       0.947
# ==============================================================================
# Omnibus:                      151.394   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              361.501
# Skew:                           0.982   Prob(JB):                     3.17e-79
# Kurtosis:                       5.590   Cond. No.                         2.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_teacher_ratio ~ + 1 + reg25_111
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/statsmodels/base/data.py:480: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   if hasattr(x, 'ix'):
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     students_teacher_ratio   R-squared:                       0.013
# Model:                                OLS   Adj. R-squared:                  0.012
# Method:                     Least Squares   F-statistic:                     11.09
# Date:                    Sun, 16 Feb 2020   Prob (F-statistic):           0.000909
# Time:                            11:47:56   Log-Likelihood:                -1877.7
# No. Observations:                     821   AIC:                             3759.
# Df Residuals:                         819   BIC:                             3769.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.6151      0.090    139.424      0.000      12.437      12.793
# reg25_111      0.7690      0.231      3.329      0.001       0.316       1.222
# ==============================================================================
# Omnibus:                        3.552   Durbin-Watson:                   1.284
# Prob(Omnibus):                  0.169   Jarque-Bera (JB):                3.562
# Skew:                          -0.161   Prob(JB):                        0.169
# Kurtosis:                       2.969   Cond. No.                         2.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_hisp ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_hisp   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3389
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.561
# Time:                        11:47:56   Log-Likelihood:                -16.825
# No. Observations:                 822   AIC:                             37.65
# Df Residuals:                     820   BIC:                             47.07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3570      0.009     38.057      0.000       0.339       0.375
# reg25_111      0.0139      0.024      0.582      0.561      -0.033       0.061
# ==============================================================================
# Omnibus:                       72.105   Durbin-Watson:                   1.260
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.423
# Skew:                           0.800   Prob(JB):                     3.82e-20
# Kurtosis:                       2.779   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_white ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_white   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4723
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.492
# Time:                        11:47:56   Log-Likelihood:                -33.195
# No. Observations:                 822   AIC:                             70.39
# Df Residuals:                     820   BIC:                             79.81
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5364      0.010     56.062      0.000       0.518       0.555
# reg25_111     -0.0167      0.024     -0.687      0.492      -0.065       0.031
# ==============================================================================
# Omnibus:                      124.775   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.677
# Skew:                          -0.402   Prob(JB):                     1.63e-11
# Kurtosis:                       2.104   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_black ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         students_black   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2489
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.618
# Time:                        11:47:56   Log-Likelihood:                 698.49
# No. Observations:                 822   AIC:                            -1393.
# Df Residuals:                     820   BIC:                            -1384.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0674      0.004     17.151      0.000       0.060       0.075
# reg25_111      0.0050      0.010      0.499      0.618      -0.015       0.025
# ==============================================================================
# Omnibus:                      572.070   Durbin-Watson:                   1.508
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7117.909
# Skew:                           3.092   Prob(JB):                         0.00
# Kurtosis:                      16.022   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# students_frpl ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          students_frpl   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.01397
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.906
# Time:                        11:47:56   Log-Likelihood:                 222.14
# No. Observations:                 822   AIC:                            -440.3
# Df Residuals:                     820   BIC:                            -430.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5547      0.007     79.092      0.000       0.541       0.568
# reg25_111     -0.0021      0.018     -0.118      0.906      -0.037       0.033
# ==============================================================================
# Omnibus:                       11.295   Durbin-Watson:                   1.698
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.608
# Skew:                          -0.284   Prob(JB):                      0.00302
# Kurtosis:                       2.875   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# avescores ~ + 1 + reg25_111
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              avescores   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1760
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.675
# Time:                        11:47:56   Log-Likelihood:                -895.17
# No. Observations:                 822   AIC:                             1794.
# Df Residuals:                     820   BIC:                             1804.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3174      0.027     11.625      0.000       0.264       0.371
# reg25_111      0.0291      0.069      0.419      0.675      -0.107       0.165
# ==============================================================================
# Omnibus:                       47.889   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.786
# Skew:                           0.569   Prob(JB):                     4.67e-13
# Kurtosis:                       3.603   Cond. No.                         2.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
