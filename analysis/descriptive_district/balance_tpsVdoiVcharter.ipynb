# %%
import sys
sys.path.append("../")

import pandas as pd
import os
import statsmodels.formula.api as sm

from library import regulations
from library import characteristics
from library import analysis
from library import tables

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
table_path = '/Users/kylieleblancKylie/domino/dofis/results/descriptive/'
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data_district.csv'),
                  sep=",")
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Just keep eligible districts and charters from 2014-15

# %%
data = data[data.year == 2016]

# %% [markdown]
# ## District Characteristics

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'doi')
district
# note, I don't have the geographic characteristics of charter schools
# Out:
# type_urban ~ + 1 + doi
#                             OLS Regression Results
# ...
# Dep. Variable:             type_urban   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.189
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):              0.276
# Time:                        08:42:23   Log-Likelihood:                 212.31
# No. Observations:                1207   AIC:                            -420.6
# Df Residuals:                    1205   BIC:                            -410.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0338      0.010      3.262      0.001       0.013       0.054
# ...

# %% [markdown]
# ## Teacher Characteristics

# %%
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'doi')
teacher
# Out:
# teachers_tenure_ave ~ + 1 + doi
#                              OLS Regression Results
# ...
# Dep. Variable:     teachers_tenure_ave   R-squared:                       0.193
# Model:                             OLS   Adj. R-squared:                  0.193
# Method:                  Least Squares   F-statistic:                     287.9
# Date:                 Sun, 16 Feb 2020   Prob (F-statistic):           4.78e-58
# Time:                         08:42:31   Log-Likelihood:                -2724.5
# No. Observations:                 1203   AIC:                             5453.
# Df Residuals:                     1201   BIC:                             5463.
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       4.7296      0.119     39.643      0.000       4.496       4.964
# ...

# %% [markdown]
# ## Student Characteristics

# %%
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'doi')
student
# Out:
# students_hisp ~ + 1 + doi
#                             OLS Regression Results
# ...
# Dep. Variable:          students_hisp   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     92.64
# Date:                Sun, 16 Feb 2020   Prob (F-statistic):           3.55e-21
# Time:                        08:42:35   Log-Likelihood:                -118.49
# No. Observations:                1207   AIC:                             241.0
# Df Residuals:                    1205   BIC:                             251.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.5179      0.014     38.039      0.000       0.491       0.545
# ...

# %% [markdown]
# ## To table

# %%
dfs = [district, teacher, student]
rows = [6, 15, 24]
tables.n_to_excel(file = table_path + 'balance_tpsVdoiVcharter.xlsx',
                 col = 2, row = 4, n = len(data[data.doi == 0]))
tables.n_to_excel(file = table_path + 'balance_tpsVdoiVcharter.xlsx',
                 col = 3, row = 4, n = len(data[data.doi == 1]))
for df, row in zip(dfs,rows):
    tables.var_diff_to_excel(file = table_path + 'balance_tpsVdoiVcharter.xlsx', 
                             df = df, 
                             control_col = 'Control', 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 2, start_row = row)

# %% [markdown]
# # Add charter columns

# %%
data = pd.read_csv(os.path.join(data_path, 'clean', 'master_data.csv'),
                  sep=",")
data = data[data.year == 'yr1415']
data = data[(data.eligible == 1 ) | (data.charter == True)]
# Out:
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,9,10,280) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/kylieleblancKylie/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# Traditional public schools versus DOI
district = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.geography,
                                 y_labels = characteristics.labels,
                                 x = 'charter')
district
# note, I don't have the geographic characteristics of charter schools
# Out:
# type_urban ~ + 1 + charter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a64eb67c986f> in <module>()
#       3                                  y_list = characteristics.geography,
#       4                                  y_labels = characteristics.labels,
# ----> 5                                  x = 'charter')
#       6 district
#       7 # note, I don't have the geographic characteristics of charter schools
#
# ~/domino/dofis/src/analysis/library/analysis.py in many_y_one_x(data, y_list, y_labels, x)
#      60         formula = y + ' ~ + 1 + ' + x
#      61         print(formula)
# ---> 62         result = smf.ols(formula=formula, data=data).fit()
#      63         print(result.summary())
#      64         cons.append(result.params["Intercept"].round(2))
#
# ...

# %% [markdown]
# Some basic descriptives

# %% [markdown]
# # Teacher characteristics

# %%
teacher = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.teacher,
                                 y_labels = characteristics.labels,
                                 x = 'charter')
teacher
# Out:
#              Characteristic  Control  Difference  Std. Error  P-value
# 0  Ave. Experience Teaching     7.37       -5.00        0.16      0.0
# 1    Teacher Turnover Ratio     0.19        0.17        0.01      0.0
# 2     Student-Teacher Ratio     6.64        4.60        1.01      0.0

# %% [markdown]
# # Student Characteristics

# %%
student = analysis.many_y_one_x(data = data, 
                                 y_list = characteristics.student,
                                 y_labels = characteristics.labels,
                                 x = 'charter')
student
# Out:
#                      Characteristic  Control  Difference  Std. Error  P-value
# 0                  Percent Hispanic     0.38        0.12        0.02      0.0
# 1                     Percent White     0.52       -0.32        0.02      0.0
# 2                     Percent Black     0.06        0.19        0.01      0.0
# 3       Percent Econ. Disadvantaged     0.56        0.12        0.02      0.0
# 4  Average STAAR Performance (Std.)     0.09       -0.54        0.06      0.0

# %% [markdown]
# # To Table

# %%
dfs = [district, teacher, student]
rows = [6, 15, 24]
tables.n_to_excel(file = table_path + 'balance_tpsVdoiVcharter.xlsx',
                 col = 4, row = 4, n = len(data[data.charter == True]))
for df, row in zip(dfs,rows):
    tables.var_diff_to_excel(file = table_path + 'balance_tpsVdoiVcharter.xlsx', 
                             df = df, 
                             control_col = 'Control', 
                             diff_col = 'Difference', 
                             se_col = 'Std. Error', pvalue_col = 'P-value',
                             start_col = 2, start_row = row,
                             change_diff_col = 4)
