# %%
import pandas as pd
import os
import re
import spacy
import en_core_web_sm
from spacy.matcher import Matcher
from IPython.display import clear_output

# %%
data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
docs = pd.read_csv(os.path.join(data_path, 'clean', 'phrases_classsize.csv'),
                  sep=",")
docs.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d33f8344980a> in <module>()
#       1 data_path = '/Users/kylieleblancKylie/domino/dofis/data/'
#       2 docs = pd.read_csv(os.path.join(data_path, 'clean', 'phrases_classsize.csv'),
# ----> 3                   sep=",")
#       4 docs.head()
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda/envs/spacy/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/Users/kylieleblancKylie/domino/dofis/data/clean/phrases_classsize.csv' does not exist: b'/Users/kylieleblancKylie/domino/dofis/data/clean/phrases_classsize.csv'

# %%
docs_to_label = docs.sample(n = 50, random_state = 45)
docs_to_label = docs_to_label[['phrase', 'link']]
docs_to_label = docs_to_label.rename({'phrase': 'text', 'link': 'source'}, axis = 1)
#docs_to_label.to_csv(os.path.join(data_path, 'plans', 'certification_to_label.csv'), header = True)

# %%
if True:
    teacher_matters_more = []
    changes = []
    for text, source in zip(docs_to_label.text[0:12], docs_to_label.source[0:12]):
        show = str(source) + str(text)
        
        annotation = input(show + "Say teachers matter more")
        teacher_matters_more.append(annotation)
        
        annotation = input("Mentions changing enrollmemt")
        changes.append(annotation)
                     
        clear_output()

# %%
teacher_matters_more
# Out:
# ['0', '1', '0', '1', '0', '0', '0', '1', '0', '0', '0', '0']

# %%
changes
# Out:
# ['1', '0', '1', '0', '0', '0', '1', '0', '0', '0', '1', '0']

# %%
if True:
    hiring = []
    for text, source in zip(docs_to_label.text[0:12], docs_to_label.source[0:12]):
        show = str(source) + str(text)
        
        annotation = input(show + "Hiring logistics")
        hiring.append(annotation)
        
        clear_output()

# %%
hiring
# Out:
# ['0', '0', '0', '1', '0', '0', '1', '0', '.', '1', '0', '0']
